# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left">

# %% [markdown]
# # Project | API and Web Data Scraping

# %% [markdown]
# ## Import Useful Libraries

# %%
import os
import numpy as np
import pandas as pd
import random
import operator
import re
import math
import matplotlib.pyplot as plt
from matplotlib import cm
import json
import requests
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
import pypokedex
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import scrapy

# %% [markdown]
# ## Working On The API

# %%
url = "https://pikalytics.com/api/p/2020-01/ss-1760"

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36"}

response = requests.get(url, headers = headers) 
results = response.json()
flattened_data = json_normalize(results)
pikalyticsDF = flattened_data

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)

# %%
pikalyticsDF = pikalyticsDF.drop(['abilities', 'raw_count', 'items', 'spreads', 'moves', 'stats.hp',
       'stats.atk', 'stats.def', 'stats.spa', 'stats.spd', 'stats.spe', 'ss'], axis=1)
pikalyticsDF.head(5)
# Out:
#          name            types  percent ranking viability  \
# 0  Togekiss    [fairy, flying]  46.0     1       B
# 1  Arcanine    [fire]           36.0     2       B
# 2  Dragapult   [dragon, ghost]  31.0     3       B
# 3  Excadrill   [ground, steel]  30.0     4       B
# 4  Whimsicott  [grass, fairy]   29.0     5       B-
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              team
# 0  [{'pokemon': 'Excadrill', 'percent': '38.536', 'types': ['ground', 'steel']}, {'pokemon': 'Arcanine', 'percent': '35.593', 'types': ['fire']}, {'pokemon': 'Dragapult', 'percent': '33.117', 'types': ['dragon', 'ghost']}, {'pokemon': 'Tyranitar', 'percent': '25.192', 'types': ['rock', 'dark']}, {'pokemon': 'Whimsicott', 'percent': '21.162', 'types': ['grass', 'fairy']}, {'pokemon': 'Gyarados', 'percent': '16.886', 'types': ['water', 'flying']}, {'pokemon': 'Duraludon', 'percent': '16.087', 'types': ['steel', 'dragon']}, {'pokemon': 'Rhyperior', 'percent': '15.737', 'types': ['ground', 'rock']}, {'pokemon': 'Gastrodon', 'percent': '14.598', 'types': ['water', 'ground']}, {'pokemon': 'Conkeldurr', 'percent': '14.553', 'types': ['fighting']}]
# 1  [{'pokemon': 'Togekiss', 'percent': '45.687', 'types': ['fairy', 'flying']}, {'pokemon': 'Dragapult', 'percent': '30.663', 'types': ['dragon', 'ghost']}, {'pokemon': 'Tyranitar', 'percent': '28.847', 'types': ['rock', 'dark']}, {'pokemon': 'Duraludon', 'percent': '27.120', 'types': ['steel', 'dragon']}, {'pokemon': 'Excadrill', 'percent': '25.730', 'types': ['ground', 'steel']}, {'pokemon': 'Grimmsnarl', 'percent': '24.526', 'types': ['dark', 'fairy']}, {'pokemon': 'Whimsicott', 'percent': '21.763', 'types': ['grass', 'fairy']}, {'pokemon': 'Gastrodon', 'percent': '19.336', 'types': ['water', 'ground']}, {'pokemon': 'Rotom-Mow', 'percent': '16.678', 'types': ['electric', 'grass']}, {'pokemon': 'Gyarados', 'percent': '15.125', 'types': ['water', 'flying']}]
# 2  [{'pokemon': 'Togekiss', 'percent': '48.228', 'types': ['fairy', 'flying']}, {'pokemon': 'Excadrill', 'percent': '38.133', 'types': ['ground', 'steel']}, {'pokemon': 'Arcanine', 'percent': '34.788', 'types': ['fire']}, {'pokemon': 'Tyranitar', 'percent': '22.340', 'types': ['rock', 'dark']}, {'pokemon': 'Whimsicott', 'percent': '21.628', 'types': ['grass', 'fairy']}, {'pokemon': 'Gyarados', 'percent': '17.180', 'types': ['water', 'flying']}, {'pokemon': 'Grimmsnarl', 'percent': '16.063', 'types': ['dark', 'fairy']}, {'pokemon': 'Gastrodon', 'percent': '14.782', 'types': ['water', 'ground']}, {'pokemon': 'Rotom-Wash', 'percent': '13.061', 'types': ['electric', 'water']}, {'pokemon': 'Rhyperior', 'percent': '12.991', 'types': ['ground', 'rock']}]
# 3  [{'pokemon': 'Togekiss', 'percent': '59.572', 'types': ['fairy', 'flying']}, {'pokemon': 'Tyranitar', 'percent': '47.122', 'types': ['rock', 'dark']}, {'pokemon': 'Dragapult', 'percent': '40.479', 'types': ['dragon', 'ghost']}, {'pokemon': 'Arcanine', 'percent': '30.988', 'types': ['fire']}, {'pokemon': 'Gyarados', 'percent': '21.042', 'types': ['water', 'flying']}, {'pokemon': 'Gastrodon', 'percent': '18.387', 'types': ['water', 'ground']}, {'pokemon': 'Rotom-Mow', 'percent': '17.144', 'types': ['electric', 'grass']}, {'pokemon': 'Whimsicott', 'percent': '16.426', 'types': ['grass', 'fairy']}, {'pokemon': 'Grimmsnarl', 'percent': '13.473', 'types': ['dark', 'fairy']}, {'pokemon': 'Rotom-Wash', 'percent': '11.674', 'types': ['electric', 'water']}]
# 4  [{'pokemon': 'Duraludon', 'percent': '36.074', 'types': ['steel', 'dragon']}, {'pokemon': 'Togekiss', 'percent': '32.431', 'types': ['fairy', 'flying']}, {'pokemon': 'Arcanine', 'percent': '25.983', 'types': ['fire']}, {'pokemon': 'Dragapult', 'percent': '22.760', 'types': ['dragon', 'ghost']}, {'pokemon': 'Conkeldurr', 'percent': '20.132', 'types': ['fighting']}, {'pokemon': 'Vanilluxe', 'percent': '18.337', 'types': ['ice']}, {'pokemon': 'Inteleon', 'percent': '17.118', 'types': ['water']}, {'pokemon': 'Excadrill', 'percent': '16.284', 'types': ['ground', 'steel']}, {'pokemon': 'Charizard', 'percent': '16.277', 'types': ['fire', 'flying']}, {'pokemon': 'Dracovish', 'percent': '15.995', 'types': ['water', 'dragon']}]

# %%
teams1 = pikalyticsDF["team"].tolist()

# %%
teams1DF = pd.DataFrame(teams1)

# %%
teams1DF2 = teams1DF.drop([3,4,5,6,7,8,9,10,11], axis=1)

# %%
teams1DF2
# Out:
#                                                                                   0  \
# 0    {'pokemon': 'Excadrill', 'percent': '38.536', 'types': ['ground', 'steel']}
# 1    {'pokemon': 'Togekiss', 'percent': '45.687', 'types': ['fairy', 'flying']}
# 2    {'pokemon': 'Togekiss', 'percent': '48.228', 'types': ['fairy', 'flying']}
# 3    {'pokemon': 'Togekiss', 'percent': '59.572', 'types': ['fairy', 'flying']}
# 4    {'pokemon': 'Duraludon', 'percent': '36.074', 'types': ['steel', 'dragon']}
# 5    {'pokemon': 'Whimsicott', 'percent': '43.844', 'types': ['grass', 'fairy']}
# 6    {'pokemon': 'Excadrill', 'percent': '61.114', 'types': ['ground', 'steel']}
# 7    {'pokemon': 'Arcanine', 'percent': '42.733', 'types': ['fire']}
# 8    {'pokemon': 'Togekiss', 'percent': '44.558', 'types': ['fairy', 'flying']}
# 9    {'pokemon': 'Arcanine', 'percent': '41.752', 'types': ['fire']}
# 10   {'pokemon': 'Togekiss', 'percent': '45.370', 'types': ['fairy', 'flying']}
# 11   {'pokemon': 'Togekiss', 'percent': '43.360', 'types': ['fairy', 'flying']}
# 12   {'pokemon': 'Arcanine', 'percent': '48.590', 'types': ['fire']}
# 13   {'pokemon': 'Togekiss', 'percent': '38.990', 'types': ['fairy', 'flying']}
# 14   {'pokemon': 'Rhyperior', 'percent': '55.334', 'types': ['ground', 'rock']}
# 15   {'pokemon': 'Duraludon', 'percent': '46.930', 'types': ['steel', 'dragon']}
# 16   {'pokemon': 'Whimsicott', 'percent': '50.403', 'types': ['grass', 'fairy']}
# 17   {'pokemon': 'Arcanine', 'percent': '49.085', 'types': ['fire']}
# 18   {'pokemon': 'Rhyperior', 'percent': '59.591', 'types': ['ground', 'rock']}
# 19   {'pokemon': 'Vanilluxe', 'percent': '54.977', 'types': ['ice']}
# 20   {'pokemon': 'Whimsicott', 'percent': '53.262', 'types': ['grass', 'fairy']}
# 21   {'pokemon': 'Braviary', 'percent': '28.356', 'types': ['normal', 'flying']}
# 22   {'pokemon': 'Togekiss', 'percent': '49.515', 'types': ['fairy', 'flying']}
# 23   {'pokemon': 'Arcanine', 'percent': '44.108', 'types': ['fire']}
# 24   {'pokemon': 'Togekiss', 'percent': '55.317', 'types': ['fairy', 'flying']}
# 25   {'pokemon': 'Whimsicott', 'percent': '56.500', 'types': ['grass', 'fairy']}
# 26   {'pokemon': 'Togekiss', 'percent': '51.005', 'types': ['fairy', 'flying']}
# 27   {'pokemon': 'Excadrill', 'percent': '42.680', 'types': ['ground', 'steel']}
# 28   {'pokemon': 'Whimsicott', 'percent': '50.520', 'types': ['grass', 'fairy']}
# 29   {'pokemon': 'Torkoal', 'percent': '31.468', 'types': ['fire']}
# 30   {'pokemon': 'Arcanine', 'percent': '47.719', 'types': ['fire']}
# 31   {'pokemon': 'Excadrill', 'percent': '51.606', 'types': ['ground', 'steel']}
# 32   {'pokemon': 'Togekiss', 'percent': '56.460', 'types': ['fairy', 'flying']}
# 33   {'pokemon': 'Arcanine', 'percent': '40.752', 'types': ['fire']}
# 34   {'pokemon': 'Togekiss', 'percent': '59.191', 'types': ['fairy', 'flying']}
# 35   {'pokemon': 'Rhyperior', 'percent': '73.684', 'types': ['ground', 'rock']}
# 36   {'pokemon': 'Arcanine', 'percent': '53.127', 'types': ['fire']}
# 37   {'pokemon': 'Rhyperior', 'percent': '27.432', 'types': ['ground', 'rock']}
# 38   {'pokemon': 'Rhyperior', 'percent': '48.736', 'types': ['ground', 'rock']}
# 39   {'pokemon': 'Togekiss', 'percent': '62.854', 'types': ['fairy', 'flying']}
# 40   {'pokemon': 'Torkoal', 'percent': '49.243', 'types': ['fire']}
# 41   {'pokemon': 'Whimsicott', 'percent': '71.934', 'types': ['grass', 'fairy']}
# 42   {'pokemon': 'Togekiss', 'percent': '46.575', 'types': ['fairy', 'flying']}
# 43   {'pokemon': 'Ludicolo', 'percent': '61.150', 'types': ['water', 'grass']}
# 44   {'pokemon': 'Pelipper', 'percent': '62.620', 'types': ['water', 'flying']}
# 45   {'pokemon': 'Togekiss', 'percent': '43.452', 'types': ['fairy', 'flying']}
# 46   {'pokemon': 'Whimsicott', 'percent': '54.438', 'types': ['grass', 'fairy']}
# 47   {'pokemon': 'Braviary', 'percent': '44.093', 'types': ['normal', 'flying']}
# 48   {'pokemon': 'Whimsicott', 'percent': '73.995', 'types': ['grass', 'fairy']}
# 49   {'pokemon': 'Torkoal', 'percent': '84.899', 'types': ['fire']}
# 50   {'pokemon': 'Togekiss', 'percent': '42.760', 'types': ['fairy', 'flying']}
# 51   {'pokemon': 'Togekiss', 'percent': '43.723', 'types': ['fairy', 'flying']}
# 52   {'pokemon': 'Arcanine', 'percent': '23.885', 'types': ['fire']}
# 53   {'pokemon': 'Excadrill', 'percent': '85.130', 'types': ['ground', 'steel']}
# 54   {'pokemon': 'Gyarados', 'percent': '57.501', 'types': ['water', 'flying']}
# 55   {'pokemon': 'Torkoal', 'percent': '56.333', 'types': ['fire']}
# 56   {'pokemon': 'Togekiss', 'percent': '47.490', 'types': ['fairy', 'flying']}
# 57   {'pokemon': 'Arcanine', 'percent': '45.633', 'types': ['fire']}
# 58   {'pokemon': 'Togekiss', 'percent': '59.342', 'types': ['fairy', 'flying']}
# 59   {'pokemon': 'Rotom-Wash', 'percent': '36.913', 'types': ['electric', 'water']}
# 60   {'pokemon': 'Indeedee-F', 'percent': '48.047', 'types': ['psychic', 'normal']}
# 61   {'pokemon': 'Whimsicott', 'percent': '61.259', 'types': ['grass', 'fairy']}
# 62   {'pokemon': 'Arcanine', 'percent': '77.814', 'types': ['fire']}
# 63   {'pokemon': 'Whimsicott', 'percent': '30.781', 'types': ['grass', 'fairy']}
# 64   {'pokemon': 'Inteleon', 'percent': '41.159', 'types': ['water']}
# 65   {'pokemon': 'Togekiss', 'percent': '34.192', 'types': ['fairy', 'flying']}
# 66   {'pokemon': 'Togekiss', 'percent': '44.748', 'types': ['fairy', 'flying']}
# 67   {'pokemon': 'Togekiss', 'percent': '56.933', 'types': ['fairy', 'flying']}
# 68   {'pokemon': 'Togekiss', 'percent': '29.450', 'types': ['fairy', 'flying']}
# 69   {'pokemon': 'Dragapult', 'percent': '42.322', 'types': ['dragon', 'ghost']}
# 70   {'pokemon': 'Arcanine', 'percent': '38.432', 'types': ['fire']}
# 71   {'pokemon': 'Excadrill', 'percent': '78.704', 'types': ['ground', 'steel']}
# 72   {'pokemon': 'Whimsicott', 'percent': '31.958', 'types': ['grass', 'fairy']}
# 73   {'pokemon': 'Togekiss', 'percent': '45.525', 'types': ['fairy', 'flying']}
# 74   {'pokemon': 'Togekiss', 'percent': '27.761', 'types': ['fairy', 'flying']}
# 75   {'pokemon': 'Arcanine', 'percent': '40.586', 'types': ['fire']}
# 76   {'pokemon': 'Snorlax', 'percent': '74.269', 'types': ['normal']}
# 77   {'pokemon': 'Togekiss', 'percent': '72.501', 'types': ['fairy', 'flying']}
# 78   {'pokemon': 'Lapras', 'percent': '60.952', 'types': ['water', 'ice']}
# 79   {'pokemon': 'Excadrill', 'percent': '35.627', 'types': ['ground', 'steel']}
# 80   {'pokemon': 'Conkeldurr', 'percent': '39.703', 'types': ['fighting']}
# 81   {'pokemon': 'Milotic', 'percent': '42.510', 'types': ['water']}
# 82   {'pokemon': 'Hatterene', 'percent': '35.132', 'types': ['psychic', 'fairy']}
# 83   {'pokemon': 'Excadrill', 'percent': '58.091', 'types': ['ground', 'steel']}
# 84   {'pokemon': 'Dragapult', 'percent': '44.609', 'types': ['dragon', 'ghost']}
# 85   {'pokemon': 'Togekiss', 'percent': '56.864', 'types': ['fairy', 'flying']}
# 86   {'pokemon': 'Pelipper', 'percent': '49.755', 'types': ['water', 'flying']}
# 87   {'pokemon': 'Conkeldurr', 'percent': '80.904', 'types': ['fighting']}
# 88   {'pokemon': 'Togekiss', 'percent': '54.023', 'types': ['fairy', 'flying']}
# 89   {'pokemon': 'Togekiss', 'percent': '38.457', 'types': ['fairy', 'flying']}
# 90   {'pokemon': 'Arcanine', 'percent': '28.094', 'types': ['fire']}
# 91   {'pokemon': 'Tyranitar', 'percent': '52.575', 'types': ['rock', 'dark']}
# 92   {'pokemon': 'Togekiss', 'percent': '45.196', 'types': ['fairy', 'flying']}
# 93   {'pokemon': 'Conkeldurr', 'percent': '38.191', 'types': ['fighting']}
# 94   {'pokemon': 'Duraludon', 'percent': '25.869', 'types': ['steel', 'dragon']}
# 95   {'pokemon': 'Togekiss', 'percent': '35.220', 'types': ['fairy', 'flying']}
# 96   {'pokemon': 'Togekiss', 'percent': '51.331', 'types': ['fairy', 'flying']}
# 97   {'pokemon': 'Torkoal', 'percent': '54.627', 'types': ['fire']}
# 98   {'pokemon': 'Pelipper', 'percent': '58.174', 'types': ['water', 'flying']}
# 99   {'pokemon': 'Snorlax', 'percent': '88.464', 'types': ['normal']}
# 100  {'pokemon': 'Corviknight', 'percent': '26.094', 'types': ['flying', 'steel']}
# 101  {'pokemon': 'Togekiss', 'percent': '36.426', 'types': ['fairy', 'flying']}
# 102  {'pokemon': 'Whimsicott', 'percent': '57.710', 'types': ['grass', 'fairy']}
# 103  {'pokemon': 'Grimmsnarl', 'percent': '26.816', 'types': ['dark', 'fairy']}
# 104  {'pokemon': 'Togekiss', 'percent': '78.323', 'types': ['fairy', 'flying']}
# 105  {'pokemon': 'Gastrodon', 'percent': '46.046', 'types': ['water', 'ground']}
# 106  {'pokemon': 'Whimsicott', 'percent': '65.658', 'types': ['grass', 'fairy']}
# 107  {'pokemon': 'Dusclops', 'percent': '42.198', 'types': ['ghost']}
# 108  {'pokemon': 'Torkoal', 'percent': '37.628', 'types': ['fire']}
# 109  {'pokemon': 'Arcanine', 'percent': '45.190', 'types': ['fire']}
# 110  {'pokemon': 'Rhyperior', 'percent': '21.387', 'types': ['ground', 'rock']}
# 111  {'pokemon': 'Duraludon', 'percent': '28.007', 'types': ['steel', 'dragon']}
# 112  {'pokemon': 'Togekiss', 'percent': '32.731', 'types': ['fairy', 'flying']}
# 113  {'pokemon': 'Gothitelle', 'percent': '31.377', 'types': ['psychic']}
# 114  {'pokemon': 'Arcanine', 'percent': '29.374', 'types': ['fire']}
# 115  {'pokemon': 'Togekiss', 'percent': '23.268', 'types': ['fairy', 'flying']}
# 116  {'pokemon': 'Hatterene', 'percent': '30.869', 'types': ['psychic', 'fairy']}
# 117  {'pokemon': 'Whimsicott', 'percent': '35.545', 'types': ['grass', 'fairy']}
# 118  {'pokemon': 'Tyranitar', 'percent': '56.405', 'types': ['rock', 'dark']}
# 119  {'pokemon': 'Torkoal', 'percent': '58.956', 'types': ['fire']}
# 120  {'pokemon': 'Torkoal', 'percent': '83.935', 'types': ['fire']}
# 121  {'pokemon': 'Whimsicott', 'percent': '25.308', 'types': ['grass', 'fairy']}
# 122  {'pokemon': 'Whimsicott', 'percent': '47.827', 'types': ['grass', 'fairy']}
# 123  {'pokemon': 'Hatterene', 'percent': '56.400', 'types': ['psychic', 'fairy']}
# 124  {'pokemon': 'Dragapult', 'percent': '36.598', 'types': ['dragon', 'ghost']}
# 125  {'pokemon': 'Milotic', 'percent': '42.528', 'types': ['water']}
# 126  {'pokemon': 'Pelipper', 'percent': '72.386', 'types': ['water', 'flying']}
# 127  {'pokemon': 'Arcanine', 'percent': '71.407', 'types': ['fire']}
# 128  {'pokemon': 'Grimmsnarl', 'percent': '63.223', 'types': ['dark', 'fairy']}
# 129  {'pokemon': 'Togekiss', 'percent': '51.725', 'types': ['fairy', 'flying']}
# 130  {'pokemon': 'Togekiss', 'percent': '26.062', 'types': ['fairy', 'flying']}
# 131  {'pokemon': 'Dracozolt', 'percent': '32.540', 'types': ['electric', 'dragon']}
# 132  {'pokemon': 'Togekiss', 'percent': '28.574', 'types': ['fairy', 'flying']}
# 133  {'pokemon': 'Arcanine', 'percent': '44.462', 'types': ['fire']}
# 134  {'pokemon': 'Vanilluxe', 'percent': '69.618', 'types': ['ice']}
# 135  {'pokemon': 'Dusclops', 'percent': '28.440', 'types': ['ghost']}
# 136  {'pokemon': 'Gyarados', 'percent': '22.761', 'types': ['water', 'flying']}
# 137  {'pokemon': 'Dragapult', 'percent': '32.698', 'types': ['dragon', 'ghost']}
# 138  {'pokemon': 'Indeedee', 'percent': '41.631', 'types': ['psychic', 'normal']}
# 139  {'pokemon': 'Gyarados', 'percent': '60.636', 'types': ['water', 'flying']}
# 140  {'pokemon': 'Whimsicott', 'percent': '83.791', 'types': ['grass', 'fairy']}
# 141  {'pokemon': 'Dragapult', 'percent': '39.055', 'types': ['dragon', 'ghost']}
# 142  {'pokemon': 'Indeedee-F', 'percent': '37.366', 'types': ['psychic', 'normal']}
# 143  {'pokemon': 'Whimsicott', 'percent': '68.239', 'types': ['grass', 'fairy']}
# 144  {'pokemon': 'Whimsicott', 'percent': '42.848', 'types': ['grass', 'fairy']}
# 145  {'pokemon': 'Excadrill', 'percent': '34.020', 'types': ['ground', 'steel']}
# 146  {'pokemon': 'Duraludon', 'percent': '51.330', 'types': ['steel', 'dragon']}
# 147  {'pokemon': 'Gastrodon', 'percent': '58.813', 'types': ['water', 'ground']}
# 148  {'pokemon': 'Arcanine', 'percent': '48.605', 'types': ['fire']}
# 149  {'pokemon': 'Pelipper', 'percent': '36.645', 'types': ['water', 'flying']}
# 150  {'pokemon': 'Jellicent', 'percent': '52.315', 'types': ['water', 'ghost']}
# 151  {'pokemon': 'Arcanine', 'percent': '45.030', 'types': ['fire']}
# 152  {'pokemon': 'Togekiss', 'percent': '22.919', 'types': ['fairy', 'flying']}
# 153  {'pokemon': 'Dusclops', 'percent': '33.945', 'types': ['ghost']}
# 154  {'pokemon': 'Torkoal', 'percent': '52.832', 'types': ['fire']}
# 155  {'pokemon': 'Togekiss', 'percent': '83.775', 'types': ['fairy', 'flying']}
# 156  {'pokemon': 'Arcanine', 'percent': '41.581', 'types': ['fire']}
# 157  {'pokemon': 'Lapras', 'percent': '87.893', 'types': ['water', 'ice']}
# 158  {'pokemon': 'Centiskorch', 'percent': '28.901', 'types': ['fire', 'bug']}
# 159  {'pokemon': 'Arcanine', 'percent': '32.689', 'types': ['fire']}
# 160  {'pokemon': 'Dragapult', 'percent': '58.310', 'types': ['dragon', 'ghost']}
# 161  {'pokemon': 'Duraludon', 'percent': '83.037', 'types': ['steel', 'dragon']}
# 162  {'pokemon': 'Mimikyu', 'percent': '53.694', 'types': ['ghost', 'fairy']}
# 163  {'pokemon': 'Arcanine', 'percent': '81.690', 'types': ['fire']}
# 164  {'pokemon': 'Togekiss', 'percent': '65.219', 'types': ['fairy', 'flying']}
# 165  {'pokemon': 'Pelipper', 'percent': '20.641', 'types': ['water', 'flying']}
# 166  {'pokemon': 'Arcanine', 'percent': '40.386', 'types': ['fire']}
# 167  {'pokemon': 'Arcanine', 'percent': '42.692', 'types': ['fire']}
# 168  {'pokemon': 'Gothitelle', 'percent': '42.717', 'types': ['psychic']}
# 169  {'pokemon': 'Togekiss', 'percent': '37.269', 'types': ['fairy', 'flying']}
# 170  {'pokemon': 'Torkoal', 'percent': '45.823', 'types': ['fire']}
# 171  {'pokemon': 'Dragapult', 'percent': '67.765', 'types': ['dragon', 'ghost']}
# 172  {'pokemon': 'Togekiss', 'percent': '35.326', 'types': ['fairy', 'flying']}
# 173  {'pokemon': 'Torkoal', 'percent': '30.255', 'types': ['fire']}
# 174  {'pokemon': 'Indeedee-F', 'percent': '41.527', 'types': ['psychic', 'normal']}
# 175  {'pokemon': 'Rhyperior', 'percent': '58.215', 'types': ['ground', 'rock']}
# 176  {'pokemon': 'Hatterene', 'percent': '42.797', 'types': ['psychic', 'fairy']}
# 177  {'pokemon': 'Gastrodon', 'percent': '27.229', 'types': ['water', 'ground']}
# 178  {'pokemon': 'Togekiss', 'percent': '87.737', 'types': ['fairy', 'flying']}
# 179  {'pokemon': 'Braviary', 'percent': '31.890', 'types': ['normal', 'flying']}
# 180  {'pokemon': 'Dragapult', 'percent': '80.779', 'types': ['dragon', 'ghost']}
# 181  {'pokemon': 'Togekiss', 'percent': '56.984', 'types': ['fairy', 'flying']}
# 182  {'pokemon': 'Conkeldurr', 'percent': '83.450', 'types': ['fighting']}
# 183  {'pokemon': 'Duraludon', 'percent': '38.999', 'types': ['steel', 'dragon']}
# 184  {'pokemon': 'Rhyperior', 'percent': '86.611', 'types': ['ground', 'rock']}
# 185  {'pokemon': 'Arcanine', 'percent': '84.581', 'types': ['fire']}
# 186  {'pokemon': 'Dragapult', 'percent': '27.172', 'types': ['dragon', 'ghost']}
# 187  {'pokemon': 'Whimsicott', 'percent': '43.638', 'types': ['grass', 'fairy']}
# 188  {'pokemon': 'Togekiss', 'percent': '59.752', 'types': ['fairy', 'flying']}
# 189  {'pokemon': 'Conkeldurr', 'percent': '43.138', 'types': ['fighting']}
# 190  {'pokemon': 'Torkoal', 'percent': '49.722', 'types': ['fire']}
# 191  {'pokemon': 'Ferrothorn', 'percent': '33.115', 'types': ['grass', 'steel']}
# 192  {'pokemon': 'Dracovish', 'percent': '52.796', 'types': ['water', 'dragon']}
# 193  {'pokemon': 'Duraludon', 'percent': '46.297', 'types': ['steel', 'dragon']}
# 194  {'pokemon': 'Snorlax', 'percent': '39.298', 'types': ['normal']}
# 195  {'pokemon': 'Togekiss', 'percent': '77.812', 'types': ['fairy', 'flying']}
# 196  {'pokemon': 'Togekiss', 'percent': '76.368', 'types': ['fairy', 'flying']}
# 197  {'pokemon': 'Torkoal', 'percent': '61.740', 'types': ['fire']}
# 198  {'pokemon': 'Dragapult', 'percent': '47.398', 'types': ['dragon', 'ghost']}
# 199  {'pokemon': 'Togekiss', 'percent': '27.743', 'types': ['fairy', 'flying']}
# 200  {'pokemon': 'Whimsicott', 'percent': '59.129', 'types': ['grass', 'fairy']}
# 201  {'pokemon': 'Arcanine', 'percent': '46.083', 'types': ['fire']}
# 202  {'pokemon': 'Dragapult', 'percent': '94.146', 'types': ['dragon', 'ghost']}
# 203  {'pokemon': 'Togekiss', 'percent': '84.962', 'types': ['fairy', 'flying']}
# 204  {'pokemon': 'Coalossal', 'percent': '61.287', 'types': ['rock', 'fire']}
# 205  {'pokemon': 'Sylveon', 'percent': '33.475', 'types': ['fairy']}
# 206  {'pokemon': 'Torkoal', 'percent': '39.928', 'types': ['fire']}
# 207  {'pokemon': 'Lapras', 'percent': '66.941', 'types': ['water', 'ice']}
# 208  {'pokemon': 'Whimsicott', 'percent': '57.042', 'types': ['grass', 'fairy']}
# 209  {'pokemon': 'Excadrill', 'percent': '31.745', 'types': ['ground', 'steel']}
# 210  {'pokemon': 'Duraludon', 'percent': '51.458', 'types': ['steel', 'dragon']}
# 211  {'pokemon': 'Dragapult', 'percent': '76.466', 'types': ['dragon', 'ghost']}
# 212  {'pokemon': 'Togekiss', 'percent': '30.509', 'types': ['fairy', 'flying']}
# 213  {'pokemon': 'Mudsdale', 'percent': '66.228', 'types': ['ground']}
# 214  {'pokemon': 'Hitmontop', 'percent': '72.267', 'types': ['fighting']}
# 215  {'pokemon': 'Arcanine', 'percent': '33.759', 'types': ['fire']}
# 216  {'pokemon': 'Rhyperior', 'percent': '35.587', 'types': ['ground', 'rock']}
# 217  {'pokemon': 'Togekiss', 'percent': '74.216', 'types': ['fairy', 'flying']}
# 218  {'pokemon': 'Duraludon', 'percent': '47.588', 'types': ['steel', 'dragon']}
# 219  {'pokemon': 'Torkoal', 'percent': '75.838', 'types': ['fire']}
# 220  {'pokemon': 'Excadrill', 'percent': '68.691', 'types': ['ground', 'steel']}
# 221  {'pokemon': 'Gyarados', 'percent': '59.921', 'types': ['water', 'flying']}
# 222  {'pokemon': 'Indeedee-F', 'percent': '95.882', 'types': ['psychic', 'normal']}
# 223  {'pokemon': 'Lapras', 'percent': '66.298', 'types': ['water', 'ice']}
#
#                                                                                    1  \
# 0    {'pokemon': 'Arcanine', 'percent': '35.593', 'types': ['fire']}
# 1    {'pokemon': 'Dragapult', 'percent': '30.663', 'types': ['dragon', 'ghost']}
# 2    {'pokemon': 'Excadrill', 'percent': '38.133', 'types': ['ground', 'steel']}
# 3    {'pokemon': 'Tyranitar', 'percent': '47.122', 'types': ['rock', 'dark']}
# 4    {'pokemon': 'Togekiss', 'percent': '32.431', 'types': ['fairy', 'flying']}
# 5    {'pokemon': 'Arcanine', 'percent': '39.353', 'types': ['fire']}
# 6    {'pokemon': 'Togekiss', 'percent': '50.508', 'types': ['fairy', 'flying']}
# 7    {'pokemon': 'Duraludon', 'percent': '38.183', 'types': ['steel', 'dragon']}
# 8    {'pokemon': 'Excadrill', 'percent': '35.918', 'types': ['ground', 'steel']}
# 9    {'pokemon': 'Togekiss', 'percent': '40.461', 'types': ['fairy', 'flying']}
# 10   {'pokemon': 'Dusclops', 'percent': '38.673', 'types': ['ghost']}
# 11   {'pokemon': 'Whimsicott', 'percent': '39.141', 'types': ['grass', 'fairy']}
# 12   {'pokemon': 'Togekiss', 'percent': '45.143', 'types': ['fairy', 'flying']}
# 13   {'pokemon': 'Arcanine', 'percent': '31.293', 'types': ['fire']}
# 14   {'pokemon': 'Torkoal', 'percent': '48.417', 'types': ['fire']}
# 15   {'pokemon': 'Whimsicott', 'percent': '42.164', 'types': ['grass', 'fairy']}
# 16   {'pokemon': 'Inteleon', 'percent': '48.180', 'types': ['water']}
# 17   {'pokemon': 'Togekiss', 'percent': '45.495', 'types': ['fairy', 'flying']}
# 18   {'pokemon': 'Dusclops', 'percent': '57.543', 'types': ['ghost']}
# 19   {'pokemon': 'Whimsicott', 'percent': '53.689', 'types': ['grass', 'fairy']}
# 20   {'pokemon': 'Duraludon', 'percent': '31.739', 'types': ['steel', 'dragon']}
# 21   {'pokemon': 'Gastrodon', 'percent': '27.891', 'types': ['water', 'ground']}
# 22   {'pokemon': 'Whimsicott', 'percent': '35.197', 'types': ['grass', 'fairy']}
# 23   {'pokemon': 'Dragapult', 'percent': '33.780', 'types': ['dragon', 'ghost']}
# 24   {'pokemon': 'Conkeldurr', 'percent': '39.889', 'types': ['fighting']}
# 25   {'pokemon': 'Inteleon', 'percent': '44.006', 'types': ['water']}
# 26   {'pokemon': 'Arcanine', 'percent': '34.530', 'types': ['fire']}
# 27   {'pokemon': 'Mimikyu', 'percent': '36.206', 'types': ['ghost', 'fairy']}
# 28   {'pokemon': 'Duraludon', 'percent': '36.505', 'types': ['steel', 'dragon']}
# 29   {'pokemon': 'Rhyperior', 'percent': '25.545', 'types': ['ground', 'rock']}
# 30   {'pokemon': 'Grimmsnarl', 'percent': '42.508', 'types': ['dark', 'fairy']}
# 31   {'pokemon': 'Gastrodon', 'percent': '35.095', 'types': ['water', 'ground']}
# 32   {'pokemon': 'Whimsicott', 'percent': '40.718', 'types': ['grass', 'fairy']}
# 33   {'pokemon': 'Dragapult', 'percent': '32.479', 'types': ['dragon', 'ghost']}
# 34   {'pokemon': 'Rhyperior', 'percent': '38.361', 'types': ['ground', 'rock']}
# 35   {'pokemon': 'Togekiss', 'percent': '62.521', 'types': ['fairy', 'flying']}
# 36   {'pokemon': 'Dragapult', 'percent': '36.175', 'types': ['dragon', 'ghost']}
# 37   {'pokemon': 'Togekiss', 'percent': '26.399', 'types': ['fairy', 'flying']}
# 38   {'pokemon': 'Torkoal', 'percent': '47.937', 'types': ['fire']}
# 39   {'pokemon': 'Excadrill', 'percent': '42.561', 'types': ['ground', 'steel']}
# 40   {'pokemon': 'Indeedee-F', 'percent': '37.958', 'types': ['psychic', 'normal']}
# 41   {'pokemon': 'Hydreigon', 'percent': '66.854', 'types': ['dark', 'dragon']}
# 42   {'pokemon': 'Gothitelle', 'percent': '33.598', 'types': ['psychic']}
# 43   {'pokemon': 'Togekiss', 'percent': '34.431', 'types': ['fairy', 'flying']}
# 44   {'pokemon': 'Togekiss', 'percent': '44.241', 'types': ['fairy', 'flying']}
# 45   {'pokemon': 'Whimsicott', 'percent': '42.738', 'types': ['grass', 'fairy']}
# 46   {'pokemon': 'Togekiss', 'percent': '46.204', 'types': ['fairy', 'flying']}
# 47   {'pokemon': 'Dragapult', 'percent': '41.809', 'types': ['dragon', 'ghost']}
# 48   {'pokemon': 'Dragapult', 'percent': '38.860', 'types': ['dragon', 'ghost']}
# 49   {'pokemon': 'Rhyperior', 'percent': '53.633', 'types': ['ground', 'rock']}
# 50   {'pokemon': 'Excadrill', 'percent': '22.596', 'types': ['ground', 'steel']}
# 51   {'pokemon': 'Excadrill', 'percent': '36.923', 'types': ['ground', 'steel']}
# 52   {'pokemon': 'Dragapult', 'percent': '23.809', 'types': ['dragon', 'ghost']}
# 53   {'pokemon': 'Togekiss', 'percent': '68.447', 'types': ['fairy', 'flying']}
# 54   {'pokemon': 'Arcanine', 'percent': '34.431', 'types': ['fire']}
# 55   {'pokemon': 'Rhyperior', 'percent': '42.255', 'types': ['ground', 'rock']}
# 56   {'pokemon': 'Arcanine', 'percent': '45.872', 'types': ['fire']}
# 57   {'pokemon': 'Togekiss', 'percent': '44.881', 'types': ['fairy', 'flying']}
# 58   {'pokemon': 'Excadrill', 'percent': '39.327', 'types': ['ground', 'steel']}
# 59   {'pokemon': 'Arcanine', 'percent': '36.905', 'types': ['fire']}
# 60   {'pokemon': 'Duraludon', 'percent': '24.280', 'types': ['steel', 'dragon']}
# 61   {'pokemon': 'Duraludon', 'percent': '48.483', 'types': ['steel', 'dragon']}
# 62   {'pokemon': 'Sylveon', 'percent': '64.159', 'types': ['fairy']}
# 63   {'pokemon': 'Dragapult', 'percent': '29.483', 'types': ['dragon', 'ghost']}
# 64   {'pokemon': 'Togekiss', 'percent': '32.629', 'types': ['fairy', 'flying']}
# 65   {'pokemon': 'Arcanine', 'percent': '24.487', 'types': ['fire']}
# 66   {'pokemon': 'Inteleon', 'percent': '41.141', 'types': ['water']}
# 67   {'pokemon': 'Corviknight', 'percent': '48.297', 'types': ['flying', 'steel']}
# 68   {'pokemon': 'Whimsicott', 'percent': '27.206', 'types': ['grass', 'fairy']}
# 69   {'pokemon': 'Tyranitar', 'percent': '39.506', 'types': ['rock', 'dark']}
# 70   {'pokemon': 'Rotom-Mow', 'percent': '34.292', 'types': ['electric', 'grass']}
# 71   {'pokemon': 'Tyranitar', 'percent': '61.219', 'types': ['rock', 'dark']}
# 72   {'pokemon': 'Togekiss', 'percent': '30.545', 'types': ['fairy', 'flying']}
# 73   {'pokemon': 'Arcanine', 'percent': '41.224', 'types': ['fire']}
# 74   {'pokemon': 'Dusclops', 'percent': '19.756', 'types': ['ghost']}
# 75   {'pokemon': 'Grimmsnarl', 'percent': '38.222', 'types': ['dark', 'fairy']}
# 76   {'pokemon': 'Dusclops', 'percent': '40.981', 'types': ['ghost']}
# 77   {'pokemon': 'Excadrill', 'percent': '71.582', 'types': ['ground', 'steel']}
# 78   {'pokemon': 'Gothitelle', 'percent': '51.293', 'types': ['psychic']}
# 79   {'pokemon': 'Mimikyu', 'percent': '35.216', 'types': ['ghost', 'fairy']}
# 80   {'pokemon': 'Togekiss', 'percent': '28.600', 'types': ['fairy', 'flying']}
# 81   {'pokemon': 'Charizard', 'percent': '40.433', 'types': ['fire', 'flying']}
# 82   {'pokemon': 'Dusclops', 'percent': '31.146', 'types': ['ghost']}
# 83   {'pokemon': 'Grimmsnarl', 'percent': '54.511', 'types': ['dark', 'fairy']}
# 84   {'pokemon': 'Gastrodon', 'percent': '37.053', 'types': ['water', 'ground']}
# 85   {'pokemon': 'Arcanine', 'percent': '45.898', 'types': ['fire']}
# 86   {'pokemon': 'Ludicolo', 'percent': '39.683', 'types': ['water', 'grass']}
# 87   {'pokemon': 'Snorlax', 'percent': '80.507', 'types': ['normal']}
# 88   {'pokemon': 'Conkeldurr', 'percent': '41.812', 'types': ['fighting']}
# 89   {'pokemon': 'Charizard', 'percent': '35.621', 'types': ['fire', 'flying']}
# 90   {'pokemon': 'Duraludon', 'percent': '27.203', 'types': ['steel', 'dragon']}
# 91   {'pokemon': 'Arcanine', 'percent': '45.296', 'types': ['fire']}
# 92   {'pokemon': 'Excadrill', 'percent': '28.469', 'types': ['ground', 'steel']}
# 93   {'pokemon': 'Dracovish', 'percent': '37.198', 'types': ['water', 'dragon']}
# 94   {'pokemon': 'Scrafty', 'percent': '22.822', 'types': ['dark', 'fighting']}
# 95   {'pokemon': 'Dragapult', 'percent': '25.889', 'types': ['dragon', 'ghost']}
# 96   {'pokemon': 'Durant', 'percent': '45.927', 'types': ['bug', 'steel']}
# 97   {'pokemon': 'Rhyperior', 'percent': '35.948', 'types': ['ground', 'rock']}
# 98   {'pokemon': 'Duraludon', 'percent': '24.301', 'types': ['steel', 'dragon']}
# 99   {'pokemon': 'Duraludon', 'percent': '87.744', 'types': ['steel', 'dragon']}
# 100  {'pokemon': 'Grimmsnarl', 'percent': '25.181', 'types': ['dark', 'fairy']}
# 101  {'pokemon': 'Arcanine', 'percent': '28.305', 'types': ['fire']}
# 102  {'pokemon': 'Gyarados', 'percent': '38.473', 'types': ['water', 'flying']}
# 103  {'pokemon': 'Dusclops', 'percent': '24.370', 'types': ['ghost']}
# 104  {'pokemon': 'Tyranitar', 'percent': '74.352', 'types': ['rock', 'dark']}
# 105  {'pokemon': 'Coalossal', 'percent': '45.540', 'types': ['rock', 'fire']}
# 106  {'pokemon': 'Arcanine', 'percent': '48.487', 'types': ['fire']}
# 107  {'pokemon': 'Indeedee-F', 'percent': '28.849', 'types': ['psychic', 'normal']}
# 108  {'pokemon': 'Grimmsnarl', 'percent': '36.885', 'types': ['dark', 'fairy']}
# 109  {'pokemon': 'Excadrill', 'percent': '33.358', 'types': ['ground', 'steel']}
# 110  {'pokemon': 'Dusclops', 'percent': '20.934', 'types': ['ghost']}
# 111  {'pokemon': 'Whimsicott', 'percent': '25.360', 'types': ['grass', 'fairy']}
# 112  {'pokemon': 'Excadrill', 'percent': '28.168', 'types': ['ground', 'steel']}
# 113  {'pokemon': 'Rhyperior', 'percent': '27.847', 'types': ['ground', 'rock']}
# 114  {'pokemon': 'Dragapult', 'percent': '25.002', 'types': ['dragon', 'ghost']}
# 115  {'pokemon': 'Hatterene', 'percent': '22.509', 'types': ['psychic', 'fairy']}
# 116  {'pokemon': 'Togekiss', 'percent': '25.403', 'types': ['fairy', 'flying']}
# 117  {'pokemon': 'Torkoal', 'percent': '24.216', 'types': ['fire']}
# 118  {'pokemon': 'Dragapult', 'percent': '51.529', 'types': ['dragon', 'ghost']}
# 119  {'pokemon': 'Charizard', 'percent': '24.651', 'types': ['fire', 'flying']}
# 120  {'pokemon': 'Charizard', 'percent': '63.547', 'types': ['fire', 'flying']}
# 121  {'pokemon': 'Duraludon', 'percent': '22.794', 'types': ['steel', 'dragon']}
# 122  {'pokemon': 'Excadrill', 'percent': '40.550', 'types': ['ground', 'steel']}
# 123  {'pokemon': 'Excadrill', 'percent': '35.079', 'types': ['ground', 'steel']}
# 124  {'pokemon': 'Torkoal', 'percent': '29.855', 'types': ['fire']}
# 125  {'pokemon': 'Excadrill', 'percent': '41.236', 'types': ['ground', 'steel']}
# 126  {'pokemon': 'Ludicolo', 'percent': '31.954', 'types': ['water', 'grass']}
# 127  {'pokemon': 'Togekiss', 'percent': '70.877', 'types': ['fairy', 'flying']}
# 128  {'pokemon': 'Arcanine', 'percent': '51.026', 'types': ['fire']}
# 129  {'pokemon': 'Excadrill', 'percent': '45.977', 'types': ['ground', 'steel']}
# 130  {'pokemon': 'Duraludon', 'percent': '23.481', 'types': ['steel', 'dragon']}
# 131  {'pokemon': 'Snorlax', 'percent': '31.142', 'types': ['normal']}
# 132  {'pokemon': 'Arcanine', 'percent': '24.636', 'types': ['fire']}
# 133  {'pokemon': 'Togekiss', 'percent': '40.362', 'types': ['fairy', 'flying']}
# 134  {'pokemon': 'Arcanine', 'percent': '32.732', 'types': ['fire']}
# 135  {'pokemon': 'Dragapult', 'percent': '27.039', 'types': ['dragon', 'ghost']}
# 136  {'pokemon': 'Togekiss', 'percent': '21.849', 'types': ['fairy', 'flying']}
# 137  {'pokemon': 'Togekiss', 'percent': '26.660', 'types': ['fairy', 'flying']}
# 138  {'pokemon': 'Rhyperior', 'percent': '36.563', 'types': ['ground', 'rock']}
# 139  {'pokemon': 'Excadrill', 'percent': '39.873', 'types': ['ground', 'steel']}
# 140  {'pokemon': 'Togekiss', 'percent': '66.008', 'types': ['fairy', 'flying']}
# 141  {'pokemon': 'Arcanine', 'percent': '38.600', 'types': ['fire']}
# 142  {'pokemon': 'Gyarados', 'percent': '31.225', 'types': ['water', 'flying']}
# 143  {'pokemon': 'Togekiss', 'percent': '66.790', 'types': ['fairy', 'flying']}
# 144  {'pokemon': 'Arcanine', 'percent': '38.727', 'types': ['fire']}
# 145  {'pokemon': 'Dragapult', 'percent': '25.990', 'types': ['dragon', 'ghost']}
# 146  {'pokemon': 'Gyarados', 'percent': '51.277', 'types': ['water', 'flying']}
# 147  {'pokemon': 'Arcanine', 'percent': '25.954', 'types': ['fire']}
# 148  {'pokemon': 'Reuniclus', 'percent': '44.529', 'types': ['psychic']}
# 149  {'pokemon': 'Togekiss', 'percent': '35.840', 'types': ['fairy', 'flying']}
# 150  {'pokemon': 'Arcanine', 'percent': '38.278', 'types': ['fire']}
# 151  {'pokemon': 'Dracovish', 'percent': '43.038', 'types': ['water', 'dragon']}
# 152  {'pokemon': 'Arcanine', 'percent': '21.600', 'types': ['fire']}
# 153  {'pokemon': 'Torkoal', 'percent': '28.816', 'types': ['fire']}
# 154  {'pokemon': 'Leafeon', 'percent': '44.201', 'types': ['grass']}
# 155  {'pokemon': 'Dracovish', 'percent': '54.770', 'types': ['water', 'dragon']}
# 156  {'pokemon': 'Togekiss', 'percent': '40.340', 'types': ['fairy', 'flying']}
# 157  {'pokemon': 'Gothitelle', 'percent': '79.227', 'types': ['psychic']}
# 158  {'pokemon': 'Gastrodon', 'percent': '28.628', 'types': ['water', 'ground']}
# 159  {'pokemon': 'Whimsicott', 'percent': '30.347', 'types': ['grass', 'fairy']}
# 160  {'pokemon': 'Corviknight', 'percent': '55.158', 'types': ['flying', 'steel']}
# 161  {'pokemon': 'Gothitelle', 'percent': '78.277', 'types': ['psychic']}
# 162  {'pokemon': 'Indeedee', 'percent': '49.725', 'types': ['psychic', 'normal']}
# 163  {'pokemon': 'Excadrill', 'percent': '81.689', 'types': ['ground', 'steel']}
# 164  {'pokemon': 'Whimsicott', 'percent': '46.124', 'types': ['grass', 'fairy']}
# 165  {'pokemon': 'Whimsicott', 'percent': '19.798', 'types': ['grass', 'fairy']}
# 166  {'pokemon': 'Gastrodon', 'percent': '35.327', 'types': ['water', 'ground']}
# 167  {'pokemon': 'Togekiss', 'percent': '37.003', 'types': ['fairy', 'flying']}
# 168  {'pokemon': 'Dragapult', 'percent': '40.421', 'types': ['dragon', 'ghost']}
# 169  {'pokemon': 'Duraludon', 'percent': '26.334', 'types': ['steel', 'dragon']}
# 170  {'pokemon': 'Togekiss', 'percent': '23.151', 'types': ['fairy', 'flying']}
# 171  {'pokemon': 'Excadrill', 'percent': '67.540', 'types': ['ground', 'steel']}
# 172  {'pokemon': 'Dragapult', 'percent': '30.611', 'types': ['dragon', 'ghost']}
# 173  {'pokemon': 'Chandelure', 'percent': '20.411', 'types': ['ghost', 'fire']}
# 174  {'pokemon': 'Duraludon', 'percent': '37.000', 'types': ['steel', 'dragon']}
# 175  {'pokemon': 'Togekiss', 'percent': '25.110', 'types': ['fairy', 'flying']}
# 176  {'pokemon': 'Rhyperior', 'percent': '37.229', 'types': ['ground', 'rock']}
# 177  {'pokemon': 'Arcanine', 'percent': '22.877', 'types': ['fire']}
# 178  {'pokemon': 'Whimsicott', 'percent': '73.745', 'types': ['grass', 'fairy']}
# 179  {'pokemon': 'Togekiss', 'percent': '27.768', 'types': ['fairy', 'flying']}
# 180  {'pokemon': 'Excadrill', 'percent': '76.504', 'types': ['ground', 'steel']}
# 181  {'pokemon': 'Mimikyu', 'percent': '52.967', 'types': ['ghost', 'fairy']}
# 182  {'pokemon': 'Grimmsnarl', 'percent': '73.035', 'types': ['dark', 'fairy']}
# 183  {'pokemon': 'Togekiss', 'percent': '34.020', 'types': ['fairy', 'flying']}
# 184  {'pokemon': 'Dusclops', 'percent': '85.022', 'types': ['ghost']}
# 185  {'pokemon': 'Tyranitar', 'percent': '77.035', 'types': ['rock', 'dark']}
# 186  {'pokemon': 'Gyarados', 'percent': '23.560', 'types': ['water', 'flying']}
# 187  {'pokemon': 'Excadrill', 'percent': '35.332', 'types': ['ground', 'steel']}
# 188  {'pokemon': 'Arcanine', 'percent': '41.452', 'types': ['fire']}
# 189  {'pokemon': 'Arcanine', 'percent': '42.918', 'types': ['fire']}
# 190  {'pokemon': 'Hatterene', 'percent': '39.934', 'types': ['psychic', 'fairy']}
# 191  {'pokemon': 'Conkeldurr', 'percent': '32.387', 'types': ['fighting']}
# 192  {'pokemon': 'Hatterene', 'percent': '50.227', 'types': ['psychic', 'fairy']}
# 193  {'pokemon': 'Rhyperior', 'percent': '44.053', 'types': ['ground', 'rock']}
# 194  {'pokemon': 'Indeedee-F', 'percent': '37.057', 'types': ['psychic', 'normal']}
# 195  {'pokemon': 'Chandelure', 'percent': '77.702', 'types': ['ghost', 'fire']}
# 196  {'pokemon': 'Arcanine', 'percent': '65.426', 'types': ['fire']}
# 197  {'pokemon': 'Togekiss', 'percent': '22.807', 'types': ['fairy', 'flying']}
# 198  {'pokemon': 'Togekiss', 'percent': '36.601', 'types': ['fairy', 'flying']}
# 199  {'pokemon': 'Excadrill', 'percent': '21.239', 'types': ['ground', 'steel']}
# 200  {'pokemon': 'Gastrodon', 'percent': '39.913', 'types': ['water', 'ground']}
# 201  {'pokemon': 'Hatterene', 'percent': '41.872', 'types': ['psychic', 'fairy']}
# 202  {'pokemon': 'Togekiss', 'percent': '94.146', 'types': ['fairy', 'flying']}
# 203  {'pokemon': 'Dragapult', 'percent': '81.917', 'types': ['dragon', 'ghost']}
# 204  {'pokemon': 'Arcanine', 'percent': '50.120', 'types': ['fire']}
# 205  {'pokemon': 'Espeon', 'percent': '32.412', 'types': ['psychic']}
# 206  {'pokemon': 'Jellicent', 'percent': '29.899', 'types': ['water', 'ghost']}
# 207  {'pokemon': 'Gothitelle', 'percent': '54.601', 'types': ['psychic']}
# 208  {'pokemon': 'Rotom-Heat', 'percent': '37.418', 'types': ['electric', 'fire']}
# 209  {'pokemon': 'Toxtricity', 'percent': '23.958', 'types': ['electric', 'poison']}
# 210  {'pokemon': 'Hitmontop', 'percent': '49.334', 'types': ['fighting']}
# 211  {'pokemon': 'Mr. Mime-Galar', 'percent': '76.434', 'types': ['ice', 'psychic']}
# 212  {'pokemon': 'Arcanine', 'percent': '29.158', 'types': ['fire']}
# 213  {'pokemon': 'Jellicent', 'percent': '59.186', 'types': ['water', 'ghost']}
# 214  {'pokemon': 'Togekiss', 'percent': '63.908', 'types': ['fairy', 'flying']}
# 215  {'pokemon': 'Dusclops', 'percent': '27.921', 'types': ['ghost']}
# 216  {'pokemon': 'Gastrodon', 'percent': '33.236', 'types': ['water', 'ground']}
# 217  {'pokemon': 'Inteleon', 'percent': '71.626', 'types': ['water']}
# 218  {'pokemon': 'Togekiss', 'percent': '36.563', 'types': ['fairy', 'flying']}
# 219  {'pokemon': 'Obstagoon', 'percent': '68.307', 'types': ['dark', 'normal']}
# 220  {'pokemon': 'Vanilluxe', 'percent': '51.546', 'types': ['ice']}
# 221  {'pokemon': 'Arcanine', 'percent': '59.832', 'types': ['fire']}
# 222  {'pokemon': 'Rhyperior', 'percent': '95.882', 'types': ['ground', 'rock']}
# 223  {'pokemon': 'Gothitelle', 'percent': '51.576', 'types': ['psychic']}
#
#                                                                                    2
# 0    {'pokemon': 'Dragapult', 'percent': '33.117', 'types': ['dragon', 'ghost']}
# 1    {'pokemon': 'Tyranitar', 'percent': '28.847', 'types': ['rock', 'dark']}
# 2    {'pokemon': 'Arcanine', 'percent': '34.788', 'types': ['fire']}
# 3    {'pokemon': 'Dragapult', 'percent': '40.479', 'types': ['dragon', 'ghost']}
# 4    {'pokemon': 'Arcanine', 'percent': '25.983', 'types': ['fire']}
# 5    {'pokemon': 'Grimmsnarl', 'percent': '31.799', 'types': ['dark', 'fairy']}
# 6    {'pokemon': 'Arcanine', 'percent': '45.056', 'types': ['fire']}
# 7    {'pokemon': 'Togekiss', 'percent': '32.534', 'types': ['fairy', 'flying']}
# 8    {'pokemon': 'Dragapult', 'percent': '31.131', 'types': ['dragon', 'ghost']}
# 9    {'pokemon': 'Tyranitar', 'percent': '36.848', 'types': ['rock', 'dark']}
# 10   {'pokemon': 'Torkoal', 'percent': '35.043', 'types': ['fire']}
# 11   {'pokemon': 'Duraludon', 'percent': '25.543', 'types': ['steel', 'dragon']}
# 12   {'pokemon': 'Tyranitar', 'percent': '44.904', 'types': ['rock', 'dark']}
# 13   {'pokemon': 'Dragapult', 'percent': '29.082', 'types': ['dragon', 'ghost']}
# 14   {'pokemon': 'Togekiss', 'percent': '40.985', 'types': ['fairy', 'flying']}
# 15   {'pokemon': 'Arcanine', 'percent': '39.854', 'types': ['fire']}
# 16   {'pokemon': 'Conkeldurr', 'percent': '32.418', 'types': ['fighting']}
# 17   {'pokemon': 'Dragapult', 'percent': '40.349', 'types': ['dragon', 'ghost']}
# 18   {'pokemon': 'Togekiss', 'percent': '27.286', 'types': ['fairy', 'flying']}
# 19   {'pokemon': 'Hydreigon', 'percent': '32.593', 'types': ['dark', 'dragon']}
# 20   {'pokemon': 'Togekiss', 'percent': '30.772', 'types': ['fairy', 'flying']}
# 21   {'pokemon': 'Dragapult', 'percent': '27.422', 'types': ['dragon', 'ghost']}
# 22   {'pokemon': 'Conkeldurr', 'percent': '32.981', 'types': ['fighting']}
# 23   {'pokemon': 'Gastrodon', 'percent': '33.488', 'types': ['water', 'ground']}
# 24   {'pokemon': 'Whimsicott', 'percent': '37.117', 'types': ['grass', 'fairy']}
# 25   {'pokemon': 'Vanilluxe', 'percent': '39.266', 'types': ['ice']}
# 26   {'pokemon': 'Excadrill', 'percent': '33.391', 'types': ['ground', 'steel']}
# 27   {'pokemon': 'Tyranitar', 'percent': '32.227', 'types': ['rock', 'dark']}
# 28   {'pokemon': 'Togekiss', 'percent': '29.992', 'types': ['fairy', 'flying']}
# 29   {'pokemon': 'Hatterene', 'percent': '23.752', 'types': ['psychic', 'fairy']}
# 30   {'pokemon': 'Togekiss', 'percent': '40.131', 'types': ['fairy', 'flying']}
# 31   {'pokemon': 'Dragapult', 'percent': '33.036', 'types': ['dragon', 'ghost']}
# 32   {'pokemon': 'Arcanine', 'percent': '38.067', 'types': ['fire']}
# 33   {'pokemon': 'Rotom-Wash', 'percent': '25.520', 'types': ['electric', 'water']}
# 34   {'pokemon': 'Arcanine', 'percent': '32.929', 'types': ['fire']}
# 35   {'pokemon': 'Dragapult', 'percent': '53.674', 'types': ['dragon', 'ghost']}
# 36   {'pokemon': 'Togekiss', 'percent': '35.395', 'types': ['fairy', 'flying']}
# 37   {'pokemon': 'Duraludon', 'percent': '21.109', 'types': ['steel', 'dragon']}
# 38   {'pokemon': 'Dusclops', 'percent': '41.415', 'types': ['ghost']}
# 39   {'pokemon': 'Tyranitar', 'percent': '27.487', 'types': ['rock', 'dark']}
# 40   {'pokemon': 'Rhyperior', 'percent': '34.441', 'types': ['ground', 'rock']}
# 41   {'pokemon': 'Inteleon', 'percent': '66.049', 'types': ['water']}
# 42   {'pokemon': 'Arcanine', 'percent': '32.433', 'types': ['fire']}
# 43   {'pokemon': 'Dragapult', 'percent': '28.024', 'types': ['dragon', 'ghost']}
# 44   {'pokemon': 'Dragapult', 'percent': '34.451', 'types': ['dragon', 'ghost']}
# 45   {'pokemon': 'Gyarados', 'percent': '33.590', 'types': ['water', 'flying']}
# 46   {'pokemon': 'Duraludon', 'percent': '28.342', 'types': ['steel', 'dragon']}
# 47   {'pokemon': 'Vanilluxe', 'percent': '38.897', 'types': ['ice']}
# 48   {'pokemon': 'Rotom-Wash', 'percent': '33.435', 'types': ['electric', 'water']}
# 49   {'pokemon': 'Dusclops', 'percent': '53.444', 'types': ['ghost']}
# 50   {'pokemon': 'Arcanine', 'percent': '20.666', 'types': ['fire']}
# 51   {'pokemon': 'Whimsicott', 'percent': '26.244', 'types': ['grass', 'fairy']}
# 52   {'pokemon': 'Whimsicott', 'percent': '23.596', 'types': ['grass', 'fairy']}
# 53   {'pokemon': 'Dragapult', 'percent': '43.126', 'types': ['dragon', 'ghost']}
# 54   {'pokemon': 'Togekiss', 'percent': '28.346', 'types': ['fairy', 'flying']}
# 55   {'pokemon': 'Vileplume', 'percent': '24.212', 'types': ['grass', 'poison']}
# 56   {'pokemon': 'Tyranitar', 'percent': '41.109', 'types': ['rock', 'dark']}
# 57   {'pokemon': 'Indeedee-F', 'percent': '42.243', 'types': ['psychic', 'normal']}
# 58   {'pokemon': 'Chandelure', 'percent': '34.182', 'types': ['ghost', 'fire']}
# 59   {'pokemon': 'Braviary', 'percent': '33.724', 'types': ['normal', 'flying']}
# 60   {'pokemon': 'Torkoal', 'percent': '21.521', 'types': ['fire']}
# 61   {'pokemon': 'Conkeldurr', 'percent': '41.949', 'types': ['fighting']}
# 62   {'pokemon': 'Dragapult', 'percent': '62.227', 'types': ['dragon', 'ghost']}
# 63   {'pokemon': 'Conkeldurr', 'percent': '27.062', 'types': ['fighting']}
# 64   {'pokemon': 'Rhyperior', 'percent': '32.298', 'types': ['ground', 'rock']}
# 65   {'pokemon': 'Corviknight', 'percent': '23.779', 'types': ['flying', 'steel']}
# 66   {'pokemon': 'Dracovish', 'percent': '39.048', 'types': ['water', 'dragon']}
# 67   {'pokemon': 'Arcanine', 'percent': '38.773', 'types': ['fire']}
# 68   {'pokemon': 'Arcanine', 'percent': '21.201', 'types': ['fire']}
# 69   {'pokemon': 'Excadrill', 'percent': '31.815', 'types': ['ground', 'steel']}
# 70   {'pokemon': 'Duraludon', 'percent': '24.845', 'types': ['steel', 'dragon']}
# 71   {'pokemon': 'Milotic', 'percent': '54.140', 'types': ['water']}
# 72   {'pokemon': 'Arcanine', 'percent': '29.149', 'types': ['fire']}
# 73   {'pokemon': 'Dragapult', 'percent': '35.456', 'types': ['dragon', 'ghost']}
# 74   {'pokemon': 'Whimsicott', 'percent': '18.254', 'types': ['grass', 'fairy']}
# 75   {'pokemon': 'Duraludon', 'percent': '34.230', 'types': ['steel', 'dragon']}
# 76   {'pokemon': 'Dragapult', 'percent': '36.927', 'types': ['dragon', 'ghost']}
# 77   {'pokemon': 'Arcanine', 'percent': '69.591', 'types': ['fire']}
# 78   {'pokemon': 'Arcanine', 'percent': '42.943', 'types': ['fire']}
# 79   {'pokemon': 'Rotom-Wash', 'percent': '29.396', 'types': ['electric', 'water']}
# 80   {'pokemon': 'Whimsicott', 'percent': '27.762', 'types': ['grass', 'fairy']}
# 81   {'pokemon': 'Excadrill', 'percent': '35.139', 'types': ['ground', 'steel']}
# 82   {'pokemon': 'Torkoal', 'percent': '24.324', 'types': ['fire']}
# 83   {'pokemon': 'Togekiss', 'percent': '53.473', 'types': ['fairy', 'flying']}
# 84   {'pokemon': 'Togekiss', 'percent': '26.434', 'types': ['fairy', 'flying']}
# 85   {'pokemon': 'Whimsicott', 'percent': '34.911', 'types': ['grass', 'fairy']}
# 86   {'pokemon': 'Ferrothorn', 'percent': '23.448', 'types': ['grass', 'steel']}
# 87   {'pokemon': 'Butterfree', 'percent': '77.011', 'types': ['bug', 'flying']}
# 88   {'pokemon': 'Dusclops', 'percent': '31.964', 'types': ['ghost']}
# 89   {'pokemon': 'Excadrill', 'percent': '35.595', 'types': ['ground', 'steel']}
# 90   {'pokemon': 'Togekiss', 'percent': '22.701', 'types': ['fairy', 'flying']}
# 91   {'pokemon': 'Gastrodon', 'percent': '39.362', 'types': ['water', 'ground']}
# 92   {'pokemon': 'Indeedee-F', 'percent': '28.061', 'types': ['psychic', 'normal']}
# 93   {'pokemon': 'Togekiss', 'percent': '34.627', 'types': ['fairy', 'flying']}
# 94   {'pokemon': 'Lapras', 'percent': '20.217', 'types': ['water', 'ice']}
# 95   {'pokemon': 'Milotic', 'percent': '24.249', 'types': ['water']}
# 96   {'pokemon': 'Chandelure', 'percent': '45.048', 'types': ['ghost', 'fire']}
# 97   {'pokemon': 'Togekiss', 'percent': '32.230', 'types': ['fairy', 'flying']}
# 98   {'pokemon': 'Togekiss', 'percent': '23.163', 'types': ['fairy', 'flying']}
# 99   {'pokemon': 'Grimmsnarl', 'percent': '86.271', 'types': ['dark', 'fairy']}
# 100  {'pokemon': 'Dragapult', 'percent': '25.073', 'types': ['dragon', 'ghost']}
# 101  {'pokemon': 'Whimsicott', 'percent': '24.062', 'types': ['grass', 'fairy']}
# 102  {'pokemon': 'Duraludon', 'percent': '31.280', 'types': ['steel', 'dragon']}
# 103  {'pokemon': 'Corviknight', 'percent': '24.256', 'types': ['flying', 'steel']}
# 104  {'pokemon': 'Arcanine', 'percent': '71.993', 'types': ['fire']}
# 105  {'pokemon': 'Excadrill', 'percent': '25.996', 'types': ['ground', 'steel']}
# 106  {'pokemon': 'Duraludon', 'percent': '46.373', 'types': ['steel', 'dragon']}
# 107  {'pokemon': 'Dragapult', 'percent': '26.054', 'types': ['dragon', 'ghost']}
# 108  {'pokemon': 'Arcanine', 'percent': '35.063', 'types': ['fire']}
# 109  {'pokemon': 'Togekiss', 'percent': '33.099', 'types': ['fairy', 'flying']}
# 110  {'pokemon': 'Hatterene', 'percent': '20.637', 'types': ['psychic', 'fairy']}
# 111  {'pokemon': 'Dracovish', 'percent': '23.451', 'types': ['water', 'dragon']}
# 112  {'pokemon': 'Whimsicott', 'percent': '25.538', 'types': ['grass', 'fairy']}
# 113  {'pokemon': 'Dusclops', 'percent': '25.787', 'types': ['ghost']}
# 114  {'pokemon': 'Sylveon', 'percent': '22.376', 'types': ['fairy']}
# 115  {'pokemon': 'Dusclops', 'percent': '21.040', 'types': ['ghost']}
# 116  {'pokemon': 'Torkoal', 'percent': '19.385', 'types': ['fire']}
# 117  {'pokemon': 'Arcanine', 'percent': '23.532', 'types': ['fire']}
# 118  {'pokemon': 'Arcanine', 'percent': '51.205', 'types': ['fire']}
# 119  {'pokemon': 'Ninetales', 'percent': '23.651', 'types': ['fire']}
# 120  {'pokemon': 'Hatterene', 'percent': '41.454', 'types': ['psychic', 'fairy']}
# 121  {'pokemon': 'Chandelure', 'percent': '19.272', 'types': ['ghost', 'fire']}
# 122  {'pokemon': 'Darmanitan-Galar', 'percent': '38.152', 'types': ['ice']}
# 123  {'pokemon': 'Arcanine', 'percent': '33.395', 'types': ['fire']}
# 124  {'pokemon': 'Dracovish', 'percent': '15.408', 'types': ['water', 'dragon']}
# 125  {'pokemon': 'Sigilyph', 'percent': '38.871', 'types': ['psychic', 'flying']}
# 126  {'pokemon': 'Togekiss', 'percent': '27.010', 'types': ['fairy', 'flying']}
# 127  {'pokemon': 'Duraludon', 'percent': '35.042', 'types': ['steel', 'dragon']}
# 128  {'pokemon': 'Mudsdale', 'percent': '49.923', 'types': ['ground']}
# 129  {'pokemon': 'Hitmontop', 'percent': '36.910', 'types': ['fighting']}
# 130  {'pokemon': 'Whimsicott', 'percent': '21.210', 'types': ['grass', 'fairy']}
# 131  {'pokemon': 'Indeedee', 'percent': '29.818', 'types': ['psychic', 'normal']}
# 132  {'pokemon': 'Indeedee-F', 'percent': '19.541', 'types': ['psychic', 'normal']}
# 133  {'pokemon': 'Rhyperior', 'percent': '36.966', 'types': ['ground', 'rock']}
# 134  {'pokemon': 'Conkeldurr', 'percent': '31.030', 'types': ['fighting']}
# 135  {'pokemon': 'Excadrill', 'percent': '24.557', 'types': ['ground', 'steel']}
# 136  {'pokemon': 'Arcanine', 'percent': '20.971', 'types': ['fire']}
# 137  {'pokemon': 'Weezing-Galar', 'percent': '25.344', 'types': ['poison', 'fairy']}
# 138  {'pokemon': 'Dusclops', 'percent': '36.140', 'types': ['ghost']}
# 139  {'pokemon': 'Whimsicott', 'percent': '27.563', 'types': ['grass', 'fairy']}
# 140  {'pokemon': 'Duraludon', 'percent': '55.382', 'types': ['steel', 'dragon']}
# 141  {'pokemon': 'Dracovish', 'percent': '32.082', 'types': ['water', 'dragon']}
# 142  {'pokemon': 'Excadrill', 'percent': '28.367', 'types': ['ground', 'steel']}
# 143  {'pokemon': 'Excadrill', 'percent': '64.831', 'types': ['ground', 'steel']}
# 144  {'pokemon': 'Scrafty', 'percent': '34.841', 'types': ['dark', 'fighting']}
# 145  {'pokemon': 'Sylveon', 'percent': '21.328', 'types': ['fairy']}
# 146  {'pokemon': 'Raichu', 'percent': '45.985', 'types': ['electric']}
# 147  {'pokemon': 'Sableye', 'percent': '20.880', 'types': ['dark', 'ghost']}
# 148  {'pokemon': 'Mimikyu', 'percent': '41.548', 'types': ['ghost', 'fairy']}
# 149  {'pokemon': 'Seismitoad', 'percent': '24.891', 'types': ['water', 'ground']}
# 150  {'pokemon': 'Excadrill', 'percent': '33.104', 'types': ['ground', 'steel']}
# 151  {'pokemon': 'Tyranitar', 'percent': '41.336', 'types': ['rock', 'dark']}
# 152  {'pokemon': 'Tyranitar', 'percent': '21.240', 'types': ['rock', 'dark']}
# 153  {'pokemon': 'Hatterene', 'percent': '27.248', 'types': ['psychic', 'fairy']}
# 154  {'pokemon': 'Ninetales', 'percent': '33.477', 'types': ['fire']}
# 155  {'pokemon': 'Whimsicott', 'percent': '54.450', 'types': ['grass', 'fairy']}
# 156  {'pokemon': 'Snorlax', 'percent': '26.737', 'types': ['normal']}
# 157  {'pokemon': 'Duraludon', 'percent': '52.856', 'types': ['steel', 'dragon']}
# 158  {'pokemon': 'Durant', 'percent': '25.482', 'types': ['bug', 'steel']}
# 159  {'pokemon': 'Gastrodon', 'percent': '23.171', 'types': ['water', 'ground']}
# 160  {'pokemon': 'Arcanine', 'percent': '40.380', 'types': ['fire']}
# 161  {'pokemon': 'Lapras', 'percent': '77.909', 'types': ['water', 'ice']}
# 162  {'pokemon': 'Torkoal', 'percent': '46.938', 'types': ['fire']}
# 163  {'pokemon': 'Togedemaru', 'percent': '76.351', 'types': ['electric', 'steel']}
# 164  {'pokemon': 'Duraludon', 'percent': '43.450', 'types': ['steel', 'dragon']}
# 165  {'pokemon': 'Sylveon', 'percent': '15.526', 'types': ['fairy']}
# 166  {'pokemon': 'Conkeldurr', 'percent': '34.354', 'types': ['fighting']}
# 167  {'pokemon': 'Jellicent', 'percent': '30.036', 'types': ['water', 'ghost']}
# 168  {'pokemon': 'Whimsicott', 'percent': '39.850', 'types': ['grass', 'fairy']}
# 169  {'pokemon': 'Snorlax', 'percent': '21.048', 'types': ['normal']}
# 170  {'pokemon': 'Charizard', 'percent': '20.878', 'types': ['fire', 'flying']}
# 171  {'pokemon': 'Abomasnow', 'percent': '61.989', 'types': ['grass', 'ice']}
# 172  {'pokemon': 'Conkeldurr', 'percent': '28.343', 'types': ['fighting']}
# 173  {'pokemon': 'Duraludon', 'percent': '17.510', 'types': ['steel', 'dragon']}
# 174  {'pokemon': 'Sableye', 'percent': '36.119', 'types': ['dark', 'ghost']}
# 175  {'pokemon': 'Torkoal', 'percent': '25.042', 'types': ['fire']}
# 176  {'pokemon': 'Indeedee-F', 'percent': '25.558', 'types': ['psychic', 'normal']}
# 177  {'pokemon': 'Charizard', 'percent': '19.369', 'types': ['fire', 'flying']}
# 178  {'pokemon': 'Chandelure', 'percent': '73.682', 'types': ['ghost', 'fire']}
# 179  {'pokemon': 'Arcanine', 'percent': '23.209', 'types': ['fire']}
# 180  {'pokemon': 'Arcanine', 'percent': '75.031', 'types': ['fire']}
# 181  {'pokemon': 'Reuniclus', 'percent': '39.704', 'types': ['psychic']}
# 182  {'pokemon': 'Mimikyu', 'percent': '72.992', 'types': ['ghost', 'fairy']}
# 183  {'pokemon': 'Rotom-Mow', 'percent': '30.387', 'types': ['electric', 'grass']}
# 184  {'pokemon': 'Butterfree', 'percent': '84.290', 'types': ['bug', 'flying']}
# 185  {'pokemon': 'Grimmsnarl', 'percent': '72.372', 'types': ['dark', 'fairy']}
# 186  {'pokemon': 'Whimsicott', 'percent': '20.804', 'types': ['grass', 'fairy']}
# 187  {'pokemon': 'Duraludon', 'percent': '28.952', 'types': ['steel', 'dragon']}
# 188  {'pokemon': 'Hitmontop', 'percent': '35.350', 'types': ['fighting']}
# 189  {'pokemon': 'Rotom-Wash', 'percent': '42.046', 'types': ['electric', 'water']}
# 190  {'pokemon': 'Drampa', 'percent': '29.939', 'types': ['normal', 'dragon']}
# 191  {'pokemon': 'Togekiss', 'percent': '31.275', 'types': ['fairy', 'flying']}
# 192  {'pokemon': 'Grimmsnarl', 'percent': '41.669', 'types': ['dark', 'fairy']}
# 193  {'pokemon': 'Sylveon', 'percent': '43.829', 'types': ['fairy']}
# 194  {'pokemon': 'Butterfree', 'percent': '33.621', 'types': ['bug', 'flying']}
# 195  {'pokemon': 'Inteleon', 'percent': '68.799', 'types': ['water']}
# 196  {'pokemon': 'Rhyperior', 'percent': '65.354', 'types': ['ground', 'rock']}
# 197  {'pokemon': 'Dragapult', 'percent': '18.752', 'types': ['dragon', 'ghost']}
# 198  {'pokemon': 'Excadrill', 'percent': '34.093', 'types': ['ground', 'steel']}
# 199  {'pokemon': 'Gastrodon', 'percent': '17.781', 'types': ['water', 'ground']}
# 200  {'pokemon': 'Gyarados', 'percent': '28.067', 'types': ['water', 'flying']}
# 201  {'pokemon': 'Snorlax', 'percent': '40.401', 'types': ['normal']}
# 202  {'pokemon': 'Duraludon', 'percent': '94.145', 'types': ['steel', 'dragon']}
# 203  {'pokemon': 'Whimsicott', 'percent': '75.497', 'types': ['grass', 'fairy']}
# 204  {'pokemon': 'Gastrodon', 'percent': '43.164', 'types': ['water', 'ground']}
# 205  {'pokemon': 'Leafeon', 'percent': '25.157', 'types': ['grass']}
# 206  {'pokemon': 'Pelipper', 'percent': '27.907', 'types': ['water', 'flying']}
# 207  {'pokemon': 'Scrafty', 'percent': '54.005', 'types': ['dark', 'fighting']}
# 208  {'pokemon': 'Lapras', 'percent': '37.154', 'types': ['water', 'ice']}
# 209  {'pokemon': 'Whimsicott', 'percent': '20.931', 'types': ['grass', 'fairy']}
# 210  {'pokemon': 'Chandelure', 'percent': '31.756', 'types': ['ghost', 'fire']}
# 211  {'pokemon': 'Torkoal', 'percent': '76.434', 'types': ['fire']}
# 212  {'pokemon': 'Gyarados', 'percent': '24.945', 'types': ['water', 'flying']}
# 213  {'pokemon': 'Conkeldurr', 'percent': '55.381', 'types': ['fighting']}
# 214  {'pokemon': 'Polteageist', 'percent': '62.443', 'types': ['ghost']}
# 215  {'pokemon': 'Whimsicott', 'percent': '23.922', 'types': ['grass', 'fairy']}
# 216  {'pokemon': 'Hatterene', 'percent': '32.771', 'types': ['psychic', 'fairy']}
# 217  {'pokemon': 'Chandelure', 'percent': '56.858', 'types': ['ghost', 'fire']}
# 218  {'pokemon': 'Hitmontop', 'percent': '34.029', 'types': ['fighting']}
# 219  {'pokemon': 'Dracozolt', 'percent': '68.292', 'types': ['electric', 'dragon']}
# 220  {'pokemon': 'Togekiss', 'percent': '51.127', 'types': ['fairy', 'flying']}
# 221  {'pokemon': 'Whimsicott', 'percent': '59.695', 'types': ['grass', 'fairy']}
# 222  {'pokemon': 'Hatterene', 'percent': '86.486', 'types': ['psychic', 'fairy']}
# 223  {'pokemon': 'Gengar', 'percent': '44.001', 'types': ['ghost', 'poison']}

# %%
teams1DF2 = teams1DF2.rename(columns={0:"First",
                            1:"Second",
                            2: "Third"})
teams1DF2.columns
# Out:
# 208  Whimsicott   57.042  [grass, fairy]
# 209  Excadrill    31.745  [ground, steel]
# 210  Duraludon    51.458  [steel, dragon]
# 211  Dragapult    76.466  [dragon, ghost]
# 212  Togekiss     30.509  [fairy, flying]
# 213  Mudsdale     66.228  [ground]
# 214  Hitmontop    72.267  [fighting]
# 215  Arcanine     33.759  [fire]
# 216  Rhyperior    35.587  [ground, rock]
# 217  Togekiss     74.216  [fairy, flying]
# 218  Duraludon    47.588  [steel, dragon]
# 219  Torkoal      75.838  [fire]
# 220  Excadrill    68.691  [ground, steel]
# 221  Gyarados     59.921  [water, flying]
# 222  Indeedee-F   95.882  [psychic, normal]
# 223  Lapras       66.298  [water, ice]

# %%
teams1DF2_Second = teams1DF2["Second"].tolist()
teams1DF2_Second = pd.DataFrame(teams1DF2_Second)
teams1DF2_Second
# Out:
#             pokemon percent               types
# 0    Arcanine        35.593  [fire]
# 1    Dragapult       30.663  [dragon, ghost]
# 2    Excadrill       38.133  [ground, steel]
# 3    Tyranitar       47.122  [rock, dark]
# 4    Togekiss        32.431  [fairy, flying]
# 5    Arcanine        39.353  [fire]
# 6    Togekiss        50.508  [fairy, flying]
# 7    Duraludon       38.183  [steel, dragon]
# 8    Excadrill       35.918  [ground, steel]
# 9    Togekiss        40.461  [fairy, flying]
# 10   Dusclops        38.673  [ghost]
# 11   Whimsicott      39.141  [grass, fairy]
# 12   Togekiss        45.143  [fairy, flying]
# 13   Arcanine        31.293  [fire]
# 14   Torkoal         48.417  [fire]
# 15   Whimsicott      42.164  [grass, fairy]
# 16   Inteleon        48.180  [water]
# 17   Togekiss        45.495  [fairy, flying]
# 18   Dusclops        57.543  [ghost]
# 19   Whimsicott      53.689  [grass, fairy]
# 20   Duraludon       31.739  [steel, dragon]
# 21   Gastrodon       27.891  [water, ground]
# 22   Whimsicott      35.197  [grass, fairy]
# 23   Dragapult       33.780  [dragon, ghost]
# 24   Conkeldurr      39.889  [fighting]
# 25   Inteleon        44.006  [water]
# 26   Arcanine        34.530  [fire]
# 27   Mimikyu         36.206  [ghost, fairy]
# 28   Duraludon       36.505  [steel, dragon]
# 29   Rhyperior       25.545  [ground, rock]
# 30   Grimmsnarl      42.508  [dark, fairy]
# 31   Gastrodon       35.095  [water, ground]
# 32   Whimsicott      40.718  [grass, fairy]
# 33   Dragapult       32.479  [dragon, ghost]
# 34   Rhyperior       38.361  [ground, rock]
# 35   Togekiss        62.521  [fairy, flying]
# 36   Dragapult       36.175  [dragon, ghost]
# 37   Togekiss        26.399  [fairy, flying]
# 38   Torkoal         47.937  [fire]
# 39   Excadrill       42.561  [ground, steel]
# 40   Indeedee-F      37.958  [psychic, normal]
# 41   Hydreigon       66.854  [dark, dragon]
# 42   Gothitelle      33.598  [psychic]
# 43   Togekiss        34.431  [fairy, flying]
# 44   Togekiss        44.241  [fairy, flying]
# 45   Whimsicott      42.738  [grass, fairy]
# 46   Togekiss        46.204  [fairy, flying]
# 47   Dragapult       41.809  [dragon, ghost]
# 48   Dragapult       38.860  [dragon, ghost]
# 49   Rhyperior       53.633  [ground, rock]
# 50   Excadrill       22.596  [ground, steel]
# 51   Excadrill       36.923  [ground, steel]
# 52   Dragapult       23.809  [dragon, ghost]
# 53   Togekiss        68.447  [fairy, flying]
# 54   Arcanine        34.431  [fire]
# 55   Rhyperior       42.255  [ground, rock]
# 56   Arcanine        45.872  [fire]
# 57   Togekiss        44.881  [fairy, flying]
# 58   Excadrill       39.327  [ground, steel]
# 59   Arcanine        36.905  [fire]
# 60   Duraludon       24.280  [steel, dragon]
# 61   Duraludon       48.483  [steel, dragon]
# 62   Sylveon         64.159  [fairy]
# 63   Dragapult       29.483  [dragon, ghost]
# 64   Togekiss        32.629  [fairy, flying]
# 65   Arcanine        24.487  [fire]
# 66   Inteleon        41.141  [water]
# 67   Corviknight     48.297  [flying, steel]
# 68   Whimsicott      27.206  [grass, fairy]
# 69   Tyranitar       39.506  [rock, dark]
# 70   Rotom-Mow       34.292  [electric, grass]
# 71   Tyranitar       61.219  [rock, dark]
# 72   Togekiss        30.545  [fairy, flying]
# 73   Arcanine        41.224  [fire]
# 74   Dusclops        19.756  [ghost]
# 75   Grimmsnarl      38.222  [dark, fairy]
# 76   Dusclops        40.981  [ghost]
# 77   Excadrill       71.582  [ground, steel]
# 78   Gothitelle      51.293  [psychic]
# 79   Mimikyu         35.216  [ghost, fairy]
# 80   Togekiss        28.600  [fairy, flying]
# 81   Charizard       40.433  [fire, flying]
# 82   Dusclops        31.146  [ghost]
# 83   Grimmsnarl      54.511  [dark, fairy]
# 84   Gastrodon       37.053  [water, ground]
# 85   Arcanine        45.898  [fire]
# 86   Ludicolo        39.683  [water, grass]
# 87   Snorlax         80.507  [normal]
# 88   Conkeldurr      41.812  [fighting]
# 89   Charizard       35.621  [fire, flying]
# 90   Duraludon       27.203  [steel, dragon]
# 91   Arcanine        45.296  [fire]
# 92   Excadrill       28.469  [ground, steel]
# 93   Dracovish       37.198  [water, dragon]
# 94   Scrafty         22.822  [dark, fighting]
# 95   Dragapult       25.889  [dragon, ghost]
# 96   Durant          45.927  [bug, steel]
# 97   Rhyperior       35.948  [ground, rock]
# 98   Duraludon       24.301  [steel, dragon]
# 99   Duraludon       87.744  [steel, dragon]
# 100  Grimmsnarl      25.181  [dark, fairy]
# 101  Arcanine        28.305  [fire]
# 102  Gyarados        38.473  [water, flying]
# 103  Dusclops        24.370  [ghost]
# 104  Tyranitar       74.352  [rock, dark]
# 105  Coalossal       45.540  [rock, fire]
# 106  Arcanine        48.487  [fire]
# 107  Indeedee-F      28.849  [psychic, normal]
# 108  Grimmsnarl      36.885  [dark, fairy]
# 109  Excadrill       33.358  [ground, steel]
# 110  Dusclops        20.934  [ghost]
# 111  Whimsicott      25.360  [grass, fairy]
# 112  Excadrill       28.168  [ground, steel]
# 113  Rhyperior       27.847  [ground, rock]
# 114  Dragapult       25.002  [dragon, ghost]
# 115  Hatterene       22.509  [psychic, fairy]
# 116  Togekiss        25.403  [fairy, flying]
# 117  Torkoal         24.216  [fire]
# 118  Dragapult       51.529  [dragon, ghost]
# 119  Charizard       24.651  [fire, flying]
# 120  Charizard       63.547  [fire, flying]
# 177  Charizard         19.369  [fire, flying]
# 178  Chandelure        73.682  [ghost, fire]
# 179  Arcanine          23.209  [fire]
# 180  Arcanine          75.031  [fire]
# 181  Reuniclus         39.704  [psychic]
# 182  Mimikyu           72.992  [ghost, fairy]
# 183  Rotom-Mow         30.387  [electric, grass]
# 184  Butterfree        84.290  [bug, flying]
# 185  Grimmsnarl        72.372  [dark, fairy]
# 186  Whimsicott        20.804  [grass, fairy]
# 187  Duraludon         28.952  [steel, dragon]
# 188  Hitmontop         35.350  [fighting]
# 189  Rotom-Wash        42.046  [electric, water]
# 190  Drampa            29.939  [normal, dragon]
# 191  Togekiss          31.275  [fairy, flying]
# 192  Grimmsnarl        41.669  [dark, fairy]
# 193  Sylveon           43.829  [fairy]
# 194  Butterfree        33.621  [bug, flying]
# 195  Inteleon          68.799  [water]
# 196  Rhyperior         65.354  [ground, rock]
# 197  Dragapult         18.752  [dragon, ghost]
# 198  Excadrill         34.093  [ground, steel]
# 199  Gastrodon         17.781  [water, ground]
# 200  Gyarados          28.067  [water, flying]
# 201  Snorlax           40.401  [normal]
# 202  Duraludon         94.145  [steel, dragon]
# 203  Whimsicott        75.497  [grass, fairy]
# 204  Gastrodon         43.164  [water, ground]
# 205  Leafeon           25.157  [grass]
# 206  Pelipper          27.907  [water, flying]
# 207  Scrafty           54.005  [dark, fighting]
# 208  Lapras            37.154  [water, ice]
# 209  Whimsicott        20.931  [grass, fairy]
# 210  Chandelure        31.756  [ghost, fire]
# 211  Torkoal           76.434  [fire]
# 212  Gyarados          24.945  [water, flying]
# 213  Conkeldurr        55.381  [fighting]
# 214  Polteageist       62.443  [ghost]
# 215  Whimsicott        23.922  [grass, fairy]
# 216  Hatterene         32.771  [psychic, fairy]
# 217  Chandelure        56.858  [ghost, fire]
# 218  Hitmontop         34.029  [fighting]
# 219  Dracozolt         68.292  [electric, dragon]
# 220  Togekiss          51.127  [fairy, flying]
# 221  Whimsicott        59.695  [grass, fairy]
# 222  Hatterene         86.486  [psychic, fairy]
# 223  Gengar            44.001  [ghost, poison]

# %% [markdown]
# ## Working On The web

# %%
url1 = "https://www.wikidex.net/wiki/Lista_de_Pok%C3%A9mon_con_sus_estad%C3%ADsticas_base"

# %%
html = requests.get(url1).content
soup = BeautifulSoup(html, "lxml")
soup

# %%
table = soup.find_all("table", {"class":"tabpokemon sortable mergetable tablemanager"})[0]
type(table)

# %%
rows = table.find_all("tr")
rows = [row.text.strip().split("\n") for row in rows]
rows = [list(filter(None,row)) for row in rows]
wikidexDF = pd.DataFrame(rows)

# %%
wikidexDF.head()

# %%
wikidexDF = wikidexDF.drop([11], axis=1)
wikidexDF.head()

# %%
wikidexDF = wikidexDF.drop([0], axis=0)
wikidexDF.head()

# %%
colnames = ["National Dex #", "Pokémon", "HP", "Attack", "Defense", "Special Attack", "Special Defense", "Speed", "Mean", "SD", "Total"]

wikidexDF = pd.DataFrame(rows[1:], columns = colnames)

# %%
wikidexDF.head(10)

# %% [markdown]
# ## Combining Information

# %%
#pokemonDF = pokemonDF.style.hide_index()
