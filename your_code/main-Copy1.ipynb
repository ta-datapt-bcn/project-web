# %% [markdown]
# ## IDEA <br>
#
# - Use OMDB API: http://www.omdbapi.com/#usage
# - Do the API request with the search, movies with word 'love', 2 pages
# - Use this URL with parameters: http://www.omdbapi.com/?i=tt3896198&apikey=aab3947e&s=love&type=movie
# - Like that get the list of titles of the movies (later create column in df)
# - Do another API request title by title to get more info about the movies
# - Use this URL with parameters: http://www.omdbapi.com/?i=tt3896198&apikey=aab3947e&t=The+Shawshank+Redemption
# - Check how to pass the movie name to the end of URL. Format: xx+xx+xxx+xx (words separated by '+')
# - Put info from both requests to the df
# - Scrap IMDB or Wikkipedia based on title or IMDB ID to get info from there
# - Check if some data matching: Release year, Genre, Director, IMDB Rating
# - Could also get more data about the director from Wiki or IMDB

# %% [markdown]
# ## API <br>
#
# - For the API portion of the project will need to make calls to your chosen API, successfully obtain a response, request data, convert it into a Pandas data frame, and export it as a CSV file.

# %% [markdown]
# ## WEB SCRAPING <br>
#
# - For the web scraping portion of the project, you will need to scrape the HTML from your chosen page, parse the HTML to extract the necessary information, and either save the results to a text (txt) file if it is text or into a CSV file if it is tabular data.

# %% [markdown]
# ## 1. API

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup

#check if using this library
import time

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#the function to flatten_json several times
#for now haven't used them

def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %% [markdown]
# - Doing the search of the titles that include word 'love' in x pages

# %%
#generating several jsons from different pages
#in the range indicate how many pages want to check (API in general gives MAX movies per search)
#and then adding all the movie names to one list
#per each loop generating json for one page and extracting titles

url_pat= 'http://www.omdbapi.com/?i=tt3896198&apikey=aab3947e&s=love&type=movie&page='
final_list = []
for page in range(1,5):
    page = str(page)
    url = url_pat + page
    response = requests.get(url)
    results = response.json()
    title_box = results.get('Search')
    title_list = [title.get('Title') for title in title_box]
    final_list += title_list
final_list
# Out:
# ['Crazy, Stupid, Love.',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Love, Actually',
#  'Shakespeare in Love',
#  'P.S. I Love You',
#  'I Love You, Man',
#  'Love & Other Drugs',
#  'Punch-Drunk Love',
#  'Love, Rosie',
#  'In the Mood for Love',
#  'From Russia with Love',
#  'From Paris with Love',
#  'I Love You Phillip Morris',
#  'Love, Simon',
#  'Eat Pray Love',
#  'To Rome with Love',
#  'Stuck in Love.',
#  'A Lot Like Love',
#  'Love Me If You Dare',
#  'Wristcutters: A Love Story',
#  'The Love Guru',
#  'Show Me Love',
#  'New York, I Love You',
#  'American Pie Presents: The Book of Love',
#  'Love',
#  'Capitalism: A Love Story',
#  'Endless Love',
#  'Down with Love',
#  'Sea of Love',
#  'Everyone Says I Love You',
#  'Love and Death',
#  'Love & Mercy',
#  'I Love You, Beth Cooper',
#  'The One I Love',
#  "Can't Buy Me Love",
#  'For Love of the Game',
#  'All the Boys Love Mandy Lane',
#  'Love Happens',
#  'Must Love Dogs',
#  'Love Story']

# %% [markdown]
# - converting names into the correct format to later pass them to the URL

# %%
titles_formatted = [string.replace(" ", "+") for string in final_list]
titles_formatted
# Out:
# ['Crazy,+Stupid,+Love.',
#  'Dr.+Strangelove+or:+How+I+Learned+to+Stop+Worrying+and+Love+the+Bomb',
#  'Love,+Actually',
#  'Shakespeare+in+Love',
#  'P.S.+I+Love+You',
#  'I+Love+You,+Man',
#  'Love+&+Other+Drugs',
#  'Punch-Drunk+Love',
#  'Love,+Rosie',
#  'In+the+Mood+for+Love',
#  'From+Russia+with+Love',
#  'From+Paris+with+Love',
#  'I+Love+You+Phillip+Morris',
#  'Love,+Simon',
#  'Eat+Pray+Love',
#  'To+Rome+with+Love',
#  'Stuck+in+Love.',
#  'A+Lot+Like+Love',
#  'Love+Me+If+You+Dare',
#  'Wristcutters:+A+Love+Story',
#  'The+Love+Guru',
#  'Show+Me+Love',
#  'New+York,+I+Love+You',
#  'American+Pie+Presents:+The+Book+of+Love',
#  'Love',
#  'Capitalism:+A+Love+Story',
#  'Endless+Love',
#  'Down+with+Love',
#  'Sea+of+Love',
#  'Everyone+Says+I+Love+You',
#  'Love+and+Death',
#  'Love+&+Mercy',
#  'I+Love+You,+Beth+Cooper',
#  'The+One+I+Love',
#  "Can't+Buy+Me+Love",
#  'For+Love+of+the+Game',
#  'All+the+Boys+Love+Mandy+Lane',
#  'Love+Happens',
#  'Must+Love+Dogs',
#  'Love+Story']

# %% [markdown]
# - Getting the info about each movie from the list

# %%
url_pattern = 'http://www.omdbapi.com/?i=tt3896198&apikey=aab3947e&t='
appended_dfs=[]

for title in titles_formatted:
    url = url_pattern + title
    response = requests.get(url)
    results = response.json()
    flattened_data = json_normalize(results)
    #appending dataframes to the list to later concatenate them to one dataframe
    appended_dfs.append(flattened_data)
    love_movies = pd.concat(appended_dfs)

love_movies
# Out:
#                                                Title  Year      Rated  \
# 0                               Crazy, Stupid, Love.  2011      PG-13
# 0  Dr. Strangelove or: How I Learned to Stop Worr...  1964         PG
# 0                                     Love, Actually  2003          R
# 0                                Shakespeare in Love  1998          R
# 0                                    P.S. I Love You  2007      PG-13
# 0                                    I Love You, Man  2009          R
# 0                                               Love  2015  Not Rated
# 0                                   Punch-Drunk Love  2002          R
# 0                                        Love, Rosie  2014          R
# 0                               In the Mood for Love  2000         PG
# 0                              From Russia with Love  1963         PG
# 0                               From Paris with Love  2010          R
# 0                          I Love You Phillip Morris  2009          R
# 0                                        Love, Simon  2018      PG-13
# 0                                      Eat Pray Love  2010      PG-13
# 0                                  To Rome with Love  2012          R
# 0                                     Stuck in Love.  2012          R
# 0                                    A Lot Like Love  2005      PG-13
# 0                                Love Me If You Dare  2003          R
# 0                         Wristcutters: A Love Story  2006          R
# 0                                      The Love Guru  2008      PG-13
# 0                                       Show Me Love  1998  Not Rated
# 0                               New York, I Love You  2008          R
# 0            American Pie Presents: The Book of Love  2009          R
# 0                                               Love  2015  Not Rated
# 0                           Capitalism: A Love Story  2009          R
# 0                                       Endless Love  2014      PG-13
# 0                                     Down with Love  2003      PG-13
# 0                                        Sea of Love  1989          R
# 0                           Everyone Says I Love You  1996          R
# 0                                     Love and Death  1975         PG
# 0                                               Love  2015  Not Rated
# 0  Paul Rudd, Rashida Jones, Sarah Burns, Greg Le...
# 0  Aomi Muyock, Karl Glusman, Klara Kristin, Ugo Fox
# 0  Adam Sandler, Jason Andrews, Don McManus, Emil...
# 0  Lily Collins, Sam Claflin, Christian Cooke, Ja...
# 0  Maggie Cheung, Tony Chiu-Wai Leung, Ping Lam S...
# 0  Sean Connery, Daniela Bianchi, Pedro Armendári...
# 0  John Travolta, Jonathan Rhys Meyers, Kasia Smu...
# 0  Jim Carrey, Ewan McGregor, Leslie Mann, Rodrig...
# 0  Nick Robinson, Jennifer Garner, Josh Duhamel, ...
# 0  Julia Roberts, I. Gusti Ayu Puspawati, Hadi Su...
# 0  Pierluigi Marchionne, Flavio Parenti, Alison P...
# 0  Greg Kinnear, Jennifer Connelly, Lily Collins,...
# 0  Amanda Peet, Ashton Kutcher, Taryn Manning, Ai...
# 0  Guillaume Canet, Marion Cotillard, Thibault Ve...
# 0  Will Arnett, Abraham Benrubi, Leslie Bibb, Mar...
# 0  Jessica Simpson, Kanye West, Mike Myers, Deepa...
# 0  Alexandra Dahlström, Rebecka Liljeberg, Erica ...
# 0  Hayden Christensen, Andy Garcia, Rachel Bilson...
# 0  Eugene Levy, Bug Hall, Kevin M. Horton, Brando...
# 0  Aomi Muyock, Karl Glusman, Klara Kristin, Ugo Fox
# 0  William Black, Jimmy Carter, Elijah Cummings, ...
# 0  Alex Pettyfer, Gabriella Wilde, Bruce Greenwoo...
# 0  Renée Zellweger, Ewan McGregor, Sarah Paulson,...
# 0  Al Pacino, Ellen Barkin, John Goodman, Michael...
# 0  Edward Norton, Drew Barrymore, Diva Gray, Ami ...
# 0  Woody Allen, Diane Keaton, Georges Adet, Robin...
# 0  Aomi Muyock, Karl Glusman, Klara Kristin, Ugo Fox
# 0  Hayden Panettiere, Paul Rust, Jack Carpenter, ...
# 0  Mark Duplass, Elisabeth Moss, Ted Danson, Kian...
# 0  Patrick Dempsey, Amanda Peterson, Courtney Gai...
# 0  Kevin Costner, Kelly Preston, John C. Reilly, ...
# 0  Amber Heard, Anson Mount, Michael Welch, Whitn...
# 0  Aaron Eckhart, Jennifer Aniston, Dan Fogler, J...
# 0  Diane Lane, John Cusack, Elizabeth Perkins, Ch...
# 0  Ali MacGraw, Ryan O'Neal, John Marley, Ray Mil...
#
#                                                 Plot  ... Metascore  \
# 0  A middle-aged husband's life changes dramatica...  ...        68
# 0  An insane general triggers a path to nuclear h...  ...        97
# 0  Follows the lives of eight very different coup...  ...        55
# 0  The world's greatest ever playwright, William ...  ...        87
# 0  A young widow discovers that her late husband ...  ...        39
# 0  Friendless Peter Klaven goes on a series of ma...  ...        70
# 0  Murphy is an American living in Paris who ente...  ...        51
# 0  A psychologically troubled novelty supplier is...  ...        78
# 0  Rosie and Alex have been best friends since th...  ...        44
# 0  Two neighbors, a woman and a man, form a stron...  ...        85
# 0  James Bond willingly falls into an assassinati...  ...        85
# 0  In Paris, a young employee in the office of th...  ...        42
# 0  A cop turns con man once he comes out of the c...  ...        65
# 0  Simon Spier keeps a huge secret from his famil...  ...        72
# 0  A married woman realizes how unhappy her marri...  ...        50
# 0  The lives of some visitors and residents of Ro...  ...        54
# 0  An acclaimed writer, his ex-wife, and their te...  ...        49
# 0  Unaquainted Emily and Oliver join the mile hig...  ...        48
# 0  As adults, best friends Julien and Sophie cont...  ...        45
# 0  A film set in a strange afterlife way station ...  ...        62
# 0  Pitka, an American raised outside of his count...  ...        24
# 0  Two teenage girls in small-town Sweden. Elin i...  ...        73
# 0  Eleven love stories set in one of the most lov...  ...        49
# 0  Ten years after the first American Pie movie, ...  ...       N/A
# 0  Murphy is an American living in Paris who ente...  ...        51
# 0  An examination of the social costs of corporat...  ...        61
# 0  The story of a privileged girl and a charismat...  ...        30
# 0  In 1962 New York City, love blossoms between a...  ...        52
# 0  A detective investigating a series of murders ...  ...        66
# 0  A New York girl sets her father up with a beau...  ...       N/A
# 0  In czarist Russia, a neurotic soldier and his ...  ...        89
# 0  Murphy is an American living in Paris who ente...  ...        51
# 0  A nerdy valedictorian proclaims his love for B...  ...        32
# 0  A troubled couple vacate to a beautiful getawa...  ...        66
# 0  A nerdy outcast secretly pays the most popular...  ...        36
# 0  After 19 years of playing the game he's loved ...  ...        43
# 0  A group of high-schoolers invite Mandy Lane, a...  ...        44
# 0  A widower whose book about coping with loss tu...  ...        33
# 0  A forty-something preschool teacher looks to t...  ...        46
# 0  A boy and a girl from different backgrounds fa...  ...        84
#
#   imdbRating imdbVotes     imdbID   Type          DVD    BoxOffice  \
# 0        7.4   447,664  tt1570728  movie  01 Nov 2011  $83,300,000
# 0        8.4   427,212  tt0057012  movie  02 Nov 2004          N/A
# 0        7.6   405,898  tt0314331  movie  27 Apr 2004  $59,365,105
# 0        7.1   205,961  tt0138097  movie  10 Aug 1999          N/A
# 0        7.0   194,541  tt0431308  movie  05 Feb 2008          N/A
# 0        7.0   188,613  tt1155056  movie  11 Aug 2009  $71,300,000
# 0        6.1    40,472  tt3774694  movie  15 Mar 2016     $176,061
# 0        7.3   137,629  tt0272338  movie  24 Jun 2003  $17,800,000
# 0        7.2   111,376  tt1638002  movie  05 May 2015          N/A
# 0        8.1   111,148  tt0118694  movie  05 Mar 2002          N/A
# 0        7.4   109,544  tt0057076  movie  28 Mar 2006          N/A
# 0        6.5   108,795  tt1179034  movie  08 Jun 2010  $23,979,741
# 0        6.6    88,737  tt1045772  movie  05 Apr 2011   $2,026,852
# 0        7.6    87,922  tt5164432  movie  12 Jun 2018          N/A
# 0        5.8    81,783  tt0879870  movie  23 Nov 2010  $80,574,010
# 0        6.3    81,074  tt1859650  movie  15 Jan 2013  $16,500,000
# 0        7.2    80,150  tt2205697  movie  08 Oct 2013     $100,000
# 0        6.6    65,452  tt0391304  movie  23 Aug 2005  $21,835,784
# 0        7.6    64,787  tt0364517  movie  19 Oct 2004     $449,282
# 0        7.3    51,998  tt0477139  movie  18 May 1999          N/A
# 0        3.8    48,853  tt0811138  movie  16 Sep 2008  $32,178,777
# 0        7.5    48,314  tt0150662  movie  03 Oct 2000          N/A
# 0        6.3    43,704  tt0808399  movie  02 Feb 2010   $1,600,000
# 0        4.8    41,633  tt1407050  movie  22 Dec 2009          N/A
# 0        6.1    40,472  tt3774694  movie  15 Mar 2016     $176,061
# 0        7.4    40,021  tt1232207  movie  09 Mar 2010  $14,342,792
# 0        6.3    38,960  tt2318092  movie  27 May 2014          N/A
# 0        6.2    37,968  tt0309530  movie  07 Oct 2003  $20,186,516
# 0        6.8    35,727  tt0098273  movie  26 May 1998          N/A
# 0        6.7    34,091  tt0116242  movie  17 Aug 1999          N/A
# 0        7.7    33,643  tt0073312  movie  05 Jul 2000          N/A
# 0        6.1    40,472  tt3774694  movie  15 Mar 2016     $176,061
# 0        5.3    32,382  tt1032815  movie  03 Nov 2009  $14,800,000
# 0        7.1    32,210  tt2756032  movie  03 Nov 2014     $511,635
# 0        6.8    30,472  tt0092718  movie  13 Aug 2002          N/A
# 0        6.6    30,344  tt0126916  movie  15 Aug 2000          N/A
# 0        5.5    30,208  tt0490076  movie  03 Dec 2013          N/A
# 0        5.6    29,592  tt0899106  movie  02 Feb 2010  $22,927,390
# 0        5.9    29,580  tt0417001  movie  20 Dec 2005  $43,800,000
# 0        6.9    28,070  tt0066011  movie  24 Apr 2001          N/A
#
#                      Production Website Response
# 0         Warner Bros. Pictures     N/A     True
# 0                 Sony Pictures     N/A     True
# 0            Universal Pictures     N/A     True
# 0                       Miramax     N/A     True
# 0                           N/A     N/A     True
# 0          Dreamworks/Paramount     N/A     True
# 0                       Alchemy     N/A     True
# 0             Columbia Pictures     N/A     True
# 0                   Film Arcade     N/A     True
# 0                     USA Films     N/A     True
# 0                United Artists     N/A     True
# 0               Lionsgate Films     N/A     True
# 0          Roadside Attractions     N/A     True
# 0              20th Century Fox     N/A     True
# 0                 Sony Pictures     N/A     True
# 0        Sony Pictures Classics     N/A     True
# 0       Millenium Entertainment     N/A     True
# 0           Touchstone Pictures     N/A     True
# 0            Paramount Classics     N/A     True
# 0                           N/A     N/A     True
# 0            Paramount Pictures     N/A     True
# 0              Strand Releasing     N/A     True
# 0         Vivendi Entertainment     N/A     True
# 0  Universal Studios Home Video     N/A     True
# 0                       Alchemy     N/A     True
# 0                Overture Films     N/A     True
# 0            Universal Pictures     N/A     True
# 0              20th Century Fox     N/A     True
# 0      MCA Universal Home Video     N/A     True
# 0               Sweetland Films     N/A     True
# 0                United Artists     N/A     True
# 0                       Alchemy     N/A     True
# 0              20th Century Fox     N/A     True
# 0                    Radius-TWC     N/A     True
# 0          Buena Vista Pictures     N/A     True
# 0            Universal Pictures     N/A     True
# 0                    Radius-TWC     N/A     True
# 0            Universal Pictures     N/A     True
# 0         Warner Bros. Pictures     N/A     True
# 0            Paramount Pictures     N/A     True
#
# [40 rows x 25 columns]
