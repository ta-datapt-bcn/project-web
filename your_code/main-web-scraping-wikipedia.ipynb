# %% [markdown]
# ## IDEA <br>
#
# - Use OMDB API: http://www.omdbapi.com/#usage
# - Do the API request with the search, movies with word 'love', extract info from x pages
# - Like that get the list of titles of the movies
# - Do another API request title by title to get more info about the movies
# - Put info from both requests to one df
# - Scrap IMDB or Wikipedia based on title or IMDB ID to get info from there
# - Check if some data matching: Release year, Genre, Director, IMDB Rating
# - Could also get more data about the director from Wiki or IMDB

# %% [markdown]
# ## API <br>
#
# - For the API portion of the project will need to make calls to your chosen API, successfully obtain a response, request data, convert it into a Pandas data frame, and export it as a CSV file.

# %%
from pandas.io.json import json_normalize
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

#check if using this library
import time

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#the function to flatten_json several times
#for now haven't used them

def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %% [markdown]
# - Doing the search of the titles that include word 'love' in x pages

# %%
#generating several jsons from different pages
#in the range indicate how many pages want to check (API in general gives MAX movies per search)
#and then adding all the movie names to one list
#per each loop generating json for one page and extracting titles

url_pat= 'http://www.omdbapi.com/?i=tt3896198&apikey=aab3947e&s=love&type=movie&page='
final_list = []
for page in range(1,5):
    page = str(page)
    url = url_pat + page
    response = requests.get(url)
    results = response.json()
    title_box = results.get('Search')
    title_list = [title.get('Title') for title in title_box]
    final_list += title_list
final_list
# Out:
# ['Crazy, Stupid, Love.',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Love, Actually',
#  'Shakespeare in Love',
#  'P.S. I Love You',
#  'I Love You, Man',
#  'Love & Other Drugs',
#  'Punch-Drunk Love',
#  'Love, Rosie',
#  'In the Mood for Love',
#  'From Russia with Love',
#  'From Paris with Love',
#  'I Love You Phillip Morris',
#  'Love, Simon',
#  'Eat Pray Love',
#  'To Rome with Love',
#  'Stuck in Love.',
#  'A Lot Like Love',
#  'Love Me If You Dare',
#  'Wristcutters: A Love Story',
#  'The Love Guru',
#  'Show Me Love',
#  'New York, I Love You',
#  'American Pie Presents: The Book of Love',
#  'Love',
#  'Capitalism: A Love Story',
#  'Endless Love',
#  'Down with Love',
#  'Sea of Love',
#  'Everyone Says I Love You',
#  'Love and Death',
#  'Love & Mercy',
#  'I Love You, Beth Cooper',
#  'The One I Love',
#  "Can't Buy Me Love",
#  'For Love of the Game',
#  'All the Boys Love Mandy Lane',
#  'Love Happens',
#  'Must Love Dogs',
#  'Love Story']

# %% [markdown]
# - converting names into the correct format to later pass them to the URL

# %%
titles_formatted = [string.replace(" ", "+") for string in final_list]
titles_formatted
# Out:
# ['Crazy,+Stupid,+Love.',
#  'Dr.+Strangelove+or:+How+I+Learned+to+Stop+Worrying+and+Love+the+Bomb',
#  'Love,+Actually',
#  'Shakespeare+in+Love',
#  'P.S.+I+Love+You',
#  'I+Love+You,+Man',
#  'Love+&+Other+Drugs',
#  'Punch-Drunk+Love',
#  'Love,+Rosie',
#  'In+the+Mood+for+Love',
#  'From+Russia+with+Love',
#  'From+Paris+with+Love',
#  'I+Love+You+Phillip+Morris',
#  'Love,+Simon',
#  'Eat+Pray+Love',
#  'To+Rome+with+Love',
#  'Stuck+in+Love.',
#  'A+Lot+Like+Love',
#  'Love+Me+If+You+Dare',
#  'Wristcutters:+A+Love+Story',
#  'The+Love+Guru',
#  'Show+Me+Love',
#  'New+York,+I+Love+You',
#  'American+Pie+Presents:+The+Book+of+Love',
#  'Love',
#  'Capitalism:+A+Love+Story',
#  'Endless+Love',
#  'Down+with+Love',
#  'Sea+of+Love',
#  'Everyone+Says+I+Love+You',
#  'Love+and+Death',
#  'Love+&+Mercy',
#  'I+Love+You,+Beth+Cooper',
#  'The+One+I+Love',
#  "Can't+Buy+Me+Love",
#  'For+Love+of+the+Game',
#  'All+the+Boys+Love+Mandy+Lane',
#  'Love+Happens',
#  'Must+Love+Dogs',
#  'Love+Story']

# %% [markdown]
# - Getting the info about each movie from the list

# %%
url_pattern = 'http://www.omdbapi.com/?i=tt3896198&apikey=aab3947e&t='
appended_dfs=[]

for title in titles_formatted:
    url = url_pattern + title
    response = requests.get(url)
    results = response.json()
    flattened_data = json_normalize(results)
    #appending dataframes to the list to later concatenate them to one dataframe
    appended_dfs.append(flattened_data)
    love_movies = pd.concat(appended_dfs, ignore_index = True) #ignoring index, to have 0,1,2...n, if not, get 0,0,0,...

love_movies
# Out:
#                                                 Title  Year      Rated  \
# 0                                Crazy, Stupid, Love.  2011      PG-13
# 1   Dr. Strangelove or: How I Learned to Stop Worr...  1964         PG
# 2                                      Love, Actually  2003          R
# 3                                 Shakespeare in Love  1998          R
# 4                                     P.S. I Love You  2007      PG-13
# 5                                     I Love You, Man  2009          R
# 6                                                Love  2015  Not Rated
# 7                                    Punch-Drunk Love  2002          R
# 8                                         Love, Rosie  2014          R
# 9                                In the Mood for Love  2000         PG
# 10                              From Russia with Love  1963         PG
# 11                               From Paris with Love  2010          R
# 12                          I Love You Phillip Morris  2009          R
# 13                                        Love, Simon  2018      PG-13
# 14                                      Eat Pray Love  2010      PG-13
# 15                                  To Rome with Love  2012          R
# 16                                     Stuck in Love.  2012          R
# 17                                    A Lot Like Love  2005      PG-13
# 18                                Love Me If You Dare  2003          R
# 19                         Wristcutters: A Love Story  2006          R
# 20                                      The Love Guru  2008      PG-13
# 21                                       Show Me Love  1998  Not Rated
# 22                               New York, I Love You  2008          R
# 23            American Pie Presents: The Book of Love  2009          R
# 24                                               Love  2015  Not Rated
# 25                           Capitalism: A Love Story  2009          R
# 26                                       Endless Love  2014      PG-13
# 27                                     Down with Love  2003      PG-13
# 28                                        Sea of Love  1989          R
# 29                           Everyone Says I Love You  1996          R
# 30                                     Love and Death  1975         PG
# 31                                               Love  2015  Not Rated
# 32                            I Love You, Beth Cooper  2009      PG-13
# 33                                     The One I Love  2014          R
# 34                                  Can't Buy Me Love  1987      PG-13
# 35                               For Love of the Game  1999      PG-13
# 36                       All the Boys Love Mandy Lane  2006          R
# 37                                       Love Happens  2009      PG-13
# 38                                     Must Love Dogs  2005      PG-13
# 39                                         Love Story  1970         PG
#
#        Released  Runtime                                              Genre  \
# 0   29 Jul 2011  118 min                             Comedy, Drama, Romance
# 1   29 Jan 1964   95 min                                             Comedy
# 2   14 Nov 2003  135 min                             Comedy, Drama, Romance
# 3   08 Jan 1999  123 min                    Comedy, Drama, History, Romance
# 4   21 Dec 2007  126 min                             Comedy, Drama, Romance
# 5   20 Mar 2009  105 min                                    Comedy, Romance
# 6   30 Oct 2015  135 min                                     Drama, Romance
# 7   01 Nov 2002   95 min                   Comedy, Drama, Romance, Thriller
# 8   22 Oct 2014  102 min                                    Comedy, Romance
# 9   09 Mar 2001   98 min                                     Drama, Romance
# 10  27 May 1964  115 min                        Action, Adventure, Thriller
# 11  05 Feb 2010   92 min                            Action, Crime, Thriller
# 12  07 Jan 2011   98 min           Biography, Comedy, Crime, Drama, Romance
# 13  16 Mar 2018  110 min                             Comedy, Drama, Romance
# 14  13 Aug 2010  133 min                                     Drama, Romance
# 15  06 Jul 2012  112 min                             Comedy, Music, Romance
# 16  02 May 2013   97 min                             Comedy, Drama, Romance
# 17  22 Apr 2005  107 min                             Comedy, Drama, Romance
# 18  28 May 2004   93 min                             Comedy, Drama, Romance
# 19  02 Nov 2007   88 min                    Comedy, Drama, Fantasy, Romance
# 20  20 Jun 2008   87 min                             Comedy, Romance, Sport
# 21  23 Oct 1998   89 min                             Comedy, Drama, Romance
# 22  16 Oct 2009  103 min                             Comedy, Drama, Romance
# 23  22 Dec 2009   93 min                                             Comedy
# 24  30 Oct 2015  135 min                                     Drama, Romance
# 25  02 Oct 2009  127 min                           Documentary, Crime, News
# 26  14 Feb 2014  104 min                                     Drama, Romance
# 27  16 May 2003  101 min                                    Comedy, Romance
# 28  15 Sep 1989  113 min           Crime, Drama, Mystery, Romance, Thriller
# 29  17 Jan 1997  101 min                           Comedy, Musical, Romance
# 30  28 Aug 1975   85 min                                        Comedy, War
# 31  30 Oct 2015  135 min                                     Drama, Romance
# 32  10 Jul 2009  102 min                                    Comedy, Romance
# 33  08 Aug 2014   91 min  Drama, Fantasy, Mystery, Romance, Sci-Fi, Thri...
# 34  14 Aug 1987   94 min                             Comedy, Drama, Romance
# 35  17 Sep 1999  137 min                              Drama, Romance, Sport
# 36  06 Sep 2013   90 min                                             Horror
# 37  18 Sep 2009  109 min                                     Drama, Romance
# 38  29 Jul 2005   98 min                                    Comedy, Romance
# 39  16 Dec 1970  100 min                                     Drama, Romance
#
#                                              Director  \
# 0                           Glenn Ficarra, John Requa
# 1                                     Stanley Kubrick
# 2                                      Richard Curtis
# 3                                         John Madden
# 4                                 Richard LaGravenese
# 5                                        John Hamburg
# 6                                          Gaspar Noé
# 7                                Paul Thomas Anderson
# 8                                    Christian Ditter
# 9                                        Kar-Wai Wong
# 10                                      Terence Young
# 11                                       Pierre Morel
# 12                          Glenn Ficarra, John Requa
# 13                                      Greg Berlanti
# 14                                        Ryan Murphy
# 15                                        Woody Allen
# 16                                         Josh Boone
# 17                                         Nigel Cole
# 18                                       Yann Samuell
# 19                                        Goran Dukic
# 20                                     Marco Schnabel
# 21                                    Lukas Moodysson
# 22  Fatih Akin, Yvan Attal, Randall Balsmeyer, All...
# 23                                         John Putch
# 24                                         Gaspar Noé
# 25                                      Michael Moore
# 26                                        Shana Feste
# 27                                        Peyton Reed
# 28                                      Harold Becker
# 29                                        Woody Allen
# 30                                        Woody Allen
# 31                                         Gaspar Noé
# 32                                     Chris Columbus
# 33                                   Charlie McDowell
# 34                                         Steve Rash
# 35                                          Sam Raimi
# 36                                    Jonathan Levine
# 37                                       Brandon Camp
# 38                                Gary David Goldberg
# 39                                      Arthur Hiller
#
#                                                Writer  \
# 0                                        Dan Fogelman
# 1   Stanley Kubrick (screenplay), Terry Southern (...
# 2                                      Richard Curtis
# 3                           Marc Norman, Tom Stoppard
# 4   Richard LaGravenese (screenplay), Steven Roger...
# 5   John Hamburg (screenplay), Larry Levin (screen...
# 6                                          Gaspar Noé
# 7                                Paul Thomas Anderson
# 8   Juliette Towhidi (screenplay), Cecelia Ahern (...
# 9                                        Kar-Wai Wong
# 10  Richard Maibaum (screenplay), Johanna Harwood ...
# 11         Adi Hasak (screenplay), Luc Besson (story)
# 12   John Requa, Glenn Ficarra, Steve McVicker (book)
# 13  Becky Albertalli (based upon the novel "Simon ...
# 14  Ryan Murphy (screenplay), Jennifer Salt (scree...
# 15                                        Woody Allen
# 16                                         Josh Boone
# 17                                Colin Patrick Lynch
# 18                                       Yann Samuell
# 19                   Goran Dukic, Etgar Keret (novel)
# 20                           Mike Myers, Graham Gordy
# 21                                    Lukas Moodysson
# 22  Hu Hong (segment), Yao Meng (segment), Israel ...
# 23         David H. Steinberg, Adam Herz (characters)
# 24                                         Gaspar Noé
# 25                                      Michael Moore
# 26  Shana Feste (screenplay), Joshua Safran (scree...
# 27                           Eve Ahlert, Dennis Drake
# 28                                      Richard Price
# 29                                        Woody Allen
# 30                                        Woody Allen
# 31                                         Gaspar Noé
# 32      Larry Doyle (screenplay), Larry Doyle (novel)
# 33                                       Justin Lader
# 34                                  Michael Swerdlick
# 35  Michael Shaara (novel), Dana Stevens (screenplay)
# 36                                       Jacob Forman
# 37                        Brandon Camp, Mike Thompson
# 38  Claire Cook (novel), Gary David Goldberg (scre...
# 39                                        Erich Segal
#
#                                                Actors  \
# 0   Steve Carell, Ryan Gosling, Julianne Moore, Em...
# 1   Peter Sellers, George C. Scott, Sterling Hayde...
# 2   Bill Nighy, Gregor Fisher, Rory MacGregor, Col...
# 3   Geoffrey Rush, Tom Wilkinson, Steven O'Donnell...
# 4   Hilary Swank, Gerard Butler, Lisa Kudrow, Gina...
# 5   Paul Rudd, Rashida Jones, Sarah Burns, Greg Le...
# 6   Aomi Muyock, Karl Glusman, Klara Kristin, Ugo Fox
# 7   Adam Sandler, Jason Andrews, Don McManus, Emil...
# 8   Lily Collins, Sam Claflin, Christian Cooke, Ja...
# 9   Maggie Cheung, Tony Chiu-Wai Leung, Ping Lam S...
# 10  Sean Connery, Daniela Bianchi, Pedro Armendári...
# 11  John Travolta, Jonathan Rhys Meyers, Kasia Smu...
# 12  Jim Carrey, Ewan McGregor, Leslie Mann, Rodrig...
# 13  Nick Robinson, Jennifer Garner, Josh Duhamel, ...
# 14  Julia Roberts, I. Gusti Ayu Puspawati, Hadi Su...
# 15  Pierluigi Marchionne, Flavio Parenti, Alison P...
# 16  Greg Kinnear, Jennifer Connelly, Lily Collins,...
# 17  Amanda Peet, Ashton Kutcher, Taryn Manning, Ai...
# 18  Guillaume Canet, Marion Cotillard, Thibault Ve...
# 19  Will Arnett, Abraham Benrubi, Leslie Bibb, Mar...
# 20  Jessica Simpson, Kanye West, Mike Myers, Deepa...
# 21  Alexandra Dahlström, Rebecka Liljeberg, Erica ...
# 22  Hayden Christensen, Andy Garcia, Rachel Bilson...
# 23  Eugene Levy, Bug Hall, Kevin M. Horton, Brando...
# 24  Aomi Muyock, Karl Glusman, Klara Kristin, Ugo Fox
# 25  William Black, Jimmy Carter, Elijah Cummings, ...
# 26  Alex Pettyfer, Gabriella Wilde, Bruce Greenwoo...
# 27  Renée Zellweger, Ewan McGregor, Sarah Paulson,...
# 28  Al Pacino, Ellen Barkin, John Goodman, Michael...
# 29  Edward Norton, Drew Barrymore, Diva Gray, Ami ...
# 30  Woody Allen, Diane Keaton, Georges Adet, Robin...
# 31  Aomi Muyock, Karl Glusman, Klara Kristin, Ugo Fox
# 32  Hayden Panettiere, Paul Rust, Jack Carpenter, ...
# 33  Mark Duplass, Elisabeth Moss, Ted Danson, Kian...
# 34  Patrick Dempsey, Amanda Peterson, Courtney Gai...
# 35  Kevin Costner, Kelly Preston, John C. Reilly, ...
# 36  Amber Heard, Anson Mount, Michael Welch, Whitn...
# 37  Aaron Eckhart, Jennifer Aniston, Dan Fogler, J...
# 38  Diane Lane, John Cusack, Elizabeth Perkins, Ch...
# 39  Ali MacGraw, Ryan O'Neal, John Marley, Ray Mil...
#
#                                                  Plot  ... Metascore  \
# 0   A middle-aged husband's life changes dramatica...  ...        68
# 1   An insane general triggers a path to nuclear h...  ...        97
# 2   Follows the lives of eight very different coup...  ...        55
# 3   The world's greatest ever playwright, William ...  ...        87
# 4   A young widow discovers that her late husband ...  ...        39
# 5   Friendless Peter Klaven goes on a series of ma...  ...        70
# 6   Murphy is an American living in Paris who ente...  ...        51
# 7   A psychologically troubled novelty supplier is...  ...        78
# 8   Rosie and Alex have been best friends since th...  ...        44
# 9   Two neighbors, a woman and a man, form a stron...  ...        85
# 10  James Bond willingly falls into an assassinati...  ...        85
# 11  In Paris, a young employee in the office of th...  ...        42
# 12  A cop turns con man once he comes out of the c...  ...        65
# 13  Simon Spier keeps a huge secret from his famil...  ...        72
# 14  A married woman realizes how unhappy her marri...  ...        50
# 15  The lives of some visitors and residents of Ro...  ...        54
# 16  An acclaimed writer, his ex-wife, and their te...  ...        49
# 17  Unaquainted Emily and Oliver join the mile hig...  ...        48
# 18  As adults, best friends Julien and Sophie cont...  ...        45
# 19  A film set in a strange afterlife way station ...  ...        62
# 20  Pitka, an American raised outside of his count...  ...        24
# 21  Two teenage girls in small-town Sweden. Elin i...  ...        73
# 22  Eleven love stories set in one of the most lov...  ...        49
# 23  Ten years after the first American Pie movie, ...  ...       N/A
# 24  Murphy is an American living in Paris who ente...  ...        51
# 25  An examination of the social costs of corporat...  ...        61
# 26  The story of a privileged girl and a charismat...  ...        30
# 27  In 1962 New York City, love blossoms between a...  ...        52
# 28  A detective investigating a series of murders ...  ...        66
# 29  A New York girl sets her father up with a beau...  ...       N/A
# 30  In czarist Russia, a neurotic soldier and his ...  ...        89
# 31  Murphy is an American living in Paris who ente...  ...        51
# 32  A nerdy valedictorian proclaims his love for B...  ...        32
# 33  A troubled couple vacate to a beautiful getawa...  ...        66
# 34  A nerdy outcast secretly pays the most popular...  ...        36
# 35  After 19 years of playing the game he's loved ...  ...        43
# 36  A group of high-schoolers invite Mandy Lane, a...  ...        44
# 37  A widower whose book about coping with loss tu...  ...        33
# 38  A forty-something preschool teacher looks to t...  ...        46
# 39  A boy and a girl from different backgrounds fa...  ...        84
#
#    imdbRating imdbVotes     imdbID   Type          DVD    BoxOffice  \
# 0         7.4   447,664  tt1570728  movie  01 Nov 2011  $83,300,000
# 1         8.4   427,212  tt0057012  movie  02 Nov 2004          N/A
# 2         7.6   405,898  tt0314331  movie  27 Apr 2004  $59,365,105
# 3         7.1   205,961  tt0138097  movie  10 Aug 1999          N/A
# 4         7.0   194,541  tt0431308  movie  05 Feb 2008          N/A
# 5         7.0   188,613  tt1155056  movie  11 Aug 2009  $71,300,000
# 6         6.1    40,472  tt3774694  movie  15 Mar 2016     $176,061
# 7         7.3   137,629  tt0272338  movie  24 Jun 2003  $17,800,000
# 8         7.2   111,376  tt1638002  movie  05 May 2015          N/A
# 9         8.1   111,148  tt0118694  movie  05 Mar 2002          N/A
# 10        7.4   109,544  tt0057076  movie  28 Mar 2006          N/A
# 11        6.5   108,795  tt1179034  movie  08 Jun 2010  $23,979,741
# 12        6.6    88,737  tt1045772  movie  05 Apr 2011   $2,026,852
# 13        7.6    87,922  tt5164432  movie  12 Jun 2018          N/A
# 14        5.8    81,783  tt0879870  movie  23 Nov 2010  $80,574,010
# 15        6.3    81,074  tt1859650  movie  15 Jan 2013  $16,500,000
# 16        7.2    80,150  tt2205697  movie  08 Oct 2013     $100,000
# 17        6.6    65,452  tt0391304  movie  23 Aug 2005  $21,835,784
# 18        7.6    64,787  tt0364517  movie  19 Oct 2004     $449,282
# 19        7.3    51,998  tt0477139  movie  18 May 1999          N/A
# 20        3.8    48,853  tt0811138  movie  16 Sep 2008  $32,178,777
# 21        7.5    48,314  tt0150662  movie  03 Oct 2000          N/A
# 22        6.3    43,704  tt0808399  movie  02 Feb 2010   $1,600,000
# 23        4.8    41,633  tt1407050  movie  22 Dec 2009          N/A
# 24        6.1    40,472  tt3774694  movie  15 Mar 2016     $176,061
# 25        7.4    40,021  tt1232207  movie  09 Mar 2010  $14,342,792
# 26        6.3    38,960  tt2318092  movie  27 May 2014          N/A
# 27        6.2    37,968  tt0309530  movie  07 Oct 2003  $20,186,516
# 28        6.8    35,727  tt0098273  movie  26 May 1998          N/A
# 29        6.7    34,091  tt0116242  movie  17 Aug 1999          N/A
# 30        7.7    33,643  tt0073312  movie  05 Jul 2000          N/A
# 31        6.1    40,472  tt3774694  movie  15 Mar 2016     $176,061
# 32        5.3    32,382  tt1032815  movie  03 Nov 2009  $14,800,000
# 33        7.1    32,210  tt2756032  movie  03 Nov 2014     $511,635
# 34        6.8    30,472  tt0092718  movie  13 Aug 2002          N/A
# 35        6.6    30,344  tt0126916  movie  15 Aug 2000          N/A
# 36        5.5    30,208  tt0490076  movie  03 Dec 2013          N/A
# 37        5.6    29,592  tt0899106  movie  02 Feb 2010  $22,927,390
# 38        5.9    29,580  tt0417001  movie  20 Dec 2005  $43,800,000
# 39        6.9    28,070  tt0066011  movie  24 Apr 2001          N/A
#
#                       Production Website Response
# 0          Warner Bros. Pictures     N/A     True
# 1                  Sony Pictures     N/A     True
# 2             Universal Pictures     N/A     True
# 3                        Miramax     N/A     True
# 4                            N/A     N/A     True
# 5           Dreamworks/Paramount     N/A     True
# 6                        Alchemy     N/A     True
# 7              Columbia Pictures     N/A     True
# 8                    Film Arcade     N/A     True
# 9                      USA Films     N/A     True
# 10                United Artists     N/A     True
# 11               Lionsgate Films     N/A     True
# 12          Roadside Attractions     N/A     True
# 13              20th Century Fox     N/A     True
# 14                 Sony Pictures     N/A     True
# 15        Sony Pictures Classics     N/A     True
# 16       Millenium Entertainment     N/A     True
# 17           Touchstone Pictures     N/A     True
# 18            Paramount Classics     N/A     True
# 19                           N/A     N/A     True
# 20            Paramount Pictures     N/A     True
# 21              Strand Releasing     N/A     True
# 22         Vivendi Entertainment     N/A     True
# 23  Universal Studios Home Video     N/A     True
# 24                       Alchemy     N/A     True
# 25                Overture Films     N/A     True
# 26            Universal Pictures     N/A     True
# 27              20th Century Fox     N/A     True
# 28      MCA Universal Home Video     N/A     True
# 29               Sweetland Films     N/A     True
# 30                United Artists     N/A     True
# 31                       Alchemy     N/A     True
# 32              20th Century Fox     N/A     True
# 33                    Radius-TWC     N/A     True
# 34          Buena Vista Pictures     N/A     True
# 35            Universal Pictures     N/A     True
# 36                    Radius-TWC     N/A     True
# 37            Universal Pictures     N/A     True
# 38         Warner Bros. Pictures     N/A     True
# 39            Paramount Pictures     N/A     True
#
# [40 rows x 25 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
#??????? maybe need to flatten again to get the info from the ratings column

#check how influences the release date being closer to valentines day (check in number of days..) to the rating, 
#if there is correlation

#could create another df with title and ratings from different sources, choose which source to scrap

#BUT

#have IMDB rating already in another column extracted

# %%
love_movies.head()

#from wiki table: 
#title, released,runtime, director, writer, actors, language, country, box office (see that not matching) 
#but it's matchin to gross worldwide from IMDB, production

#will need to delet last two columns: website and Response
#from wiki can add production company, because in API under production have distribution company AND budget
#can update some NAs from wiki, like box office

#url to use: https://en.wikipedia.org/wiki/Crazy,_Stupid,_Love
#will need to format again the names





#from IMDB
#search by this url: https://www.imdb.com/title/tt1570728/
#could check the main info, need to select which info going to check in wiki, api and imdb
#could extract quates from imdb and add them to the df, let's say we will need to use them for the MKT materials
# Out:
#                                                                   Title  Year  \
# 0  Crazy, Stupid, Love.                                                  2011
# 1  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb  1964
# 2  Love, Actually                                                        2003
# 3  Shakespeare in Love                                                   1998
# 4  P.S. I Love You                                                       2007
#
#    Rated     Released  Runtime                            Genre  \
# 0  PG-13  29 Jul 2011  118 min  Comedy, Drama, Romance
# 1  PG     29 Jan 1964  95 min   Comedy
# 2  R      14 Nov 2003  135 min  Comedy, Drama, Romance
# 3  R      08 Jan 1999  123 min  Comedy, Drama, History, Romance
# 4  PG-13  21 Dec 2007  126 min  Comedy, Drama, Romance
#
#                     Director  \
# 0  Glenn Ficarra, John Requa
# 1  Stanley Kubrick
# 2  Richard Curtis
# 3  John Madden
# 4  Richard LaGravenese
#
#                                                                                                                                    Writer  \
# 0  Dan Fogelman
# 1  Stanley Kubrick (screenplay), Terry Southern (screenplay), Peter George (screenplay), Peter George (based on the book: "Red Alert" by)
# 2  Richard Curtis
# 3  Marc Norman, Tom Stoppard
# 4  Richard LaGravenese (screenplay), Steven Rogers (screenplay), Cecelia Ahern (novel)
#
#                                                          Actors  \
# 0  Steve Carell, Ryan Gosling, Julianne Moore, Emma Stone
# 1  Peter Sellers, George C. Scott, Sterling Hayden, Keenan Wynn
# 2  Bill Nighy, Gregor Fisher, Rory MacGregor, Colin Firth
# 3  Geoffrey Rush, Tom Wilkinson, Steven O'Donnell, Tim McMullan
# 4  Hilary Swank, Gerard Butler, Lisa Kudrow, Gina Gershon
#
#                                                                                                                                                                                                        Plot  \
# 0  A middle-aged husband's life changes dramatically when his wife asks him for a divorce. He seeks to rediscover his manhood with the help of a newfound friend, Jacob, learning to pick up girls at bars.
# 1  An insane general triggers a path to nuclear holocaust that a War Room full of politicians and generals frantically tries to stop.
# 2  Follows the lives of eight very different couples in dealing with their love lives in various loosely interrelated tales all set during a frantic month before Christmas in London, England.
# 3  The world's greatest ever playwright, William Shakespeare, is young, out of ideas and short of cash, but meets his ideal woman and is inspired to write one of his most famous plays.
# 4  A young widow discovers that her late husband has left her 10 messages intended to help ease her pain and start a new life.
#
#                       Language          Country  \
# 0  English                      USA
# 1  English, Russian             UK, USA
# 2  English, Portuguese, French  UK, USA, France
# 3  English                      USA, UK
# 4  English                      USA
#
#                                                              Awards  \
# 0  Nominated for 1 Golden Globe. Another 3 wins & 22 nominations.
# 1  Nominated for 4 Oscars. Another 13 wins & 7 nominations.
# 2  Nominated for 2 Golden Globes. Another 10 wins & 27 nominations.
# 3  Won 7 Oscars. Another 57 wins & 87 nominations.
# 4  2 wins & 4 nominations.
#
#                                                                                                                                Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMTg2MjkwMTM0NF5BMl5BanBnXkFtZTcwMzc4NDg2NQ@@._V1_SX300.jpg
# 1  https://m.media-amazon.com/images/M/MV5BZWI3ZTMxNjctMjdlNS00NmUwLWFiM2YtZDUyY2I3N2MxYTE0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SX300.jpg
# 2  https://m.media-amazon.com/images/M/MV5BMTY4NjQ5NDc0Nl5BMl5BanBnXkFtZTYwNjk5NDM3._V1_SX300.jpg
# 3  https://m.media-amazon.com/images/M/MV5BM2ZkNjM5MjEtNTBlMC00OTI5LTgyYmEtZDljMzNmNzhiNzY0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SX300.jpg
# 4  https://m.media-amazon.com/images/M/MV5BNTg2MDg4MjI5NV5BMl5BanBnXkFtZTcwMzQ0MDczMw@@._V1_SX300.jpg
#
#                                                                                                                                                   Ratings  \
# 0  [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}, {'Source': 'Rotten Tomatoes', 'Value': '79%'}, {'Source': 'Metacritic', 'Value': '68/100'}]
# 1  [{'Source': 'Internet Movie Database', 'Value': '8.4/10'}, {'Source': 'Rotten Tomatoes', 'Value': '98%'}, {'Source': 'Metacritic', 'Value': '97/100'}]
# 2  [{'Source': 'Internet Movie Database', 'Value': '7.6/10'}, {'Source': 'Rotten Tomatoes', 'Value': '64%'}, {'Source': 'Metacritic', 'Value': '55/100'}]
# 3  [{'Source': 'Internet Movie Database', 'Value': '7.1/10'}, {'Source': 'Rotten Tomatoes', 'Value': '92%'}, {'Source': 'Metacritic', 'Value': '87/100'}]
# 4  [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}, {'Source': 'Metacritic', 'Value': '39/100'}]
#
#   Metascore imdbRating imdbVotes     imdbID   Type          DVD    BoxOffice  \
# 0  68        7.4        447,664   tt1570728  movie  01 Nov 2011  $83,300,000
# 1  97        8.4        427,212   tt0057012  movie  02 Nov 2004  N/A
# 2  55        7.6        405,898   tt0314331  movie  27 Apr 2004  $59,365,105
# 3  87        7.1        205,961   tt0138097  movie  10 Aug 1999  N/A
# 4  39        7.0        194,541   tt0431308  movie  05 Feb 2008  N/A
#
#               Production Website Response
# 0  Warner Bros. Pictures  N/A     True
# 1  Sony Pictures          N/A     True
# 2  Universal Pictures     N/A     True
# 3  Miramax                N/A     True
# 4  N/A                    N/A     True

# %% [markdown]
# ## WEB SCRAPING <br>
#
# - For the web scraping portion of the project, you will need to scrape the HTML from your chosen page, parse the HTML to extract the necessary information, and either save the results to a text (txt) file if it is text or into a CSV file if it is tabular data.

# %%
#for some urls will need to add (film) at the end, but only if the book, so will check if get an error 
#(if don't find the table), and if so, add (film) to the end of the URL

# %%
url = 'https://en.wikipedia.org/wiki/Crazy,_Stupid,_Love'
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Crazy, Stupid, Love - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"Xkb-vwpAMFIAAHfIJ-AAAADV","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Crazy,_Stupid,_Love","wgTitle":"Crazy, Stupid, Love","wgCurRevisionId":938616522,"wgRevisionId":938616522,"wgArticleId":28880684,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from June 2012","Commons category link is on Wikidata","2011 films","English-language films","2010s romantic comedy films","American films","American romantic comedy films",
# "Films directed by Glenn Ficarra and John Requa","Films produced by Denise Di Novi","Films scored by Christophe Beck","Films set in Los Angeles","Films shot in Los Angeles","Midlife crisis films","Warner Bros. films","Films about divorce"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Crazy,_Stupid,_Love","wgRelevantArticleId":28880684,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q519490","wgCentralAuthMobileDomain":!1,
# "wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","mediawiki.toc.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","skins.vector.js","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar",
# "ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@tffin",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cmediawiki.toc.styles%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.35.0-wmf.18" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/en/7/78/CrazyStupidLovePoster.jpg" property="og:image"/>
#   <link href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Crazy,_Stupid,_Love" rel="alternate"/>
#   <link href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/Crazy,_Stupid,_Love" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Crazy_Stupid_Love rootpage-Crazy_Stupid_Love skin-vector action-view">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     <i>
#      Crazy, Stupid, Love
#     </i>
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#p-search">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="hatnote navigation-not-searchable" role="note">
#        For the song by Cheryl Cole, see
#        <a href="/wiki/Crazy_Stupid_Love_(song)" title="Crazy Stupid Love (song)">
#         Crazy Stupid Love (song)
#        </a>
#        .
#       </div>
#       <p class="mw-empty-elt">
#       </p>
#       <table class="infobox vevent" style="width:22em;font-size:90%;">
#        <tbody>
#         <tr>
#          <th class="summary" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:110%;font-style:italic;">
#           Crazy, Stupid, Love.
#          </th>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center">
#           <a class="image" href="/wiki/File:CrazyStupidLovePoster.jpg">
#            <img alt="CrazyStupidLovePoster.jpg" class="thumbborder" data-file-height="326" data-file-width="220" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/7/78/CrazyStupidLovePoster.jpg" width="220"/>
#           </a>
#           <div style="font-size:95%;padding:0.35em 0.35em 0.25em;line-height:1.25em;">
#            Theatrical release poster
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Directed by
#          </th>
#          <td>
#           <div class="plainlist">
#            <ul>
#             <li>
#              <a href="/wiki/Glenn_Ficarra" title="Glenn Ficarra">
#               Glenn Ficarra
#              </a>
#             </li>
#             <li>
#              <a href="/wiki/John_Requa" title="John Requa">
#               John Requa
#              </a>
#             </li>
#            </ul>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Produced by
#          </th>
#          <td>
#           <div class="plainlist">
#            <ul>
#             <li>
#              <a href="/wiki/Steve_Carell" title="Steve Carell">
#               Steve Carell
#              </a>
#              <sup class="reference" id="cite_ref-HR_2009-01-13_1-0">
#               <a href="#cite_note-HR_2009-01-13-1">
#                [1]
#               </a>
#              </sup>
#             </li>
#             <li>
#              <a href="/wiki/Denise_Di_Novi" title="Denise Di Novi">
#               Denise Di Novi
#              </a>
#             </li>
#            </ul>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Written by
#          </th>
#          <td>
#           <a href="/wiki/Dan_Fogelman" title="Dan Fogelman">
#            Dan Fogelman
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Starring
#          </th>
#          <td>
#           <div class="plainlist">
#            <ul>
#             <li>
#              <a href="/wiki/Steve_Carell" title="Steve Carell">
#               Steve Carell
#              </a>
#             </li>
#             <li>
#              <a href="/wiki/Ryan_Gosling" title="Ryan Gosling">
#               Ryan Gosling
#              </a>
#             </li>
#             <li>
#              <a href="/wiki/Julianne_Moore" title="Julianne Moore">
#               Julianne Moore
#              </a>
#             </li>
#             <li>
#              <a href="/wiki/Emma_Stone" title="Emma Stone">
#               Emma Stone
#              </a>
#             </li>
#             <li>
#              <a href="/wiki/Marisa_Tomei" title="Marisa Tomei">
#               Marisa Tomei
#              </a>
#             </li>
#             <li>
#              <a href="/wiki/Kevin_Bacon" title="Kevin Bacon">
#               Kevin Bacon
#              </a>
#             </li>
#            </ul>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Music by
#          </th>
#          <td>
#           <div class="plainlist">
#            <ul>
#             <li>
#              <a href="/wiki/Christophe_Beck" title="Christophe Beck">
#               Christophe Beck
#              </a>
#             </li>
#             <li>
#              <a class="mw-redirect" href="/wiki/Nick_Urata" title="Nick Urata">
#               Nick Urata
#              </a>
#             </li>
#            </ul>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Cinematography
#          </th>
#          <td>
#           <a href="/wiki/Andrew_Dunn_(cinematographer)" title="Andrew Dunn (cinematographer)">
#            Andrew Dunn
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Edited by
#          </th>
#          <td>
#           <a href="/wiki/Lee_Haxall" title="Lee Haxall">
#            Lee Haxall
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           <div style="padding:0.1em 0;line-height:1.2em;">
#            Production
#            <br/>
#            company
#           </div>
#          </th>
#          <td>
#           <div style="vertical-align:middle;">
#            <a href="/wiki/Steve_Carell" title="Steve Carell">
#             Carousel Productions
#            </a>
#            <sup class="reference" id="cite_ref-HR_2009-01-13_1-1">
#             <a href="#cite_note-HR_2009-01-13-1">
#              [1]
#             </a>
#            </sup>
#            <br/>
#            <a href="/wiki/Denise_Di_Novi" title="Denise Di Novi">
#             Di Novi Pictures
#            </a>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Distributed by
#          </th>
#          <td>
#           <a class="mw-redirect" href="/wiki/Warner_Bros._Pictures" title="Warner Bros. Pictures">
#            Warner Bros. Pictures
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           <div style="padding:0.1em 0;line-height:1.2em;white-space:normal;">
#            Release date
#           </div>
#          </th>
#          <td>
#           <div class="plainlist">
#            <ul>
#             <li>
#              July 19, 2011
#              <span style="display:none">
#               (
#               <span class="bday dtstart published updated">
#                2011-07-19
#               </span>
#               )
#              </span>
#              (
#              <a href="/wiki/New_York_City" title="New York City">
#               New York City
#              </a>
#              )
#             </li>
#             <li>
#              July 29, 2011
#              <span style="display:none">
#               (
#               <span class="bday dtstart published updated">
#                2011-07-29
#               </span>
#               )
#              </span>
#              (United States)
#             </li>
#            </ul>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           <div style="padding:0.1em 0;line-height:1.2em;white-space:normal;">
#            Running time
#           </div>
#          </th>
#          <td>
#           118 minutes
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Country
#          </th>
#          <td>
#           United States
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Language
#          </th>
#          <td>
#           English
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Budget
#          </th>
#          <td>
#           $50 million
#           <sup class="reference" id="cite_ref-BoxOfficeMojo_2-0">
#            <a href="#cite_note-BoxOfficeMojo-2">
#             [2]
#            </a>
#           </sup>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Box office
#          </th>
#          <td>
#           $145 million
#           <sup class="reference" id="cite_ref-BoxOfficeMojo_2-1">
#            <a href="#cite_note-BoxOfficeMojo-2">
#             [2]
#            </a>
#           </sup>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <p>
#        <i>
#         <b>
#          Crazy, Stupid, Love
#         </b>
#        </i>
#        is a 2011 American
#        <a href="/wiki/Romantic_comedy" title="Romantic comedy">
#         romantic comedy
#        </a>
#        film directed by
#        <a href="/wiki/Glenn_Ficarra" title="Glenn Ficarra">
#         Glenn Ficarra
#        </a>
#        and
#        <a href="/wiki/John_Requa" title="John Requa">
#         John Requa
#        </a>
#        , written by
#        <a href="/wiki/Dan_Fogelman" title="Dan Fogelman">
#         Dan Fogelman
#        </a>
#        , and starring
#        <a href="/wiki/Steve_Carell" title="Steve Carell">
#         Steve Carell
#        </a>
#        ,
#        <a href="/wiki/Ryan_Gosling" title="Ryan Gosling">
#         Ryan Gosling
#        </a>
#        ,
#        <a href="/wiki/Julianne_Moore" title="Julianne Moore">
#         Julianne Moore
#        </a>
#        ,
#        <a href="/wiki/Emma_Stone" title="Emma Stone">
#         Emma Stone
#        </a>
#        ,
#        <a href="/wiki/Marisa_Tomei" title="Marisa Tomei">
#         Marisa Tomei
#        </a>
#        , and
#        <a href="/wiki/Kevin_Bacon" title="Kevin Bacon">
#         Kevin Bacon
#        </a>
#        . It follows a recently
#        <a href="/wiki/Divorce_in_the_United_States" title="Divorce in the United States">
#         divorced
#        </a>
#        man who seeks to rediscover his manhood and is taught how to pick up women at bars.
#       </p>
#       <p>
#        The film was released in the United States by
#        <a class="mw-redirect" href="/wiki/Warner_Bros._Pictures" title="Warner Bros. Pictures">
#         Warner Bros. Pictures
#        </a>
#        on July 29, 2011, grossing over $142 million against its $50 million budget. Gosling was nominated for the
#        <a class="mw-redirect" href="/wiki/Golden_Globe_Award" title="Golden Globe Award">
#         Golden Globe Award
#        </a>
#        for
#        <a href="/wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Motion_Picture_Musical_or_Comedy" title="Golden Globe Award for Best Actor – Motion Picture Musical or Comedy">
#         Best Actor – Motion Picture Musical or Comedy
#        </a>
#        for his performance.
#       </p>
#       <div class="toc" id="toc">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2>
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Plot">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Plot
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-2">
#          <a href="#Cast">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            Cast
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-3">
#          <a href="#Production">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            Production
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-4">
#          <a href="#Release">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            Release
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-5">
#            <a href="#Box_office">
#             <span class="tocnumber">
#              4.1
#             </span>
#             <span class="toctext">
#              Box office
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-6">
#            <a href="#Home_media">
#             <span class="tocnumber">
#              4.2
#             </span>
#             <span class="toctext">
#              Home media
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-7">
#          <a href="#Critical_response">
#           <span class="tocnumber">
#            5
#           </span>
#           <span class="toctext">
#            Critical response
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-8">
#            <a href="#Accolades">
#             <span class="tocnumber">
#              5.1
#             </span>
#             <span class="toctext">
#              Accolades
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-9">
#          <a href="#References">
#           <span class="tocnumber">
#            6
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-10">
#          <a href="#External_links">
#           <span class="tocnumber">
#            7
#           </span>
#           <span class="toctext">
#            External links
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="Plot">
#         Plot
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=1" title="Edit section: Plot">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        The film begins with Cal Weaver, (
#        <a href="/wiki/Steve_Carell" title="Steve Carell">
#         Steve Carell
#        </a>
#        ) a middle-aged man, being told by his wife Emily (
#        <a href="/wiki/Julianne_Moore" title="Julianne Moore">
#         Julianne Moore
#        </a>
#        ) – with whom he has been married for almost 25 years – that she has cheated on him with a coworker, David Lindhagen (
#        <a href="/wiki/Kevin_Bacon" title="Kevin Bacon">
#         Kevin Bacon
#        </a>
#        ), and wants a divorce. On the way home from dinner, Cal refuses to speak to Emily while she drives and tries to verbalize where their marriage went wrong and what led her to cheat. Cal requests that Emily stop talking but she continues, Cal opens the passenger door and rolls out of the moving car. Cal and Emily arrive home where 17-year-old Jessica Riley (
#        <a href="/wiki/Analeigh_Tipton" title="Analeigh Tipton">
#         Analeigh Tipton
#        </a>
#        ) is babysitting their middle-school-aged son (who is in love with Jessica) and youngest daughter. Jessica notices how beat up and dirty Cal looks (from having jumped out of the car) and asks what happened. Cal tells the truth about Mrs. Weaver wanting a divorce not realizing that his son Robbie (
#        <a href="/wiki/Jonah_Bobo" title="Jonah Bobo">
#         Jonah Bobo
#        </a>
#        ) is standing in the living room. Embarrassed and ashamed that Robbie had to find out that way, Cal offers to drive Jessica home. As Cal drops Jessica off she tries to cheer him up saying how Mrs. Weaver is crazy for wanting to divorce him. Before she can finish her speech and reveal to Cal that she has feelings for him, he thanks her for babysitting and drives home.
#       </p>
#       <p>
#        Cal moves into his own small apartment, leaving Robbie and his daughter Molly (
#        <a href="/wiki/Joey_King" title="Joey King">
#         Joey King
#        </a>
#        ) to live at the family house with Emily while they begin the divorce process. Cal goes to a local bar night after night, talking loudly about his divorce even when no one is listening. His behavior attracts the attention of a young man named Jacob Palmer (
#        <a href="/wiki/Ryan_Gosling" title="Ryan Gosling">
#         Ryan Gosling
#        </a>
#        ), a
#        <a href="/wiki/Promiscuity#Male_promiscuity" title="Promiscuity">
#         womanizer
#        </a>
#        who beds different women each night. Although the night before Cal showed up a young woman named Hannah (
#        <a href="/wiki/Emma_Stone" title="Emma Stone">
#         Emma Stone
#        </a>
#        ) rejected his advances.
#       </p>
#       <p>
#        Jacob takes pity on Cal and offers to teach him how to reinvent himself and become a confident man again, which will allow him to pick up women just like Jacob does. While Cal is skeptical of why Jacob wants to help him, he agrees to take his advice. After a makeover and lessons on how to converse with women, Cal seduces a woman named Kate (
#        <a href="/wiki/Marisa_Tomei" title="Marisa Tomei">
#         Marisa Tomei
#        </a>
#        ) at the bar. Kate asks Cal to call her, but having found his confidence for the first time in his life Cal begins to successfully seduce other women at the bar. He sees Emily again at Robbie's parent-teacher conference. Their interaction goes well until they discover that Robbie's teacher is Kate, whom Cal never called after their one-night stand. Angered that Cal won't admit how they know one another, Kate reveals to Emily that she and Cal have had sex together. Emily storms out of the parent-teacher conference. Cal catches up to her and confesses to having slept with nine women since their separation. Emily leaves in disgust and begins actively dating David.
#       </p>
#       <p>
#        Meanwhile, Hannah is expecting her boyfriend Richard (
#        <a href="/wiki/Josh_Groban" title="Josh Groban">
#         Josh Groban
#        </a>
#        ) to propose marriage while they celebrate her passing the bar exam. However, instead of a proposal he offers her a position at his law firm. Offended and hurt, Hannah storms out from the restaurant and returns to the bar where she originally rejected Jacob's advances. Finding him there she walks right up to Jacob and passionately kisses him, asking if Jacob still finds her attractive and wants to take her home. Hannah takes him by the hand and leads Jacob out of the bar. At his home, Hannah calls Jacob out on his process of seducing women. They playfully banter back and forth, Jacob realizing his standard pick-up lines and techniques don't fool Hannah. Cal tries to call Jacob but Jacob continually lets the calls go to voicemail. Jacob slowly begins to open up to Hannah as the night goes on; eventually they stay up into the early hours of the morning laughing and talking until Jacob passes out. Hannah kisses him on the cheek before falling asleep herself.
#       </p>
#       <p>
#        David takes Emily out for a nice dinner together, then walks her to her door to say goodnight. They are interrupted by Jessica, who is babysitting again. Emily tries to introduce David as just a co-worker who took her out for dinner after work but Jessica sees right through it. Emily asks how much she owes Jessica for babysitting and in response Jessica shares with Emily how Robbie and Molly are the only two kids she's ever babysat that always stay up until their dad gets home. In confusion, Emily asks what she is trying to say; Jessica tells her she does not want her "slut money" and proceeds to walk home.
#       </p>
#       <p>
#        Upon arriving home, Jessica decides to take several nude photos of herself to eventually give to Cal on the advice of her classmate Madison (
#        <a href="/wiki/Julianna_Guill" title="Julianna Guill">
#         Julianna Guill
#        </a>
#        ), who is known to have relationships with older men. Jessica prints and puts the photos into a card and envelope addressed to Cal and hides it in one of her clothing drawers.
#       </p>
#       <p>
#        Later, Emily calls Cal under the guise of needing help with the house's pilot light. Cal sees through the ruse because he has secretly been gardening at the family house at night after having a nightmare that David was doing all the yard work himself for Emily. Realizing that she called just because she too was missing him, Cal decides to try and win her back. Jacob finally returns Cal's calls and asks for advice about being in a real relationship and meeting his girlfriend's parents, as he is very nervous and never legitimately dated anyone before. Cal tells Jacob to just be himself and everything will be fine.
#       </p>
#       <p>
#        Jessica's mother, Claire (
#        <a href="/wiki/Beth_Littleford" title="Beth Littleford">
#         Beth Littleford
#        </a>
#        ), discovers Jessica's naked photos addressed to Cal while putting away laundry. She shows them to Jessica's father, Bernie (
#        <a href="/wiki/John_Carroll_Lynch" title="John Carroll Lynch">
#         John Carroll Lynch
#        </a>
#        ). Bernie becomes disgusted and enraged, believing that Cal is preying on his daughter and rushes out of the house to confront Cal. Jessica races after him to try to tell him the truth, that Cal has no idea she is in love with him or anything about the photos.
#       </p>
#       <p>
#        Cal, with the help of Robbie and Molly, creates a makeshift mini-golf set in their backyard to remind Emily of their first date. The kids lead Emily into the backyard where Cal is waiting. Before Cal can tell Emily how he still feels, Jacob and Hannah show up at the house, and Hannah is revealed to be Cal and Emily's first daughter born to them right out of high school. Cal is appalled that Jacob is dating his daughter, and immediately forbids her from seeing him. Before Hannah can get an answer on how Cal and Jacob know one another, Bernie shows up and attacks Cal. Jessica arrives as Bernie and Cal wrestle on the ground and tells her father that Cal knew nothing of the pictures or that she was in love with him. Robbie is devastated that Jessica loves his dad, not him. As all this is going on David arrives in the backyard to return Emily's sweater that she left in his car the previous date night. Jacob asks David if his name is Lindhagen and when David replies "yes," Jacob punches him in the face for the pain he caused Cal. Cal, Jacob, David, and Bernie then get into a scuffle which is soon broken up by the police. Cal starts spending time at the bar again and receives a visit from Jacob, who confesses that he is in love with Hannah and has begun to re-evaluate his life as a result. Cal replies that he is happy that Jacob is a changed man but does not approve of Jacob and Hannah's relationship, having seen Jacob's former lifestyle. Jacob resigns without harboring any ill feelings; rather, he expresses his respect for Cal and praises him for being a great father.
#       </p>
#       <p>
#        At Robbie's eighth-grade graduation, Robbie is the
#        <a href="/wiki/Salutatorian" title="Salutatorian">
#         salutatorian
#        </a>
#        and begins to give a pessimistic speech about how he no longer believes in true love and
#        <a href="/wiki/Soulmate" title="Soulmate">
#         soulmates
#        </a>
#        . Cal stops him and instead begins to recount his courtship with Emily to the audience, saying that, while he does not know if things will work out, he will never give up on Emily. With renewed faith, Robbie reaffirms his love for Jessica, to the audience's applause. After the ceremony, Cal gives Jacob and Hannah his blessing. Jessica gives Robbie an envelope containing the nude photos of herself that were originally intended for Cal to "get him through high school." Cal and Emily have a laugh talking about the events that have transpired the past year, hinting that they might get back together.
#       </p>
#       <h2>
#        <span class="mw-headline" id="Cast">
#         Cast
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=2" title="Edit section: Cast">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <div class="div-col columns column-width" style="-moz-column-width: 22em; -webkit-column-width: 22em; column-width: 22em;">
#        <ul>
#         <li>
#          <a href="/wiki/Steve_Carell" title="Steve Carell">
#           Steve Carell
#          </a>
#          as Cal Weaver
#         </li>
#         <li>
#          <a href="/wiki/Ryan_Gosling" title="Ryan Gosling">
#           Ryan Gosling
#          </a>
#          as Jacob Palmer
#         </li>
#         <li>
#          <a href="/wiki/Julianne_Moore" title="Julianne Moore">
#           Julianne Moore
#          </a>
#          as Emily Weaver
#         </li>
#         <li>
#          <a href="/wiki/Emma_Stone" title="Emma Stone">
#           Emma Stone
#          </a>
#          as Hannah Weaver
#         </li>
#         <li>
#          <a href="/wiki/Marisa_Tomei" title="Marisa Tomei">
#           Marisa Tomei
#          </a>
#          as Kate Tafferty
#         </li>
#         <li>
#          <a href="/wiki/Kevin_Bacon" title="Kevin Bacon">
#           Kevin Bacon
#          </a>
#          as David Lindhagen
#         </li>
#         <li>
#          <a href="/wiki/John_Carroll_Lynch" title="John Carroll Lynch">
#           John Carroll Lynch
#          </a>
#          as Bernie Riley
#         </li>
#         <li>
#          <a href="/wiki/Josh_Groban" title="Josh Groban">
#           Josh Groban
#          </a>
#          as Richard
#         </li>
#         <li>
#          <a href="/wiki/Analeigh_Tipton" title="Analeigh Tipton">
#           Analeigh Tipton
#          </a>
#          as Jessica Riley
#         </li>
#         <li>
#          <a href="/wiki/Jonah_Bobo" title="Jonah Bobo">
#           Jonah Bobo
#          </a>
#          as Robbie Weaver
#         </li>
#         <li>
#          <a href="/wiki/Joey_King" title="Joey King">
#           Joey King
#          </a>
#          as Molly Weaver
#         </li>
#         <li>
#          <a href="/wiki/Beth_Littleford" title="Beth Littleford">
#           Beth Littleford
#          </a>
#          as Claire Riley
#         </li>
#         <li>
#          <a href="/wiki/Julianna_Guill" title="Julianna Guill">
#           Julianna Guill
#          </a>
#          as Madison
#         </li>
#         <li>
#          <a href="/wiki/Liza_Lapira" title="Liza Lapira">
#           Liza Lapira
#          </a>
#          as Liz
#         </li>
#         <li>
#          <a href="/wiki/Crystal_Reed" title="Crystal Reed">
#           Crystal Reed
#          </a>
#          as Amy Johnson
#         </li>
#         <li>
#          <a href="/wiki/Dan_Butler" title="Dan Butler">
#           Dan Butler
#          </a>
#          as Cal's boss
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="Production">
#         Production
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=3" title="Edit section: Production">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        The film was originally called
#        <i>
#         Untitled Marital Crisis Comedy
#        </i>
#        , as the actress Emma Stone claimed in an interview for
#        <i>
#         ANS
#        </i>
#        .
#        <sup class="reference" id="cite_ref-3">
#         <a href="#cite_note-3">
#          [3]
#         </a>
#        </sup>
#       </p>
#       <p>
#        <a href="/wiki/Dan_Fogelman" title="Dan Fogelman">
#         Dan Fogelman
#        </a>
#        started writing the screenplay in 2009 about love among a group of people.
#        <sup class="reference" id="cite_ref-LATimes1_4-0">
#         <a href="#cite_note-LATimes1-4">
#          [4]
#         </a>
#        </sup>
#        It is based on his own experiences and was written with
#        <a href="/wiki/Steve_Carell" title="Steve Carell">
#         Steve Carell
#        </a>
#        in mind.
#        <sup class="reference" id="cite_ref-ProdNotes_5-0">
#         <a href="#cite_note-ProdNotes-5">
#          [5]
#         </a>
#        </sup>
#        After Fogelman sent it to his manager, within a week Carell read it and came aboard the project.
#        <sup class="reference" id="cite_ref-6">
#         <a href="#cite_note-6">
#          [6]
#         </a>
#        </sup>
#        <sup class="reference" id="cite_ref-WGA_7-0">
#         <a href="#cite_note-WGA-7">
#          [7]
#         </a>
#        </sup>
#        In December 2009,
#        <a href="/wiki/Warner_Bros." title="Warner Bros.">
#         Warner Bros.
#        </a>
#        secured the rights of the then-untitled project for $2.5 million.
#        <sup class="reference" id="cite_ref-LATimes1_4-1">
#         <a href="#cite_note-LATimes1-4">
#          [4]
#         </a>
#        </sup>
#        <sup class="reference" id="cite_ref-8">
#         <a href="#cite_note-8">
#          [8]
#         </a>
#        </sup>
#        In January 2010, the film was in pre-production.
#        <sup class="reference" id="cite_ref-FilmSchool_9-0">
#         <a href="#cite_note-FilmSchool-9">
#          [9]
#         </a>
#        </sup>
#        On March 16, 2010,
#        <a href="/wiki/Emma_Stone" title="Emma Stone">
#         Emma Stone
#        </a>
#        was in negotiations to star in the film.
#        <sup class="reference" id="cite_ref-10">
#         <a href="#cite_note-10">
#          [10]
#         </a>
#        </sup>
#        On April 7, 2010,
#        <a href="/wiki/Analeigh_Tipton" title="Analeigh Tipton">
#         Analeigh Tipton
#        </a>
#        was in final talks to appear in the film.
#        <sup class="reference" id="cite_ref-11">
#         <a href="#cite_note-11">
#          [11]
#         </a>
#        </sup>
#        On April 12,
#        <a href="/wiki/Kevin_Bacon" title="Kevin Bacon">
#         Kevin Bacon
#        </a>
#        also joined the cast.
#        <sup class="reference" id="cite_ref-12">
#         <a href="#cite_note-12">
#          [12]
#         </a>
#        </sup>
#        It is the first project produced by Carell's Carousel Productions.
#        <sup class="reference" id="cite_ref-ProdNotes_5-1">
#         <a href="#cite_note-ProdNotes-5">
#          [5]
#         </a>
#        </sup>
#       </p>
#       <p>
#        <a href="/wiki/Principal_photography" title="Principal photography">
#         Principal photography
#        </a>
#        took place in and around
#        <a href="/wiki/Los_Angeles" title="Los Angeles">
#         Los Angeles
#        </a>
#        ,
#        <a href="/wiki/California" title="California">
#         California
#        </a>
#        . Filming started on April 16, 2010 and lasted for fifty three days.
#        <sup class="reference" id="cite_ref-13">
#         <a href="#cite_note-13">
#          [13]
#         </a>
#        </sup>
#        Locations included
#        <a href="/wiki/Westfield_Century_City" title="Westfield Century City">
#         Westfield Century City
#        </a>
#        mall,
#        <a href="/wiki/Ventura_Boulevard" title="Ventura Boulevard">
#         Ventura Boulevard
#        </a>
#        ,
#        <a href="/wiki/Hollywood_Hills" title="Hollywood Hills">
#         Hollywood Hills
#        </a>
#        where Jacob's house is located,
#        <a class="mw-redirect" href="/wiki/William_Howard_Taft_Charter_High_School_(Los_Angeles)" title="William Howard Taft Charter High School (Los Angeles)">
#         Taft High School
#        </a>
#        in Woodland Hills,
#        <a href="/wiki/Los_Angeles_Unified_School_District" title="Los Angeles Unified School District">
#         Portola Middle School
#        </a>
#        in Tarzana and
#        <a href="/wiki/Grant_High_School_(Los_Angeles)" title="Grant High School (Los Angeles)">
#         Grant High School
#        </a>
#        in Van Nuys, which stood for Robbie and Jessica's campuses, El Torito Grill at the
#        <a href="/wiki/Sherman_Oaks_Galleria" title="Sherman Oaks Galleria">
#         Sherman Oaks Galleria
#        </a>
#        and Equinox Fitness in
#        <a href="/wiki/Woodland_Hills,_Los_Angeles" title="Woodland Hills, Los Angeles">
#         Woodland Hills
#        </a>
#        , which became the sports club featured in the film.
#        <sup class="reference" id="cite_ref-ProdNotes_5-2">
#         <a href="#cite_note-ProdNotes-5">
#          [5]
#         </a>
#        </sup>
#        Before editing, the original cut was three hours long.
#        <sup class="reference" id="cite_ref-FilmSchool_9-1">
#         <a href="#cite_note-FilmSchool-9">
#          [9]
#         </a>
#        </sup>
#       </p>
#       <h2>
#        <span class="mw-headline" id="Release">
#         Release
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=4" title="Edit section: Release">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        The film's release was originally slated for April 22, 2011, but was later changed to July 29, 2011.
#        <sup class="reference" id="cite_ref-14">
#         <a href="#cite_note-14">
#          [14]
#         </a>
#        </sup>
#       </p>
#       <h3>
#        <span class="mw-headline" id="Box_office">
#         Box office
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=5" title="Edit section: Box office">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h3>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:SteveCarellFullPremiereSept2011.jpg">
#          <img alt="" class="thumbimage" data-file-height="731" data-file-width="353" decoding="async" height="352" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/SteveCarellFullPremiereSept2011.jpg/170px-SteveCarellFullPremiereSept2011.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/51/SteveCarellFullPremiereSept2011.jpg/255px-SteveCarellFullPremiereSept2011.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/51/SteveCarellFullPremiereSept2011.jpg/340px-SteveCarellFullPremiereSept2011.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:SteveCarellFullPremiereSept2011.jpg" title="Enlarge">
#           </a>
#          </div>
#          Carell at the Sydney premiere for the film in September 2011
#         </div>
#        </div>
#       </div>
#       <p>
#        <i>
#         Crazy, Stupid, Love
#        </i>
#        grossed $84.2 million in the United States and Canada and $58.5 million in other countries, for a worldwide total of $142.7 million, against its production of $50 million.
#        <sup class="reference" id="cite_ref-BoxOfficeMojo_2-2">
#         <a href="#cite_note-BoxOfficeMojo-2">
#          [2]
#         </a>
#        </sup>
#       </p>
#       <p>
#        The film opened at #5 at the North American box office on its opening weekend with $19.1 million.
#        <sup class="reference" id="cite_ref-15">
#         <a href="#cite_note-15">
#          [15]
#         </a>
#        </sup>
#       </p>
#       <h3>
#        <span class="mw-headline" id="Home_media">
#         Home media
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=6" title="Edit section: Home media">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h3>
#       <p>
#        <i>
#         Crazy, Stupid, Love
#        </i>
#        was released on
#        <a href="/wiki/DVD" title="DVD">
#         DVD
#        </a>
#        and
#        <a class="mw-redirect" href="/wiki/Blu-ray_disc" title="Blu-ray disc">
#         Blu-ray Disc
#        </a>
#        on November 6, 2011. DVD sales grossed $19.8 million and Blu-ray sales $5.6 million.
#        <sup class="reference" id="cite_ref-16">
#         <a href="#cite_note-16">
#          [16]
#         </a>
#        </sup>
#       </p>
#       <h2>
#        <span class="mw-headline" id="Critical_response">
#         Critical response
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Crazy,_Stupid,_Love&amp;action=edit&amp;section=7" title="Edit section: Critical response">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        On
#        <a href="/wiki/Rotten_Tomatoes" title="Rotten Tomatoes">
#         Rotten Tomatoes
#        </a>
#        , the film has an approval rating of 79% based on 232 reviews and an average rating of 6.92/10. The site's critical consensus reads, "It never lives up to the first part of its title, but
#        <i>
#         Crazy, Stupid, Love
#        </i>
#        <span class="nowrap" style="padding-left:0.1em;">
#         '
#        </span>
#        s unabashed sweetness -- and its terrifically talented cast -- more than make up for its flaws."
#        <sup class="reference" id="cite_ref-17">
#         <a href="#cite_note-17">
#          [17]
#         </a>
#        </sup>
#        On
#        <a href="/wiki/Metacritic" title="Metacritic">
#         Metacritic
#        </a>
#        , the film has a score of 68 out of 100 based on 40 critics, indicating "generally favorable reviews".
#        <sup class="reference" id="cite_ref-18">
#         <a href="#cite_note-18">
#          [18]
#         </a>
#        </sup>
#        Audiences polled by
#        <a href="/wiki/CinemaScore" title="CinemaScore">
#         CinemaScore
#        </a>
#        gave the film an average grade of "B+" on an A+ to F scale.
#        <sup class="reference" id="cite_ref-CinemaScore_19-0">
#         <a href="#cite_note-CinemaScore-19">
#          [19]
#         </a>
#        </sup>
#       </p>
#       <p>
#        <a href="/wiki/Roger_Ebert" title="Roger Ebert">
#         Roger Ebert
#        </a>
#        gave
#        <i>
#         Crazy, Stupid, Love
#        </i>
#        3 out of 4 stars and remarked that it "is a sweet romantic comedy about good-hearted people".
#        <sup class="reference" id="cite_ref-20">
#         <a href="#cite_note-20">
#          [20]
#         </a>
#        </sup>
#        <a href="/wiki/A._O._Scott" title="A. O. Scott">
#         A. O. Scott
#        </a>
#        of
#        <i>
#         <a href="/wiki/The_New_York_Times" title="The New York Times">
#          The New York Times
#         </a>
#        </i>
#        was also positive and gave the film 4 out of 5 stars, stating "
#        <i>
#         Crazy, Stupid, Love
#        </i>
#        is, on balance, remarkably sane and reasonably smart".
#        <sup class="reference" id="cite_ref-21">
#         <a href="#cite_note-21">
#          [21]
#         </a>
#        </sup>
#        Betsy Sharkey of the
#        <i>
#         <a href="/wiki/Los_Angeles_Times" title="Los Angeles Times">
#          Los Angeles Times
#         </a>
#        </i>
#        gave the film a 4 out of 5 review as well and said that it "conjures up the bittersweet magic of first loves, lasting loves, lost loves and all the loves in between".
#        <sup class="reference" id="cite_ref-22">
#         <a href="#cite_note-22">
#          [22]
#         </a>
#        </sup>
#       </p>
#       <p>
#        Some reviewers were less favorable, such as
#        <a href="/wiki/Christy_Lemire" title="Christy Lemire">
#         Christy Lemire
#        </a>
#        at the
#        <a href="/wiki/Associated_Press" title="Associated Press">
#         Associated Press
#        </a>
#        , who wrote that "it never gets crazy or stupid enough to make you truly fall in love with it", giving the film a 2 out of 4 rating.
#        <sup class="reference" id="cite_ref-23">
#         <a href="#cite_note-23">
#          [23]
#         </a>
#        </sup>
#        James Rocchi of
#        <i>
#         MSN Movies
#        </i>
#        was particularly critical, giving it 1 out of 5 and remarking that it is "a star-studded lump of fantasy and falsehood".
#        <sup class="reference" id="cite_ref-24">
#         <a href="#cite_note-24">
#          [24]
#         </a>
#        </sup>
#        The film was included in
#        <i>
#         <a href="/wiki/TV_Guide" title="TV Guide">
#          TV Guide
#         </a>
#        </i>
#        <span class="nowrap" style="padding-left:0.1em;">
#         's
#        </span>
#        "Best Movies of 2011" list.
#        <sup class="reference" id="cite_ref-25">
#         <a href="#cite_note-25">
#          [25]
#         </a>
#        </sup>
#       </p>
#       <h3>
#        <span class="mw-headline" id="Accolades">
#         Accolades
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
# ...
#          Wikimedia Commons
#         </a>
#        </li>
#        <li class="wb-otherproject-link wb-otherproject-wikiquote">
#         <a href="https://en.wikiquote.org/wiki/Crazy,_Stupid,_Love." hreflang="en">
#          Wikiquote
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-coll-print_export-label" class="portal" id="p-coll-print_export" role="navigation">
#      <h3 id="p-coll-print_export-label">
#       Print/export
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="coll-create_a_book">
#         <a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Crazy%2C+Stupid%2C+Love">
#          Create a book
#         </a>
#        </li>
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:ElectronPdf&amp;page=Crazy%2C+Stupid%2C+Love&amp;action=show-download-screen">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=Crazy,_Stupid,_Love&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-lang-label" class="portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       Languages
#      </h3>
#      <div class="body">
#       <ul>
#        <li class="interlanguage-link interwiki-ar">
#         <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%AD%D8%A8_%D9%85%D8%AC%D9%86%D9%88%D9%86%D8%8C_%D8%A3%D8%AD%D9%85%D9%82" hreflang="ar" lang="ar" title="حب مجنون، أحمق – Arabic">
#          العربية
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bg">
#         <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/%D0%9E%D0%B3%D0%BB%D1%83%D0%BF%D0%B5%D0%BB%D0%B8_%D0%BE%D1%82_%D0%BB%D1%8E%D0%B1%D0%BE%D0%B2" hreflang="bg" lang="bg" title="Оглупели от любов – Bulgarian">
#          Български
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ca">
#         <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/Amor,_boig_i_est%C3%BApid" hreflang="ca" lang="ca" title="Amor, boig i estúpid – Catalan">
#          Català
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-cs">
#         <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/Bl%C3%A1zniv%C3%A1,_zatracen%C3%A1_l%C3%A1ska" hreflang="cs" lang="cs" title="Bláznivá, zatracená láska – Czech">
#          Čeština
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-de">
#         <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="de" lang="de" title="Crazy, Stupid, Love. – German">
#          Deutsch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-el">
#         <a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="el" lang="el" title="Crazy, Stupid, Love. – Greek">
#          Ελληνικά
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-es">
#         <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Crazy,_Stupid,_Love" hreflang="es" lang="es" title="Crazy, Stupid, Love – Spanish">
#          Español
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fa">
#         <a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D8%B9%D8%B4%D9%82%D8%8C_%D8%A7%D8%AD%D9%85%D9%82%D8%A7%D9%86%D9%87%D8%8C_%D8%AF%DB%8C%D9%88%D8%A7%D9%86%D9%87%E2%80%8C%D9%88%D8%A7%D8%B1" hreflang="fa" lang="fa" title="عشق، احمقانه، دیوانه‌وار – Persian">
#          فارسی
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hif">
#         <a class="interlanguage-link-target" href="https://hif.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="hif" lang="hif" title="Crazy, Stupid, Love. – Fiji Hindi">
#          Fiji Hindi
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="fr" lang="fr" title="Crazy, Stupid, Love. – French">
#          Français
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ko">
#         <a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%ED%81%AC%EB%A0%88%EC%9D%B4%EC%A7%80,_%EC%8A%A4%ED%88%AC%ED%94%BC%EB%93%9C,_%EB%9F%AC%EB%B8%8C" hreflang="ko" lang="ko" title="크레이지, 스투피드, 러브 – Korean">
#          한국어
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hy">
#         <a class="interlanguage-link-target" href="https://hy.wikipedia.org/wiki/%D4%BD%D5%A5%D5%AC%D5%A1%D5%A3%D5%A1%D6%80,_%D5%B0%D5%AB%D5%B4%D5%A1%D6%80_%D5%BD%D5%A5%D6%80" hreflang="hy" lang="hy" title="Խելագար, հիմար սեր – Armenian">
#          Հայերեն
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-id">
#         <a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="id" lang="id" title="Crazy, Stupid, Love. – Indonesian">
#          Bahasa Indonesia
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-it">
#         <a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Crazy,_Stupid,_Love" hreflang="it" lang="it" title="Crazy, Stupid, Love – Italian">
#          Italiano
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-jv">
#         <a class="interlanguage-link-target" href="https://jv.wikipedia.org/wiki/Crazy,_Stupid,_Love" hreflang="jv" lang="jv" title="Crazy, Stupid, Love – Javanese">
#          Jawa
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-lv">
#         <a class="interlanguage-link-target" href="https://lv.wikipedia.org/wiki/Trak%C4%81,_dull%C4%81_m%C4%ABlest%C4%ABba" hreflang="lv" lang="lv" title="Trakā, dullā mīlestība – Latvian">
#          Latviešu
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hu">
#         <a class="interlanguage-link-target" href="https://hu.wikipedia.org/wiki/%C5%90r%C3%BClt,_dilis,_szerelem" hreflang="hu" lang="hu" title="Őrült, dilis, szerelem – Hungarian">
#          Magyar
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ms">
#         <a class="interlanguage-link-target" href="https://ms.wikipedia.org/wiki/Crazy,_Stupid,_Love" hreflang="ms" lang="ms" title="Crazy, Stupid, Love – Malay">
#          Bahasa Melayu
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-nl">
#         <a class="interlanguage-link-target" href="https://nl.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="nl" lang="nl" title="Crazy, Stupid, Love. – Dutch">
#          Nederlands
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ja">
#         <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/%E3%83%A9%E3%83%96%E3%83%BB%E3%82%A2%E3%82%B2%E3%82%A4%E3%83%B3_(%E6%98%A0%E7%94%BB)" hreflang="ja" lang="ja" title="ラブ・アゲイン (映画) – Japanese">
#          日本語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-no">
#         <a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="nb" lang="nb" title="Crazy, Stupid, Love. – Norwegian Bokmål">
#          Norsk bokmål
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pl">
#         <a class="interlanguage-link-target" href="https://pl.wikipedia.org/wiki/Kocha,_lubi,_szanuje_(film_2011)" hreflang="pl" lang="pl" title="Kocha, lubi, szanuje (film 2011) – Polish">
#          Polski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Crazy,_Stupid,_Love" hreflang="pt" lang="pt" title="Crazy, Stupid, Love – Portuguese">
#          Português
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%AD%D1%82%D0%B0_%D0%B4%D1%83%D1%80%D0%B0%D1%86%D0%BA%D0%B0%D1%8F_%D0%BB%D1%8E%D0%B1%D0%BE%D0%B2%D1%8C" hreflang="ru" lang="ru" title="Эта дурацкая любовь – Russian">
#          Русский
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sr">
#         <a class="interlanguage-link-target" href="https://sr.wikipedia.org/wiki/%D0%A2%D0%B0_%D0%BB%D1%83%D0%B4%D0%B0_%D1%99%D1%83%D0%B1%D0%B0%D0%B2" hreflang="sr" lang="sr" title="Та луда љубав – Serbian">
#          Српски / srpski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sh">
#         <a class="interlanguage-link-target" href="https://sh.wikipedia.org/wiki/Crazy,_Stupid,_Love." hreflang="sh" lang="sh" title="Crazy, Stupid, Love. – Serbo-Croatian">
#          Srpskohrvatski / српскохрватски
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fi">
#         <a class="interlanguage-link-target" href="https://fi.wikipedia.org/wiki/H%C3%B6lm%C3%B6_hullu_rakkaus" hreflang="fi" lang="fi" title="Hölmö hullu rakkaus – Finnish">
#          Suomi
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/%C3%87%C4%B1lg%C4%B1n_Aptal_A%C5%9Fk" hreflang="tr" lang="tr" title="Çılgın Aptal Aşk – Turkish">
#          Türkçe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%A6%D0%B5_%D0%B1%D0%B5%D0%B7%D0%B3%D0%BB%D1%83%D0%B7%D0%B4%D0%B5_%D0%BA%D0%BE%D1%85%D0%B0%D0%BD%D0%BD%D1%8F" hreflang="uk" lang="uk" title="Це безглузде кохання – Ukrainian">
#          Українська
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-yue">
#         <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/%E6%BB%BE%E6%90%9E%E4%BA%86%E6%84%9B%E6%83%85" hreflang="yue" lang="yue" title="滾搞了愛情 – Cantonese">
#          粵語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E7%86%9F%E7%94%B7%E5%9E%8B%E4%B8%8D%E5%9E%8B" hreflang="zh" lang="zh" title="熟男型不型 – Chinese">
#          中文
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q519490#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer" role="contentinfo">
#    <ul class="" id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 1 February 2020, at 09:43
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul class="" id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/v2/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Crazy,_Stupid,_Love&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.584","walltime":"0.757","ppvisitednodes":{"value":3256,"limit":1000000},"postexpandincludesize":{"value":93293,"limit":2097152},"templateargumentsize":{"value":3985,"limit":2097152},"expansiondepth":{"value":24,"limit":40},"expensivefunctioncount":{"value":2,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":111945,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  673.987      1 -total"," 37.59%  253.371      1 Template:Reflist"," 16.90%  113.929     28 Template:Cite_web"," 14.38%   96.900      6 Template:Cite_news"," 12.25%   82.543      1 Template:Infobox_film"," 11.93%   80.419      1 Template:Official_website"," 11.38%   76.688      1 Template:Infobox","  6.25%   42.099      1 Template:For","  5.42%   36.524      1 Template:Commons_category","  5.04%   33.951      1 Template:Use_mdy_dates"]},"scribunto":{"limitreport-timeusage":{"value":"0.289","limit":"10.000"},"limitreport-memusage":{"value":5302750,"limit":52428800}},"cachereport":{"origin":"mw1305","timestamp":"20200214201200","ttl":3600,"transientcontent":true}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Crazy, Stupid, Love","url":"https:\/\/en.wikipedia.org\/wiki\/Crazy,_Stupid,_Love","sameAs":"http:\/\/www.wikidata.org\/entity\/Q519490","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q519490","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2010-09-19T16:31:13Z","dateModified":"2020-02-01T09:43:02Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/en\/7\/78\/CrazyStupidLovePoster.jpg","headline":"2011 American film"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":94,"wgHostname":"mw1247"});});
#   </script>
#  </body>
# </html>

# %%
#how to find info tag under tag

#for div in soup.find_all('div', {'class': 'plainlist'}):
 #   for each in div.find_all('a'):  
    #  each.string#get all elements with 'a' tag
     #   href = each.get('href')
      #  print href          #print href
       # print each.string   #print the text in tags
        #print each          #print whole tag

# %%
#check if the class is the same for all movies ---> yes

table = soup.find_all('table', {'class':'infobox vevent'})
table
# Out:
# [<table class="infobox vevent" style="width:22em;font-size:90%;"><tbody><tr><th class="summary" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:110%;font-style:italic;">Crazy, Stupid, Love.</th></tr><tr><td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:CrazyStupidLovePoster.jpg"><img alt="CrazyStupidLovePoster.jpg" class="thumbborder" data-file-height="326" data-file-width="220" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/7/78/CrazyStupidLovePoster.jpg" width="220"/></a><div style="font-size:95%;padding:0.35em 0.35em 0.25em;line-height:1.25em;">Theatrical release poster</div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Directed by</th><td><div class="plainlist"><ul><li><a href="/wiki/Glenn_Ficarra" title="Glenn Ficarra">Glenn Ficarra</a></li><li><a href="/wiki/John_Requa" title="John Requa">John Requa</a></li></ul></div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Produced by</th><td><div class="plainlist"><ul><li><a href="/wiki/Steve_Carell" title="Steve Carell">Steve Carell</a><sup class="reference" id="cite_ref-HR_2009-01-13_1-0"><a href="#cite_note-HR_2009-01-13-1">[1]</a></sup></li><li><a href="/wiki/Denise_Di_Novi" title="Denise Di Novi">Denise Di Novi</a></li></ul></div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Written by</th><td><a href="/wiki/Dan_Fogelman" title="Dan Fogelman">Dan Fogelman</a></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Starring</th><td><div class="plainlist"><ul><li><a href="/wiki/Steve_Carell" title="Steve Carell">Steve Carell</a></li><li><a href="/wiki/Ryan_Gosling" title="Ryan Gosling">Ryan Gosling</a></li><li><a href="/wiki/Julianne_Moore" title="Julianne Moore">Julianne Moore</a></li><li><a href="/wiki/Emma_Stone" title="Emma Stone">Emma Stone</a></li><li><a href="/wiki/Marisa_Tomei" title="Marisa Tomei">Marisa Tomei</a></li><li><a href="/wiki/Kevin_Bacon" title="Kevin Bacon">Kevin Bacon</a></li></ul></div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Music by</th><td><div class="plainlist"><ul><li><a href="/wiki/Christophe_Beck" title="Christophe Beck">Christophe Beck</a></li><li><a class="mw-redirect" href="/wiki/Nick_Urata" title="Nick Urata">Nick Urata</a></li></ul></div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Cinematography</th><td><a href="/wiki/Andrew_Dunn_(cinematographer)" title="Andrew Dunn (cinematographer)">Andrew Dunn</a></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Edited by</th><td><a href="/wiki/Lee_Haxall" title="Lee Haxall">Lee Haxall</a></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;">Production<br/>company </div></th><td><div style="vertical-align:middle;"><a href="/wiki/Steve_Carell" title="Steve Carell">Carousel Productions</a><sup class="reference" id="cite_ref-HR_2009-01-13_1-1"><a href="#cite_note-HR_2009-01-13-1">[1]</a></sup><br/><a href="/wiki/Denise_Di_Novi" title="Denise Di Novi">Di Novi Pictures</a> </div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Distributed by</th><td><a class="mw-redirect" href="/wiki/Warner_Bros._Pictures" title="Warner Bros. Pictures">Warner Bros. Pictures</a></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;white-space:normal;">Release date</div></th><td><div class="plainlist">
#  <ul><li>July 19, 2011<span style="display:none"> (<span class="bday dtstart published updated">2011-07-19</span>)</span> (<a href="/wiki/New_York_City" title="New York City">New York City</a>)</li>
#  <li>July 29, 2011<span style="display:none"> (<span class="bday dtstart published updated">2011-07-29</span>)</span> (United States)</li></ul>
#  </div></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;white-space:normal;">Running time</div></th><td>118 minutes</td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Country</th><td>United States</td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Language</th><td>English</td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Budget</th><td>$50 million<sup class="reference" id="cite_ref-BoxOfficeMojo_2-0"><a href="#cite_note-BoxOfficeMojo-2">[2]</a></sup></td></tr><tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Box office</th><td>$145 million<sup class="reference" id="cite_ref-BoxOfficeMojo_2-1"><a href="#cite_note-BoxOfficeMojo-2">[2]</a></sup></td></tr></tbody></table>]

# %%
#getting colnames, just need to delete the first element

for head in table:
    headers_box = head.find_all('th')
    colnames = [head.text for head in headers_box]
colnames
# Out:
# ['Crazy, Stupid, Love.',
#  'Directed by',
#  'Produced by',
#  'Written by',
#  'Starring',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office']

# %%
#getting rows

for row in table:
    rows = row.find_all('tr')
rows
# Out:
# [<tr><th class="summary" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:110%;font-style:italic;">Crazy, Stupid, Love.</th></tr>,
#  <tr><td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:CrazyStupidLovePoster.jpg"><img alt="CrazyStupidLovePoster.jpg" class="thumbborder" data-file-height="326" data-file-width="220" decoding="async" height="326" src="//upload.wikimedia.org/wikipedia/en/7/78/CrazyStupidLovePoster.jpg" width="220"/></a><div style="font-size:95%;padding:0.35em 0.35em 0.25em;line-height:1.25em;">Theatrical release poster</div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Directed by</th><td><div class="plainlist"><ul><li><a href="/wiki/Glenn_Ficarra" title="Glenn Ficarra">Glenn Ficarra</a></li><li><a href="/wiki/John_Requa" title="John Requa">John Requa</a></li></ul></div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Produced by</th><td><div class="plainlist"><ul><li><a href="/wiki/Steve_Carell" title="Steve Carell">Steve Carell</a><sup class="reference" id="cite_ref-HR_2009-01-13_1-0"><a href="#cite_note-HR_2009-01-13-1">[1]</a></sup></li><li><a href="/wiki/Denise_Di_Novi" title="Denise Di Novi">Denise Di Novi</a></li></ul></div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Written by</th><td><a href="/wiki/Dan_Fogelman" title="Dan Fogelman">Dan Fogelman</a></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Starring</th><td><div class="plainlist"><ul><li><a href="/wiki/Steve_Carell" title="Steve Carell">Steve Carell</a></li><li><a href="/wiki/Ryan_Gosling" title="Ryan Gosling">Ryan Gosling</a></li><li><a href="/wiki/Julianne_Moore" title="Julianne Moore">Julianne Moore</a></li><li><a href="/wiki/Emma_Stone" title="Emma Stone">Emma Stone</a></li><li><a href="/wiki/Marisa_Tomei" title="Marisa Tomei">Marisa Tomei</a></li><li><a href="/wiki/Kevin_Bacon" title="Kevin Bacon">Kevin Bacon</a></li></ul></div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Music by</th><td><div class="plainlist"><ul><li><a href="/wiki/Christophe_Beck" title="Christophe Beck">Christophe Beck</a></li><li><a class="mw-redirect" href="/wiki/Nick_Urata" title="Nick Urata">Nick Urata</a></li></ul></div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Cinematography</th><td><a href="/wiki/Andrew_Dunn_(cinematographer)" title="Andrew Dunn (cinematographer)">Andrew Dunn</a></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Edited by</th><td><a href="/wiki/Lee_Haxall" title="Lee Haxall">Lee Haxall</a></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;">Production<br/>company </div></th><td><div style="vertical-align:middle;"><a href="/wiki/Steve_Carell" title="Steve Carell">Carousel Productions</a><sup class="reference" id="cite_ref-HR_2009-01-13_1-1"><a href="#cite_note-HR_2009-01-13-1">[1]</a></sup><br/><a href="/wiki/Denise_Di_Novi" title="Denise Di Novi">Di Novi Pictures</a> </div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Distributed by</th><td><a class="mw-redirect" href="/wiki/Warner_Bros._Pictures" title="Warner Bros. Pictures">Warner Bros. Pictures</a></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;white-space:normal;">Release date</div></th><td><div class="plainlist">
#  <ul><li>July 19, 2011<span style="display:none"> (<span class="bday dtstart published updated">2011-07-19</span>)</span> (<a href="/wiki/New_York_City" title="New York City">New York City</a>)</li>
#  <li>July 29, 2011<span style="display:none"> (<span class="bday dtstart published updated">2011-07-29</span>)</span> (United States)</li></ul>
#  </div></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;"><div style="padding:0.1em 0;line-height:1.2em;white-space:normal;">Running time</div></th><td>118 minutes</td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Country</th><td>United States</td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Language</th><td>English</td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Budget</th><td>$50 million<sup class="reference" id="cite_ref-BoxOfficeMojo_2-0"><a href="#cite_note-BoxOfficeMojo-2">[2]</a></sup></td></tr>,
#  <tr><th scope="row" style="white-space:nowrap;padding-right:0.65em;">Box office</th><td>$145 million<sup class="reference" id="cite_ref-BoxOfficeMojo_2-1"><a href="#cite_note-BoxOfficeMojo-2">[2]</a></sup></td></tr>]

# %%
rows = [row.text.split('\n') for row in rows]
rows
# Out:
# [['Crazy, Stupid, Love.'],
#  ['Theatrical release poster'],
#  ['Directed byGlenn FicarraJohn Requa'],
#  ['Produced bySteve Carell[1]Denise Di Novi'],
#  ['Written byDan Fogelman'],
#  ['StarringSteve CarellRyan GoslingJulianne MooreEmma StoneMarisa TomeiKevin Bacon'],
#  ['Music byChristophe BeckNick Urata'],
#  ['CinematographyAndrew Dunn'],
#  ['Edited byLee Haxall'],
#  ['Productioncompany Carousel Productions[1]Di Novi Pictures '],
#  ['Distributed byWarner Bros. Pictures'],
#  ['Release date',
#   'July\xa019,\xa02011\xa0(2011-07-19) (New York City)',
#   'July\xa029,\xa02011\xa0(2011-07-29) (United States)',
#   ''],
#  ['Running time118 minutes'],
#  ['CountryUnited States'],
#  ['LanguageEnglish'],
#  ['Budget$50 million[2]'],
#  ['Box office$145 million[2]']]

# %%
# have two lists

# %%
#colnames, delete first item
colnames.pop(0)
# Out:
# 'Crazy, Stupid, Love.'

# %%
#rows, delete first element
rows.pop(0)
# Out:
# ['Crazy, Stupid, Love.']

# %%
#rows, delete second element
rows.pop(0)
# Out:
# ['Theatrical release poster']

# %%
colnames
# Out:
# ['Directed by',
#  'Produced by',
#  'Written by',
#  'Starring',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office']

# %%
rows
# Out:
# [['Directed byGlenn FicarraJohn Requa'],
#  ['Produced bySteve Carell[1]Denise Di Novi'],
#  ['Written byDan Fogelman'],
#  ['StarringSteve CarellRyan GoslingJulianne MooreEmma StoneMarisa TomeiKevin Bacon'],
#  ['Music byChristophe BeckNick Urata'],
#  ['CinematographyAndrew Dunn'],
#  ['Edited byLee Haxall'],
#  ['Productioncompany Carousel Productions[1]Di Novi Pictures '],
#  ['Distributed byWarner Bros. Pictures'],
#  ['Release date',
#   'July\xa019,\xa02011\xa0(2011-07-19) (New York City)',
#   'July\xa029,\xa02011\xa0(2011-07-29) (United States)',
#   ''],
#  ['Running time118 minutes'],
#  ['CountryUnited States'],
#  ['LanguageEnglish'],
#  ['Budget$50 million[2]'],
#  ['Box office$145 million[2]']]

# %%
for lst, head in zip(rows, colnames):
    for string in lst:
        string.split(head)
# Out:
# ['', 'Glenn FicarraJohn Requa']
# ['', 'Steve Carell[1]Denise Di Novi']
# ['', 'Dan Fogelman']
# ['', 'Steve CarellRyan GoslingJulianne MooreEmma StoneMarisa TomeiKevin Bacon']
# ['', 'Christophe BeckNick Urata']
# ['', 'Andrew Dunn']
# ['', 'Lee Haxall']
# ['', 'Carousel Productions[1]Di Novi Pictures ']
# ['', 'Warner Bros. Pictures']
# ['', '']
# ['July\xa019,\xa02011\xa0(2011-07-19) (New York City)']
# ['July\xa029,\xa02011\xa0(2011-07-29) (United States)']
# ['']
# ['', '118 minutes']
# ['', 'United States']
# ['', 'English']
# ['', '$50 million[2]']
# ['', '$145 million[2]']

# %%
#unify country, see that have USA in API and united states in wiki.., depending if will need this column..

#colnames = ['Title','Poster','Director', 'Producer', 'Writer', 'Actors', 'Music', 'Cinematography', 'Edited by', 
#            'Prodcution Company', 'Distribution Company', 'Released', 'Runtime', 'Country', 'Language', 'Budget', 'BoxOffice']

#df = pd.DataFrame(rows[1:], columns = colnames)


df = pd.DataFrame(rows[:])
df.index += 1
df
# Out:
#                                                                                   0  \
# 1   Crazy, Stupid, Love.
# 2   Theatrical release poster
# 3   Directed byGlenn FicarraJohn Requa
# 4   Produced bySteve Carell[1]Denise Di Novi
# 5   Written byDan Fogelman
# 6   StarringSteve CarellRyan GoslingJulianne MooreEmma StoneMarisa TomeiKevin Bacon
# 7   Music byChristophe BeckNick Urata
# 8   CinematographyAndrew Dunn
# 9   Edited byLee Haxall
# 10  Productioncompany Carousel Productions[1]Di Novi Pictures
# 11  Distributed byWarner Bros. Pictures
# 12  Release date
# 13  Running time118 minutes
# 14  CountryUnited States
# 15  LanguageEnglish
# 16  Budget$50 million[2]
# 17  Box office$145 million[2]
#
#                                              1  \
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  July 19, 2011 (2011-07-19) (New York City)
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
#
#                                              2
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  July 29, 2011 (2011-07-29) (United States)
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
