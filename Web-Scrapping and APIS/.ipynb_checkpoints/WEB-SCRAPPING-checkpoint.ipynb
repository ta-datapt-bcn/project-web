# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
#import scrapy

# %%
url = "https://www.switchup.org/rankings/best-coding-bootcamps"

# %%
html = requests.get(url).content
soup = bs(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <script async="" data-cbid="91cbde44-d58b-46fb-b95d-6cfc8d1fb0c3" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-5DLMKG3');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-8097542-2', 'switchup.org');
#       ga('set', 'anonymizeIp', true);
#       ga('send', 'pageview');
#     </script>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="3KTXCi9DglrwqHWQ0ydoBgIgPysW8k7Fhtf2sj5hNyo=" name="csrf-token"/>
# <link href="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/application-14318a431daee07cc20f001c8433139c.css" media="screen" rel="stylesheet" type="text/css"/>
# <meta content="en-us" http-equiv="content-language"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"87b303eadd","applicationID":"36432587","transactionName":"clcMFxEJX10HRx4RAF9TCw0EFRxSDVFYDQZuWg0MFwVSXBJG","queueTime":1,"applicationTime":126,"agent":""}</script>
# <script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!E++){var e=x.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey&&e.applicationID&&n))return s.abort();c(y,function(n,t){e[n]|| ...
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="Copyright 2019 SwitchUp.Org All rights reserved." name="copyright"/>
# <!-- Facebook Pixel Code -->
# <script>
#       !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#       n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#       n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#       document,'script','//connect.facebook.net/en_US/fbevents.js');
#
#       fbq('init', '1514972078822546');
#       fbq('track', "PageView");
#     </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1514972078822546&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <script type="text/javascript">
#       setTimeout(function(){var a=document.createElement("script");
#       var b=document.getElementsByTagName("script")[0];
#       a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0066/3835.js?"+Math.floor(new Date().getTime()/3600000);
#       a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
#     </script>
# <title>2019 Best Coding Bootcamps</title>
# <meta content="2019 Best Coding Bootcamps" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://www.switchup.org/rankings/best-coding-bootcamps" property="og:url"/>
# <meta content="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/best_coding_alt_image-b69e6cb98bf9a69a3ca37105fc36f056.png" property="og:image"/>
# <meta content="SwitchUp" property="og:site_name"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="6827D40DFE5BE5BF47211DC5EF094E4D" name="msvalidate.01"/>
# <meta content="SwitchUp" name="author"/>
# <meta content="SwitchUp" name="designer"/>
# <link href="https://www.switchup.org/rankings/best-coding-bootcamps" rel="canonical"/>
# <link href="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/switch_logo_sm-9a2ba92daffba58b8b23e561687edaee.png" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
# </head>
# <body>
# <div class="body-div">
# <div class="body-background navbar-home" id="navbar-color">
# <div class="navbar navbar-secondary" style="position:fixed;background-color:#171717;">
# <div class="navbar-inner" style="max-height:60px;">
# <div class="container">
# <span itemscope="" itemtype="http://schema.org/Organization">
# <a href="https://www.switchup.org" itemprop="url">
# <header role="banner">
# <img alt="SwitchUp - Coding Bootcamp Reviews" class="site-logo" itemprop="logo" src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/switch_logo_sm-9a2ba92daffba58b8b23e561687edaee.png"/><p id="site-name"> switchup</p>
# </header>
# </a>
# </span>
# <a class="btn btn-navbar" data-target=".nav-collapse" data-toggle="collapse">
# <i class="fa fa-bars"></i>
# </a>
# <div class="nav-collapse collapse">
# <ul class="nav pull-right">
# <li class="rankings-nav not-bootcamp-nav">
# <a class="btn hidden-phone" href="/rankings">Bootcamp Rankings</a>
# <a class="btn visible-phone" href="/rankings/best-coding-bootcamps">Bootcamp Rankings</a>
# </li>
# <div class="rankings-hidden-nav dropdown-menu" style="background-color:#171717;left: 0;width: 355px;margin-left:0px;z-index:999;border-top: solid 3px #d43d2e;">
# <a class="btn btn-apply" href="/rankings/best-coding-bootcamps">
# <i class="fa fa-caret-right"></i>
#                       Best Coding Bootcamps
#                     </a>
# <a class="btn btn-apply" href="/rankings/best-online-bootcamps">
# <i class="fa fa-caret-right"></i>
#                       Best Online Bootcamps
#                     </a>
# <a class="btn btn-apply" href="/rankings/best-data-science-bootcamps">
# <i class="fa fa-caret-right"></i>
#                       Best Data Science Bootcamps
#                     </a>
# <a class="btn btn-apply" href="/rankings/best-web-design-bootcamps">
# <i class="fa fa-caret-right"></i>
#                       Best Web Design Bootcamps
#                     </a>
# <a class="btn btn-apply" href="/rankings/best-cyber-security-bootcamps">
# <i class="fa fa-caret-right"></i>
#                       Best Cyber Security Bootcamps
#                     </a>
# </div>
# <li class="bootcamp-nav not-rankings-nav">
# <a class="btn" href="/coding-bootcamps-reviews">All Bootcamps</a>
# </li>
# <div class="bootcamp-hidden-nav dropdown-menu" style="background-color:#171717;left: 0;width: 250px;margin-left:215px;z-index:999;border-top: solid 3px #d43d2e;">
# <a class="btn btn-apply" href="/coding-bootcamps-reviews">
# <i class="fa fa-caret-right"></i>
#                       Compare Bootcamps
#                     </a>
# <a class="btn btn-apply" href="/rankings#locations">
# <i class="fa fa-caret-right"></i>
#                       By Location
#                     </a>
# <a class="btn btn-apply" href="/subjects">
# <i class="fa fa-caret-right"></i>
#                       By Subject
#                     </a>
# </div>
# <li class="no-dropdown not-rankings-nav not-bootcamp-nav">
# <a class="btn btn-apply" href="/blog">Blog</a>
# </li>
# <li class="no-dropdown not-rankings-nav not-bootcamp-nav">
# <a class="btn btn-apply" href="/write_review" role="button">Write Review</a>
# </li>
# <li class="hidden-phone no-dropdown not-rankings-nav not-bootcamp-nav" style="padding:5px 15px 0;">
# <span>
# <a class="btn btn-green" href="/match?source=GlobalNavCTADesktop" style="font-size:18px;">Get Matched</a>
# </span>
# </li>
# <li class="visible-phone no-dropdown">
# <a class="btn btn-green" href="/match?source=GlobalNavCTAMobile">Get Matched</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="footer-fix">
# <div class="container">
# <div class="row">
# <div class="span12 alert-initial">
# </div>
# </div>
# </div>
# <!-- Google + -->
# <link href="https://plus.google.com/110457191582855820517" rel="author"/>
# <div class="blog-post-container coding-bootcamps" itemscope="" itemtype="http://schema.org/Article">
# <meta content="https://www.switchup.org/rankings/best-coding-bootcamps" itemprop="mainEntityOfPage"/>
# <div itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization" style="display:none;">
# <div itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <img src="https://www.switchup.org/assets/switch_logo_sm.png" style="display:none;"/>
# <meta content="https://www.switchup.org/assets/switch_logo_sm.png" itemprop="url"/>
# <meta content="33" itemprop="width"/>
# <meta content="33" itemprop="height"/>
# </div>
# <meta content="SwitchUp" itemprop="name"/>
# </div>
# <div itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject" style="display:none;">
# <img alt="2019 Best Coding Bootcamps" class="post_preview" itemprop="image" src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/best_bootcamps_back-4f4ba88a907ca9121ac6d642de07167a.jpg"/>
# <meta content="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/best_bootcamps_back-4f4ba88a907ca9121ac6d642de07167a.jpg" itemprop="url"/>
# </div>
# <div class="splash-section rankings-version-new best_coding" id="first-bootcamp-section" style="background-image: url(https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/best_bootcamps_back-4f4ba88a907ca9121ac6d642de07167a.jpg);">
# <div class="black-overlay no-pad">
# <div class="row-fluid">
# <div class="span12" style="border-bottom:none;">
# <h1 class="blog-post-title text-center" itemprop="headline name">
#             2019 Best Coding Bootcamps
#           </h1>
# <h2 class="blog-post-subtitle" itemprop="description" style="font-weight:600;font-size:24px;">
# <span class="visible-desktop text-center">
#                 50 Top Schools: Rankings, Reviews, and Courses
#               </span>
# <span class="hidden-desktop text-center">
#                 Guide to the Top Schools
#               </span>
# </h2>
# </div>
# </div>
# </div>
# <div class="alert alert-info contact-banner" role="alert" style="position:absolute;bottom:0;width:100%;margin-bottom:0;background-color:rgba(238,238,238,0.92);padding:8px 14px 8px 14px;">
# <div class="content" style="padding-top:0px;padding-bottom:0px;">
# <strong style="display:inline-block;color:black;">Not sure where to apply?</strong>
# <span class="hidden-phone">
#
#     </span>
# <br class="mobile-only-show"/>
# <br class="mobile-only-show"/>
# <a class="btn btn-reviews-new" href="/match?source=Coding_BannerCTA" role="button" style="display:inline-block;max-width:200px;">
# <i class="fa fa-envelope"></i>
#       Get Matched
#     </a>
# </div>
# </div>
# </div>
# <div class="row-fluid" id="sidebar-fix" style="padding-top:30px;">
# <div class="span9">
# <div class="visible-phone">
# <img alt="coding bootcamp review" class="topic-image rankings-badge" itemprop="image" src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Best_Coding_Bootcamp-8-6fd523c21756fee8efe10dcac741eaff.png" title="coding bootcamp review"/>
# </div>
# <div class="blog-post rankings" itemprop="articleBody">
# <p>SwitchUp's fourth annual rankings cover the 50 best coding bootcamps worldwide. We amassed thousands of alumni reviews and data points this past year to bring you our most comprehensive list to date. This list highlights price range, location, job outcomes, and several other criteria to help you find the perfect school.</p>
# <p>SwitchUp has been a trusted bootcamp resource since 2014, and we know that alumni reviews are crucial to a student's decision. That's why ours is the only rankings list based primarily on review scores from verified alumni. Please see our <a href="#" onclick="window.open('/rankings/methodology','SwitchUp Methodology','resizable,height=500,width=600'); return false;">ranking methodology</a><noscript>You need Javascript to use the previous link or use <a href="/rankings/methodology" rel="noopener noreferrer" target="_blank">ranking methodology</a></noscript> to learn more about the creation of this list. To continue your research, see our <a href="/rankings#locations">top schools by location</a> or check out <a href="#expert-advice">our expert advice</a> on making the most of your code bootcamp.</p>
# <div class="ranking-item">
# <div class="row-fluid" style="padding:0 20px;">
# <div class="span12" style="border-bottom:none;">
# <h3 style="margin-bottom:5px;">Best Bootcamp Highlights</h3>
# <p style="margin-bottom:10px">Looking for a school with specific qualities? We've awarded merit badges to schools in several key areas:</p>
# </div>
# </div>
# <div class="row-fluid" style="padding:0 20px;">
# <div class="span3">
# <h4 style="font-weight:700;font-size:16px;margin-bottom:0;">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png" style="width:auto;max-height: 23px;padding-bottom:2px;margin-right:3px;"/>
#         Available Online
#       </h4>
# <h6 class="hidden-phone" style="font-weight:normal;font-size:16px;line-height: 1.4;margin-top:5px;">
#         School offers fully online courses
#       </h6>
# </div>
# <div class="span3">
# <h4 style="font-weight:700;font-size:16px;margin-bottom:0;">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png" style="width:auto;max-height: 23px;padding-bottom:2px;margin-right:3px;"/>
#         Verified Outcomes
#       </h4>
# <h6 class="hidden-phone" style="font-weight:normal;font-size:16px;line-height: 1.4;margin-top:5px;">
#         School publishes a third-party verified outcomes report
#       </h6>
# </div>
# <div class="span3">
# <h4 style="font-weight:700;font-size:16px;margin-bottom:0;">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png" style="width:auto;max-height: 23px;padding-bottom:2px;margin-right:3px;"/>
#         Flexible Classes
#       </h4>
# <h6 class="hidden-phone" style="font-weight:normal;font-size:16px;line-height: 1.4;margin-top:5px;">
#         School offers part-time and evening classes
#       </h6>
# </div>
# <div class="span3">
# <h4 style="font-weight:700;font-size:16px;margin-bottom:0;">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Guaranteed_Job_Icon-8-5e0dd8636b0f4e02217bc9cc165af3c3.png" style="width:auto;max-height: 23px;padding-bottom:2px;margin-right:3px;"/>
#         Job Guarantee
#       </h4>
# <h6 class="hidden-phone" style="font-weight:normal;font-size:16px;line-height: 1.4;margin-top:5px;">
#         School guarantees job placement
#       </h6>
# </div>
# </div>
# </div>
# <ul>
# <li>
# <div class="ranking-item">
# <div class="ranking-item__header">
# <div class="ranking-item__header--right hidden-phone">
# </div>
# <div class="ranking-item__header--left ranking-item__header--logo hidden-phone hidden-tablet">
# <a href="/bootcamps/le-wagon">
# <img src="https://d1vki863cvir6c.cloudfront.net/uploads/topic/image/210/lewagon-logo.png"/>
# </a> </div>
# <div class="ranking-item__header--left">
# <h3>
#           1.
#         <a href="/bootcamps/le-wagon" itemprop="url">Le Wagon</a>
# </h3>
# <div class="ranking-item__rating">
# <a href="/bootcamps/le-wagon#tablist-tab-review" style="text-decoration:none;">
# <div class="rating-stars">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# <div class="rating-stars--fill" style="width:99.516994633273704%;">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# </div>
# </div>
# </a> <a href="/bootcamps/le-wagon#tablist-tab-review" style="color: black;text-decoration:none;">
# <span class="ranking-item__rating--value">
#               4.98/5
#             </span>
# </a> <span class="ranking-item__rating--count">
#               (<a href="/bootcamps/le-wagon#tablist-tab-review">1,118 reviews</a>)
#             </span>
# </div>
# <div class="ranking-item__price">
# <span class="dollar-sign--filled">$</span><span class="dollar-sign--filled">$</span><span class="dollar-sign--empty">$</span><span class="dollar-sign--empty">$</span>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <table class="ranking-item__info-table hidden-phone">
# <tbody>
# <tr>
# <th>
#             Locations:
#           </th>
# <td>
#               Amsterdam, Bali, Barcelona, Belo Horizonte, Berlin, Bordeaux, Brussels, Buenos Aires, Casablanca, Chengdu...
#               <a href="/bootcamps/le-wagon">View All 34 Locations</a>
# </td>
# </tr>
# <tr>
# <th>
#             Course:
#           </th>
# <td>
#               FullStack program - 35+ locations
#           </td>
# </tr>
# <tr>
# <th>
#             Subjects:
#           </th>
# <td>
#             ruby, ruby on Rails, HTML/CSS, JavaScript
#           </td>
# </tr>
# </tbody>
# </table>
# <div class="hidden-desktop hidden-tablet">
# <div class="ranking-item__info-mobile">
# <strong>
#           Locations:
#         </strong>
#           Amsterdam, Bali, Barcelona, Belo Horizonte, Berlin, Bordeaux, Brussels, Buenos Aires, Casablanca, Chengdu...
#           <a href="/bootcamps/le-wagon">View All 34 Locations</a>
# </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Course:
#         </strong>
#           FullStack program - 35+ locations
#       </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Subjects:
#         </strong>
#         ruby, ruby on Rails, HTML/CSS, JavaScript
#       </div>
# </div>
# <hr/>
# <div class="hidden-desktop hidden-tablet">
# </div>
# <div class="ranking-item__desc">
# <p>
#       Le Wagon is an intensive, full-time international bootcamp geared toward entrepreneurs who want to gain coding skills. Participants complete 450 hours of coding in 9 weeks, which includes building their own web app. After completing the program, students join an international alumni network of 3,150+ for career support and community.
#     </p>
# </div>
# <div class="ranking-item__review">
# <div class="ranking-item__review--content">
#         I really think it's an amazing coding school ! I learned a lot about ruby on rails and it is so useful for me now in my startup. I am able to code pretty much everything we need here. Also the staff is amazing and the student life is awesome ! We ...
#       </div>
# <div class="ranking-item__review--author">
#         Fabrice - July 24, 2019
#       </div>
# <div class="ranking-item__review--read-all">
# <a href="/bootcamps/le-wagon#tablist-tab-review">
#           Read All Reviews
#           <i class="fa fa-arrow-circle-right"></i>
# </a> </div>
# <div class="clear"></div>
# </div>
# <div class="text-center">
# <a class="btn btn-green btn-wide btn-center ranking-item__cta" href="/bootcamps/le-wagon" itemprop="url">
#       Learn More
# </a> </div>
# </div>
# </li>
# <li>
# <div class="ranking-item">
# <div class="ranking-item__header">
# <div class="ranking-item__header--right hidden-phone">
# <span class="merit-badge merit-badge--medium" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
# <span>
#             Verified Outcomes
#           </span>
# </span>
# <span class="merit-badge merit-badge--medium" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
# <span>
#             Flexible Classes
#           </span>
# </span>
# </div>
# <div class="ranking-item__header--left ranking-item__header--logo hidden-phone hidden-tablet">
# <a href="/bootcamps/ironhack">
# <img src="https://d1vki863cvir6c.cloudfront.net/uploads/topic/image/99/logo_ironhack.jpg"/>
# </a> </div>
# <div class="ranking-item__header--left">
# <h3>
#           2.
#         <a href="/bootcamps/ironhack" itemprop="url">Ironhack</a>
# </h3>
# <div class="ranking-item__rating">
# <a href="/bootcamps/ironhack#tablist-tab-review" style="text-decoration:none;">
# <div class="rating-stars">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# <div class="rating-stars--fill" style="width:97.6036866359447%;">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# </div>
# </div>
# </a> <a href="/bootcamps/ironhack#tablist-tab-review" style="color: black;text-decoration:none;">
# <span class="ranking-item__rating--value">
#               4.88/5
#             </span>
# </a> <span class="ranking-item__rating--count">
#               (<a href="/bootcamps/ironhack#tablist-tab-review">651 reviews</a>)
#             </span>
# </div>
# <div class="ranking-item__price">
# <span class="dollar-sign--filled">$</span><span class="dollar-sign--filled">$</span><span class="dollar-sign--empty">$</span><span class="dollar-sign--empty">$</span>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <table class="ranking-item__info-table hidden-phone">
# <tbody>
# <tr>
# <th>
#             Locations:
#           </th>
# <td>
#               Amsterdam, Barcelona, Berlin, Bogota, Lisbon, Madrid, Mexico City, Miami, Munich, Paris...
#               <a href="/bootcamps/ironhack">View All 11 Locations</a>
# </td>
# </tr>
# <tr>
# <th>
#             Courses:
#           </th>
# <td>
#               Part-time UX/UI Design , Full-time UX/UI Design Bootcamp...
#               <a href="/bootcamps/ironhack#tablist-tab-courses">View All 4 Courses</a>
# </td>
# </tr>
# <tr>
# <th>
#             Subjects:
#           </th>
# <td>
#             JavaScript, HTML, CSS, MERN Stack, MongoDB, ExpressJS, NodeJS
#           </td>
# </tr>
# </tbody>
# </table>
# <div class="hidden-desktop hidden-tablet">
# <div class="ranking-item__info-mobile">
# <strong>
#           Locations:
#         </strong>
#           Amsterdam, Barcelona, Berlin, Bogota, Lisbon, Madrid, Mexico City, Miami, Munich, Paris...
#           <a href="/bootcamps/ironhack">View All 11 Locations</a>
# </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Courses:
#         </strong>
#           Part-time UX/UI Design , Full-time UX/UI Design Bootcamp...
#           <a href="/bootcamps/ironhack">View All 4 Courses</a>
# </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Subjects:
#         </strong>
#         JavaScript, HTML, CSS, MERN Stack, MongoDB, ExpressJS, NodeJS
#       </div>
# </div>
# <hr/>
# <div class="hidden-desktop hidden-tablet">
# <span class="merit-badge merit-badge--mobile" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
#         Verified Outcomes
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
#         Flexible Classes
#       </span>
# <br/>
# <br/>
# </div>
# <div class="ranking-item__desc">
# <p>
#       Ironhack offers full-time and part-time courses in 9- or 24-week formats, respectively. Career services include portfolio and resume building, job interview preparation, networking, and hiring fairs. Ironhack has scholarships available for women and military vets who are interested in a tech career.
#     </p>
# </div>
# <div class="ranking-item__review">
# <div class="ranking-item__review--content">
#         Having gone to Ironhack with -1 experience in web development, I learned all the necessary skills to become a software developer and change my career into technology. This includes the most important skill which is to learn how to "learn" new ...
#       </div>
# <div class="ranking-item__review--author">
#         William - July 21, 2019
#       </div>
# <div class="ranking-item__review--read-all">
# <a href="/bootcamps/ironhack#tablist-tab-review">
#           Read All Reviews
#           <i class="fa fa-arrow-circle-right"></i>
# </a> </div>
# <div class="clear"></div>
# </div>
# <div class="text-center">
# <a class="btn btn-green btn-wide btn-center ranking-item__cta" href="/bootcamps/ironhack" itemprop="url">
#       Learn More
# </a> </div>
# </div>
# </li>
# <li>
# <div class="ranking-item">
# <div class="ranking-item__header">
# <div class="ranking-item__header--right hidden-phone">
# <span class="merit-badge merit-badge--medium" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
# <span>
#             Available Online
#           </span>
# </span>
# <span class="merit-badge merit-badge--medium" title="Job Guarantee: School guarantees job placement">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Guaranteed_Job_Icon-8-5e0dd8636b0f4e02217bc9cc165af3c3.png"/>
# <span>
#             Job Guarantee
#           </span>
# </span>
# </div>
# <div class="ranking-item__header--left ranking-item__header--logo hidden-phone hidden-tablet">
# <a href="/bootcamps/app-academy">
# <img src="https://d1vki863cvir6c.cloudfront.net/uploads/topic/image/4/appacademy_logo.png"/>
# </a> </div>
# <div class="ranking-item__header--left">
# <h3>
#           3.
#         <a href="/bootcamps/app-academy" itemprop="url">App Academy</a>
# </h3>
# <div class="ranking-item__rating">
# <a href="/bootcamps/app-academy#tablist-tab-review" style="text-decoration:none;">
# <div class="rating-stars">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# <div class="rating-stars--fill" style="width:93.935681470137826%;">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# </div>
# </div>
# </a> <a href="/bootcamps/app-academy#tablist-tab-review" style="color: black;text-decoration:none;">
# <span class="ranking-item__rating--value">
#               4.7/5
#             </span>
# </a> <span class="ranking-item__rating--count">
#               (<a href="/bootcamps/app-academy#tablist-tab-review">653 reviews</a>)
#             </span>
# </div>
# <div class="ranking-item__price">
# <span class="dollar-sign--filled">$</span><span class="dollar-sign--filled">$</span><span class="dollar-sign--filled">$</span><span class="dollar-sign--empty">$</span>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <table class="ranking-item__info-table hidden-phone">
# <tbody>
# <tr>
# <th>
#             Locations:
#           </th>
# <td>
#               NYC, Online, San Francisco
#           </td>
# </tr>
# <tr>
# <th>
#             Courses:
#           </th>
# <td>
#               Bootcamp Prep, Engineering Interview Prep...
#               <a href="/bootcamps/app-academy#tablist-tab-courses">View All 4 Courses</a>
# </td>
# </tr>
# <tr>
# <th>
#             Subjects:
#           </th>
# <td>
#             JavaScript, Ruby, Rails, React.js, Redux, CSS, HTML, SQL, Advanced Algorithims
#           </td>
# </tr>
# </tbody>
# </table>
# <div class="hidden-desktop hidden-tablet">
# <div class="ranking-item__info-mobile">
# <strong>
#           Locations:
#         </strong>
#           NYC, Online, San Francisco
#       </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Courses:
#         </strong>
#           Bootcamp Prep, Engineering Interview Prep...
#           <a href="/bootcamps/app-academy">View All 4 Courses</a>
# </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Subjects:
#         </strong>
#         JavaScript, Ruby, Rails, React.js, Redux, CSS, HTML, SQL, Advanced Algorithims
#       </div>
# </div>
# <hr/>
# <div class="hidden-desktop hidden-tablet">
# <span class="merit-badge merit-badge--mobile" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
#         Available Online
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Job Guarantee: School guarantees job placement">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Guaranteed_Job_Icon-8-5e0dd8636b0f4e02217bc9cc165af3c3.png"/>
#         Job Guarantee
#       </span>
# <br/>
# <br/>
# </div>
# <div class="ranking-item__desc">
# <p>
#       App Academy teaches participants everything they need to know about software engineering in just 12 weeks. Their full-time bootcamps have helped over 2,000 graduates find jobs at more than 850 companies. Their deferred tuition plan means participants pay for the program only after they’ve landed their first web development job.
#     </p>
# </div>
# <div class="ranking-item__review">
# <div class="ranking-item__review--content">
#         If you are ready to truly immerse yourself in 12 weeks of code, this is the place for you. The program is definitely challenging but if you are committed, utilize all the resources given, and ASK QUESTIONS, you will have no problems passing the ...
#       </div>
# <div class="ranking-item__review--author">
#         Robin Shrestha - July 24, 2019
#       </div>
# <div class="ranking-item__review--read-all">
# <a href="/bootcamps/app-academy#tablist-tab-review">
#           Read All Reviews
#           <i class="fa fa-arrow-circle-right"></i>
# </a> </div>
# <div class="clear"></div>
# </div>
# <div class="text-center">
# <a class="btn btn-green btn-wide btn-center ranking-item__cta" href="/bootcamps/app-academy" itemprop="url">
#       Learn More
# </a> </div>
# </div>
# </li>
# <li>
# <div class="ranking-item">
# <div class="ranking-item__header">
# <div class="ranking-item__header--right hidden-phone">
# <span class="merit-badge merit-badge--medium" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
# <span>
#             Available Online
#           </span>
# </span>
# <span class="merit-badge merit-badge--medium" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
# <span>
#             Verified Outcomes
#           </span>
# </span>
# <span class="merit-badge merit-badge--medium" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
# <span>
#             Flexible Classes
#           </span>
# </span>
# </div>
# <div class="ranking-item__header--left ranking-item__header--logo hidden-phone hidden-tablet">
# <a href="/bootcamps/general-assembly">
# <img src="https://d1vki863cvir6c.cloudfront.net/uploads/topic/image/64/GA_logo1.jpeg"/>
# </a> </div>
# <div class="ranking-item__header--left">
# <h3>
#           4.
#         <a href="/bootcamps/general-assembly" itemprop="url">General Assembly</a>
# </h3>
# <div class="ranking-item__rating">
# <a href="/bootcamps/general-assembly#tablist-tab-review" style="text-decoration:none;">
# <div class="rating-stars">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# <div class="rating-stars--fill" style="width:84.62015503875969%;">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# </div>
# </div>
# </a> <a href="/bootcamps/general-assembly#tablist-tab-review" style="color: black;text-decoration:none;">
# <span class="ranking-item__rating--value">
#               4.23/5
#             </span>
# </a> <span class="ranking-item__rating--count">
#               (<a href="/bootcamps/general-assembly#tablist-tab-review">645 reviews</a>)
#             </span>
# </div>
# <div class="ranking-item__price">
# <span class="dollar-sign--filled">$</span><span class="dollar-sign--filled">$</span><span class="dollar-sign--empty">$</span><span class="dollar-sign--empty">$</span>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <table class="ranking-item__info-table hidden-phone">
# <tbody>
# <tr>
# <th>
#             Locations:
#           </th>
# <td>
#               Atlanta, Austin, Boston, Chicago, Dallas, Denver, Hong Kong, London, Los Angeles, Melbourne...
#               <a href="/bootcamps/general-assembly">View All 21 Locations</a>
# </td>
# </tr>
# <tr>
# <th>
#             Courses:
#           </th>
# <td>
#               User Experience Design Remote, Data Analytics...
#               <a href="/bootcamps/general-assembly#tablist-tab-courses">View All 16 Courses</a>
# </td>
# </tr>
# <tr>
# <th>
#             Subjects:
#           </th>
# <td>
#             Web Development (Full-stack: Javascript, Ruby, Rails), Web Design, UI/UX Design, Product Management, Digital Marketing, Analytics, Front-end (HTML, CSS, Javascript), Back-end (Ruby, Ruby on Rails), Data Science
#           </td>
# </tr>
# </tbody>
# </table>
# <div class="hidden-desktop hidden-tablet">
# <div class="ranking-item__info-mobile">
# <strong>
#           Locations:
#         </strong>
#           Atlanta, Austin, Boston, Chicago, Dallas, Denver, Hong Kong, London, Los Angeles, Melbourne...
#           <a href="/bootcamps/general-assembly">View All 21 Locations</a>
# </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Courses:
#         </strong>
#           User Experience Design Remote, Data Analytics...
#           <a href="/bootcamps/general-assembly">View All 16 Courses</a>
# </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Subjects:
#         </strong>
#         Web Development (Full-stack: Javascript, Ruby, Rails), Web Design, UI/UX Design, Product Management, Digital Marketing, Analytics, Front-end (HTML, CSS, Javascript), Back-end (Ruby, Ruby on Rails), Data Science
#       </div>
# </div>
# <hr/>
# <div class="hidden-desktop hidden-tablet">
# <span class="merit-badge merit-badge--mobile" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
#         Available Online
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
#         Verified Outcomes
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
#         Flexible Classes
#       </span>
# <br/>
# <br/>
# </div>
# <div class="ranking-item__desc">
# <p>
#       General Assembly offers a range of full-time, part-time, and self-paced courses. They have a number of financial assistance options available including loans and scholarships. For many of the programs, students are given a career coach and the opportunity to attend various networking events.
#     </p>
# </div>
# <div class="ranking-item__review">
# <div class="ranking-item__review--content">
#         From the first moment I heard about the concept of UX in 2012, I knew it was what I was meant to do. I've been chasing UX for 7 years, but trying to learn it on my own was really daunting. There are so many amazing resources but it's such a ...
#       </div>
# <div class="ranking-item__review--author">
#         Liberty - July 17, 2019
#       </div>
# <div class="ranking-item__review--read-all">
# <a href="/bootcamps/general-assembly#tablist-tab-review">
#           Read All Reviews
#           <i class="fa fa-arrow-circle-right"></i>
# </a> </div>
# <div class="clear"></div>
# </div>
# <div class="text-center">
# <a class="btn btn-green btn-wide btn-center ranking-item__cta" href="/bootcamps/general-assembly" itemprop="url">
#       Learn More
# </a> </div>
# </div>
# </li>
# <li>
# <div class="ranking-item">
# <div class="ranking-item__header">
# <div class="ranking-item__header--right hidden-phone">
# <span class="merit-badge merit-badge--small" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
# <span>
#             Available Online
#           </span>
# </span>
# <span class="merit-badge merit-badge--small" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
# <span>
#             Verified Outcomes
#           </span>
# </span>
# <span class="merit-badge merit-badge--small" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
# <span>
#             Flexible Classes
#           </span>
# </span>
# <span class="merit-badge merit-badge--small" title="Job Guarantee: School guarantees job placement">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Guaranteed_Job_Icon-8-5e0dd8636b0f4e02217bc9cc165af3c3.png"/>
# <span>
#             Job Guarantee
#           </span>
# </span>
# </div>
# <div class="ranking-item__header--left ranking-item__header--logo hidden-phone hidden-tablet">
# <a href="/bootcamps/bloc">
# <img src="https://d1vki863cvir6c.cloudfront.net/uploads/topic/image/17/alex__1_.png"/>
# </a> </div>
# <div class="ranking-item__header--left">
# <h3>
#           5.
#         <a href="/bootcamps/bloc" itemprop="url">Bloc</a>
# </h3>
# <div class="ranking-item__rating">
# <a href="/bootcamps/bloc#tablist-tab-review" style="text-decoration:none;">
# <div class="rating-stars">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# <div class="rating-stars--fill" style="width:94.678899082568808%;">
# <i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i><i class="fa fa-star"></i>
# </div>
# </div>
# </a> <a href="/bootcamps/bloc#tablist-tab-review" style="color: black;text-decoration:none;">
# <span class="ranking-item__rating--value">
#               4.73/5
#             </span>
# </a> <span class="ranking-item__rating--count">
#               (<a href="/bootcamps/bloc#tablist-tab-review">327 reviews</a>)
#             </span>
# </div>
# <div class="ranking-item__price">
# <span class="dollar-sign--filled">$</span><span class="dollar-sign--filled">$</span><span class="dollar-sign--empty">$</span><span class="dollar-sign--empty">$</span>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <table class="ranking-item__info-table hidden-phone">
# <tbody>
# <tr>
# <th>
#             Location:
#           </th>
# <td>
#               Online
#           </td>
# </tr>
# <tr>
# <th>
#             Courses:
#           </th>
# <td>
#               Web Developer Track, Designer Track
#           </td>
# </tr>
# <tr>
# <th>
#             Subjects:
#           </th>
# <td>
#             Ruby on Rails, HTML, Javascript, iOS, Android, Objective C, Swift, UX Design, CSS, AngularJS
#           </td>
# </tr>
# </tbody>
# </table>
# <div class="hidden-desktop hidden-tablet">
# <div class="ranking-item__info-mobile">
# <strong>
#           Location:
#         </strong>
#           Online
#       </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Courses:
#         </strong>
#           Web Developer Track, Designer Track
#       </div>
# <div class="ranking-item__info-mobile">
# <strong>
#           Subjects:
#         </strong>
#         Ruby on Rails, HTML, Javascript, iOS, Android, Objective C, Swift, UX Design, CSS, AngularJS
#       </div>
# </div>
# <hr/>
# <div class="hidden-desktop hidden-tablet">
# <span class="merit-badge merit-badge--mobile" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
#         Available Online
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
#         Verified Outcomes
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
#         Flexible Classes
#       </span>
# <span class="merit-badge merit-badge--mobile" title="Job Guarantee: School guarantees job placement">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Guaranteed_Job_Icon-8-5e0dd8636b0f4e02217bc9cc165af3c3.png"/>
#         Job Guarantee
#       </span>
# <br/>
# <br/>
# </div>
# <div class="ranking-item__desc">
# <p>
#       Bloc was the first tech school to offer self-paced online bootcamps in web development and design. Students stay accountable through one-to-one mentorship as they work full- or part-time, finishing the course in an average of 4–8 months. Land a job within six months or get your money back.
#     </p>
# </div>
# <div class="ranking-item__review">
# <div class="ranking-item__review--content">
#         I heard about Bloc thru a friend. She was also studying in the designer track. I chose to enroll with Bloc because I heard it has a mentor program. Every week I can have a 30-mins online meeting with my mentor. I don't have any background with ...
#       </div>
# <div class="ranking-item__review--author">
#         Songting Hu - July 19, 2019
#       </div>
# <div class="ranking-item__review--read-all">
# <a href="/bootcamps/bloc#tablist-tab-review">
#           Read All Reviews
#           <i class="fa fa-arrow-circle-right"></i>
# </a> </div>
# <div class="clear"></div>
# </div>
# <div class="text-center">
# <a class="btn btn-green btn-wide btn-center ranking-item__cta" href="/bootcamps/bloc" itemprop="url">
#       Learn More
# </a> </div>
# </div>
# </li>
# <li>
# <div class="ranking-item">
# <div class="ranking-item__header">
# <div class="ranking-item__header--right hidden-phone">
# <span class="merit-badge merit-badge--small" title="Available Online: School offers fully online courses">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Available_Online-8-6843bc0cb26e1261c2b62dfcafecc507.png"/>
# <span>
#             Available Online
#           </span>
# </span>
# <span class="merit-badge merit-badge--small" title="Verified Outcomes: School publishes a third-party verified outcomes report">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Verified_Outcomes_Icon-8-6562921bc1cf203166c897357e4140b2.png"/>
# <span>
#             Verified Outcomes
#           </span>
# </span>
# <span class="merit-badge merit-badge--small" title="Flexible Classes: School offers part-time and evening classes">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Flexible_Classes_Icon-8-0a9dcae4a3985548d80c4540c5fd77c5.png"/>
# <span>
#             Flexible Classes
#           </span>
# </span>
# <span class="merit-badge merit-badge--small" title="Job Guarantee: School guarantees job placement">
# <img src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/Guaranteed_Job_Icon-8-5e0dd8636b0f4e02217bc9cc165af3c3.png"/>
# <span>
#             Job Guarantee
#           </span>
# </span>
# </div>
# <div class="ranking-item__header--left ranking-item__header--logo hidden-phone hidden-tablet">
# <a href="/bootcamps/thinkful">
# <img src="https://d1vki863cvir6c.cloudfront.net/uploads/topic/image/34/Social-Profile-Image-T_preview.png"/>
# </a> </div>
# <div class="ranking-item__header--left">
# <h3>
#           6.
#         <a href="/bootcamps/thinkful" itemprop="url">Thinkful</a>
# </h3>
# <div class="ranking-item__rating">
# ...
# <option value="90">Tech Talent South</option>
# <option value="662">Techtonica</option>
# <option value="552">Techvalley Training Center</option>
# <option value="1018">Tecky Academy Limited</option>
# <option value="788">Tecnológico de Monterrey Boot Camps</option>
# <option value="547">Telegraph Academy</option>
# <option value="351">Temple University</option>
# <option value="268">Texas A&amp;M University</option>
# <option value="1005">Texas A&amp;M University - Kingsville Bootcamps</option>
# <option value="177">The App Academy NL</option>
# <option value="815">The Blockchain Academy</option>
# <option value="494">The Closer Academy</option>
# <option value="754">the Clubhouse</option>
# <option value="116">The Coded</option>
# <option value="25">The Code Path</option>
# <option value="890">The Coding Boot Camp at UCR Extension</option>
# <option value="352">The College of Saint Scholastica</option>
# <option value="898">The Computer Workshop</option>
# <option value="145">The Data Incubator</option>
# <option value="812">The Data Lab</option>
# <option value="933">The Den</option>
# <option value="489">The Dev Masters</option>
# <option value="404">The Dev School</option>
# <option value="570">The Devs Lab</option>
# <option value="189">The Firehose Project</option>
# <option value="463">The Guild of Software Architects</option>
# <option value="411">The Hacking School</option>
# <option value="773">The Institute for Statistics Education</option>
# <option value="86">The Iron Yard</option>
# <option value="793">The Job Hackers</option>
# <option value="1020">The Jump</option>
# <option value="944">thenexgencoders</option>
# <option value="737">The Odin Project</option>
# <option value="48">The Recurse Center, aka Hacker School</option>
# <option value="881">The Shkola</option>
# <option value="30">The Software Guild</option>
# <option value="78">The Tech Academy</option>
# <option value="269">The University of Alabama</option>
# <option value="316">The University of Tennessee</option>
# <option value="315">The University of Tennessee at Chattanooga</option>
# <option value="270">The University of Texas at San Antonio</option>
# <option value="795">The Valley Bootcamp</option>
# <option value="683">The Valley DBS</option>
# <option value="496">Think Academy</option>
# <option value="34">Thinkful</option>
# <option value="319">Thomas Edison State College</option>
# <option value="667">TK2 Academy</option>
# <option value="999">Tortuga Coders</option>
# <option value="208">Tradecraft</option>
# <option value="204">Treehouse</option>
# <option value="353">Trocaire College</option>
# <option value="20">Try Ruby</option>
# <option value="182">Turing School of Software and Design</option>
# <option value="739">Turn into Coders</option>
# <option value="196">Turn To Tech</option>
# <option value="75">Tutorials Point</option>
# <option value="917">Twin Cities Code Camp</option>
# <option value="506">Ubiqum Code Academy</option>
# <option value="228">UC Berkeley Data Science</option>
# <option value="743">UC Davis Boot Camps</option>
# <option value="573">UCF Coding Bootcamp</option>
# <option value="603">UC Irvine Boot Camps</option>
# <option value="571">UCLA Extension Boot Camps</option>
# <option value="1022">UConn Coding Boot Camp</option>
# <option value="580">UC San Diego Extension Boot Camps</option>
# <option value="206">Udacity</option>
# <option value="205">Udemy</option>
# <option value="787">UMUC Coding Bootcamp</option>
# <option value="932">Umuzi</option>
# <option value="534">UNC-Chapel Hill Boot Camps</option>
# <option value="582">UNC Charlotte Boot Camps</option>
# <option value="605">UNH Boot Camps</option>
# <option value="354">Union Graduate College</option>
# <option value="804">UNIT Factory</option>
# <option value="320">University at Buffalo</option>
# <option value="604">University of Arizona Boot Camps</option>
# <option value="321">University of Arkansas</option>
# <option value="246">University of California, Berkeley</option>
# <option value="322">University of California-Davis</option>
# <option value="355">University of Central Florida</option>
# <option value="323">University of Chicago</option>
# <option value="247">University of Cincinnati</option>
# <option value="324">University of Cincinnati-Main Campus</option>
# <option value="325">University of Colorado Boulder</option>
# <option value="271">University of Colorado Denver</option>
# <option value="248">University of Connecticut</option>
# <option value="326">University of Denver</option>
# <option value="627">University of Denver Boot Camps</option>
# <option value="327">University of Florida</option>
# <option value="328">University of Georgia</option>
# <option value="356">University of Illinois at Chicago</option>
# <option value="329">University of Kansas</option>
# <option value="272">University of Maine at Farmington</option>
# <option value="249">University of Maryland</option>
# <option value="330">University of Maryland-College Park</option>
# <option value="357">University of Memphis</option>
# <option value="331">University of Miami</option>
# <option value="721">University of Miami Boot Camps</option>
# <option value="332">University of Michigan-Dearborn</option>
# <option value="727">University of Minnesota Boot Camps</option>
# <option value="333">University of Minnesota-Duluth</option>
# <option value="358">University of North Carolina at Chapel Hill</option>
# <option value="273">University of North Carolina at Charlotte</option>
# <option value="334">University of North Carolina at Greensboro</option>
# <option value="335">University of North Texas</option>
# <option value="274">University of Notre Dame</option>
# <option value="926">University of Oregon Boot Camps</option>
# <option value="336">University of Phoenix</option>
# <option value="359">University of Pittsburgh-Bradford</option>
# <option value="720">University of Richmond Boot Camps</option>
# <option value="337">University of Rochester</option>
# <option value="250">University of San Francisco</option>
# <option value="361">University of Southern California</option>
# <option value="360">University of South Florida-Main Campus</option>
# <option value="251">University of Tennessee</option>
# <option value="317">University of Texas at Austin</option>
# <option value="318">University of Texas at Dallas</option>
# <option value="275">University of the District of Columbia</option>
# <option value="650">University of Utah Boot Camps</option>
# <option value="252">University of Virginia</option>
# <option value="869">University of Washington Coding Boot Camp</option>
# <option value="996">Untapped Code Academy</option>
# <option value="745">UofT SCS Boot Camps</option>
# <option value="809">UP Academy</option>
# <option value="1010">UpCode Academy</option>
# <option value="684">Upload</option>
# <option value="601">Upscale Academy</option>
# <option value="728">USC Viterbi Data Analytics Boot Camp Affiliated with Trilogy Education</option>
# <option value="522">UT Austin Boot Camps</option>
# <option value="1021">UTSA Coding Boot Camp</option>
# <option value="929">UW Extended Campus Coding Boot Camp</option>
# <option value="939">UWM Coding Bootcamp</option>
# <option value="893">UW Professional Continuing Education</option>
# <option value="953">UX Design Institute</option>
# <option value="752">UXER School</option>
# <option value="928">Vanderbilt University Boot Camps</option>
# <option value="551">Velocity 360</option>
# <option value="885">Vertabelo Academy</option>
# <option value="220">Viking Code School</option>
# <option value="276">Villanova University</option>
# <option value="490">Vital Accelerator</option>
# <option value="950">VIVADATA</option>
# <option value="107">V School</option>
# <option value="997">Vvork Cloud Technologies</option>
# <option value="1011">Wagner College bootcamps</option>
# <option value="854">Washington University Data Analytics Boot Camp</option>
# <option value="528">Web Dev Camp</option>
# <option value="212">Web Fellowship</option>
# <option value="557">WebsiteSetup</option>
# <option value="229">We Can Code IT</option>
# <option value="927">WeCloudData</option>
# <option value="188">We Got Coders</option>
# <option value="724">WeThinkCode_</option>
# <option value="807">Wichita State University Coding Bootcamp</option>
# <option value="955">Wild Code School</option>
# <option value="567">Women's Coding Collective</option>
# <option value="497">World Tech Academy</option>
# <option value="417">World Tech Makers</option>
# <option value="863">Woz U</option>
# <option value="111">Wyncode</option>
# <option value="633">Xccelerate</option>
# <option value="616">XTOL Corp</option>
# <option value="622">York College, CUNY Continuing and Professional Education Center</option>
# <option value="433">Zip Code Wilmington</option>
# <option value="140">Zipfian Academy</option>
# <option value="899">Zuitt</option></select>
# <div class="row submit review-form">
# <input class="btn btn-bootcamps btn-large" name="commit" type="submit" value="GO"/>
# </div>
# </form> </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="modal-news-label" class="modal modal-news hide fade match-pop" id="modalNews" role="dialog" style="border-top: 5px grey;" tabindex="-1">
# <div class="modal-header" style="border-bottom:0px; background: rgba(0, 0, 0, 0.25);">
# </div>
# <div class="modal-body" style="max-height:500px;">
# <button aria-hidden="true" class="close" data-dismiss="modal" style="color:black;opacity:1.0;" type="button">×</button>
# <div class="container-fluid lead-gen text-center">
# <div class="row-fluid">
# <p class="span9" style="color: black;margin:0 auto;border-top:10px grey;font-size:35px;">Match with the <br/>Top Rated Bootcamps</p>
# <img alt="Mail_icon" class="span3" src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/mail_icon-78800b88f2774e5ab74c44a7c4b523b0.png" style="max-width:100px;text-align:center;margin:0 auto;"/>
# </div>
# <br/>
# <p style="color:black;">Not sure where to start? Tell us about yourself and we'll help.</p>
# <br/>
# <a class="match-btn" href="/match?source=PopupCTA" style="font-size:30px;">Get Matched</a>
# </div>
# </div>
# </div>
# <footer class="navbar-fixed-bottom footer-section">
# <a href="https://plus.google.com/113076999677266283701" rel="publisher"></a>
# <div class="container-fluid">
# <div class="row-fluid">
# <div class="span2">
# <ul class="footer-updates">
# <li>
# <a class="footer-logo" href="/">
# <img alt="SwitchUp" class="footer-logo" src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/switch_logo_sm-9a2ba92daffba58b8b23e561687edaee.png"/><h5>switchup</h5><br/>DebunkMe, Inc.
#                     </a>
# </li>
# </ul>
# </div>
# <div class="span3" id="footer-main">
# <ul class="footer-links">
# <li><a href="/rankings/best-coding-bootcamps">Coding Bootcamps</a></li>
# <li><a href="/rankings/best-web-design-bootcamps">Design Bootcamps</a></li>
# <li><a href="/rankings/best-data-science-bootcamps">Data Science</a></li>
# <li><a href="/rankings">All Rankings</a></li>
# <li><a href="/rankings#locations">By Locations</a></li>
# <li><a href="/rankings/coding-bootcamp-survey">2018 Survey Data</a></li>
# </ul>
# </div>
# <div class="span2" id="footer-user">
# <ul class="footer-links-2">
# <li>
# <a href="/write_review" role="button" style="width: 100%;padding-left:0px;">Write Review</a>
# </li>
# <li><a href="/users/login">Login</a></li>
# <li><a href="/users/password/new">Reset PW</a></li>
# <li><a href="/about">About</a></li>
# <li><a href="/contact">Contact</a></li>
# </ul>
# </div>
# <div class="span2">
# <ul class="footer-links-2">
# <li><a href="/press">Press</a></li>
# <li><a href="/schools">For Schools</a></li>
# <li><a href="/privacy">Privacy</a></li>
# <li><a href="/terms">Terms</a></li>
# <li><a href="/ethics">Ethics</a></li>
# </ul>
# </div>
# <div class="span2" id="footer-social">
# <ul class="footer-contact">
# <li>
# <strong>Follow Us</strong>
# </li>
# <li>
# <a href="http://www.twitter.com/switchorg">
# <i class="fa fa-twitter-square"></i>
# </a>
# <a href="http://www.facebook.com/switchorg">
# <i class="fa fa-facebook-square"></i>
# </a>
# <a href="http://plus.google.com/+SwitchUpOrgEdu">
# <i class="fa fa-google-plus"></i>
# </a>
# <a href="https://www.linkedin.com/company/switchup-org">
# <i class="fa fa-linkedin"></i>
# </a>
# <a href="https://www.quora.com/profile/Jonathan-Lau-7">
# <i class="fa fa-fw"><strong>Q</strong></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script>
# <script type="text/javascript">
#     /**
#     * Function that tracks a click on an outbound link in Google Analytics.
#     * This function takes a valid URL string as an argument, and uses that URL string
#     * as the event label.
#     */
#     var trackOutboundLink = function(url) {
#       ga('send', 'event', 'outbound', 'click', url, {'hitCallback':
#         function () {
#           return true;
#         }
#       });
#     }
#
#     $(document).ready(function() {
#       function checkMq() {
#         if (Modernizr.mq('only screen and (min-width: 768px)')) {
#           $('#sidebar-wrap').fixTo('#sidebar-fix', {
#             useNativeSticky: false,
#             mindBottomPadding: true,
#             zIndex: 5,
#             top: 100
#           });
#         }
#         else {
#           $('#sidebar-wrap').fixTo('destroy');
#         }
#       }
#       $(function() {
#         checkMq();
#         $(window).resize(function() {
#           checkMq();
#         });
#       });
#     });
#   </script>
# <script type="text/javascript">
#       $(document).ready(function() {
#         $(window).scroll(function() {
#           if ($(window).width() > 768) {
#             $(".parallax").css({'opacity' : 1-($(this).scrollTop()/500)});
#           }
#         });
#
#         if (navigator.userAgent.match(/(iPod|iPhone|iPad)/)){
#           function iosVhHeightBug() {
#             var height = $(window).height();
#             $(".first-section").css('height', height);
#             $("#landing-splash").css('height', height);
#             $("#about-first-section").css('height', height);
#             $("#switcher-quiz-container").css('height', height);
#           }
#
#           iosVhHeightBug();
#           $(window).bind('resize', iosVhHeightBug);
#         }
#
#         $(".rankings-nav").hover(function() {
#           $('.rankings-hidden-nav').addClass('show');
#         });
#         $(".not-rankings-nav").hover(function() {
#           $('.rankings-hidden-nav').removeClass('show');
#         })
#         $(".rankings-hidden-nav").mouseleave(function() {
#           $('.rankings-hidden-nav').removeClass('show');
#         });
#
#         $(".bootcamp-nav").hover(function() {
#           $('.bootcamp-hidden-nav').addClass('show');
#         });
#         $(".not-bootcamp-nav").hover(function() {
#           $('.bootcamp-hidden-nav').removeClass('show');
#         })
#         $(".bootcamp-hidden-nav").mouseleave(function() {
#           $('.bootcamp-hidden-nav').removeClass('show');
#         });
#
#         $("#footer-fix").mouseenter(function() {
#           $('.rankings-hidden-nav').removeClass('show');
#           $('.bootcamp-hidden-nav').removeClass('show');
#         });
#       });
#     </script>
# <script type="text/javascript">
#       var trackOutboundLinkMatch = function(url) {
#         ga('send', 'event', 'match', 'click', url, {'hitCallback':
#           function () {
#             location.open(url, '_blank');
#           }
#         });
#       }
#     </script>
# <link href="https://fonts.googleapis.com/css?family=Source Sans Pro:300,400,700,300italic,400italic|Merriweather:300,300italic,400,400italic" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css" rel="stylesheet"/>
# <script src="https://switch-production-herokuapp-com.global.ssl.fastly.net/assets/application-1ccbe83b6a107d7593e4396cd8e361ae.js" type="text/javascript"></script>
# <!-- Start of HubSpot Embed Code -->
# <script async="" defer="" id="hs-script-loader" src="//js.hs-scripts.com/2939580.js" type="text/javascript"></script>
# <!-- End of HubSpot Embed Code -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5DLMKG3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# </body>
# </html>

# %%
school = soup.find_all(["div",{"class":"ranking-item"}])[1].find_all("h3")
schools = [school[i].text.split(".")[1].strip() for i in range(1,51)]

# %%
rating = soup.find_all("span",{"class":"ranking-item__rating--value"})
ratings = [rating[i].text.split("/")[0].strip() for i in range(len(rating))]

# %%
rev = soup.find_all("span",{"class":"ranking-item__rating--count"})
reviews = [rev[i].text.split()[0] for i in range(len(rev))]
for i in range(len(reviews)):
    reviews[i] = reviews[i].replace("(","")

# %%
details = soup.find_all("td")
details = [details[i].text.strip() for i in range(len(details))]

loc = [details[i] for i in range(0,len(details),3)]
courses = [details[i] for i in range(1,len(details),3)]
subject = [details[i] for i in range(2,len(details),3)]

# %%
top_df=pd.DataFrame({"Schools":schools,"Ratings":ratings,"Reviews":reviews,"Locations":loc,"Courses":courses,"Subjects":subject})
top_df["Ratings"]=top_df["Ratings"].astype(float)
top_df.loc[0,"Reviews"]=top_df.loc[0,"Reviews"].replace(",","")
top_df["Reviews"]=top_df["Reviews"].astype(float)

# %%
top_df.head()
# Out:
#             Schools  Ratings  Reviews  \
# 0          Le Wagon     4.98   1118.0
# 1          Ironhack     4.88    651.0
# 2       App Academy     4.70    653.0
# 3  General Assembly     4.23    645.0
# 4              Bloc     4.73    327.0
#
#                                            Locations  \
# 0  Amsterdam, Bali, Barcelona, Belo Horizonte, Be...
# 1  Amsterdam, Barcelona, Berlin, Bogota, Lisbon, ...
# 2                         NYC, Online, San Francisco
# 3  Atlanta, Austin, Boston, Chicago, Dallas, Denv...
# 4                                             Online
#
#                                              Courses  \
# 0                  FullStack program - 35+ locations
# 1  Part-time UX/UI Design , Full-time UX/UI Desig...
# 2  Bootcamp Prep, Engineering Interview Prep...\n...
# 3  User Experience Design Remote, Data Analytics....
# 4                Web Developer Track, Designer Track
#
#                                             Subjects
# 0          ruby, ruby on Rails, HTML/CSS, JavaScript
# 1  JavaScript, HTML, CSS, MERN Stack, MongoDB, Ex...
# 2  JavaScript, Ruby, Rails, React.js, Redux, CSS,...
# 3  Web Development (Full-stack: Javascript, Ruby,...
# 4  Ruby on Rails, HTML, Javascript, iOS, Android,...

# %% [markdown]
# ## Trying to get with a single command

# %%
def no_space(x):
    if x != "":
        return x

# %%
r = soup.find_all("div",{"class":"ranking-item"})
r2 = [school.text.split("\n") for school in r]
r3 = [list(filter(None,school)) for school in r2]
r4 = r3[1:]
pd.DataFrame(r4)
# Out:
#                                0              1   \
# 0                                             1.
# 1               Verified Outcomes
# 2                Available Online
# 3                Available Online
# 4                Available Online
# 5                Available Online
# 6                Available Online
# 7                Available Online
# 8                Flexible Classes
# 9                Available Online
# 10               Available Online
# 11               Available Online
# 12               Available Online
# 13                  Job Guarantee
# 14               Available Online
# 15               Flexible Classes
# 16               Available Online
# 17              Verified Outcomes
# 18               Available Online
# 19               Flexible Classes
# 20               Available Online
# 21              Verified Outcomes
# 22                                           23.
# 23              Verified Outcomes
# 24               Available Online
# 25              Verified Outcomes
# 26              Verified Outcomes
# 27              Verified Outcomes
# 28                                           29.
# 29              Verified Outcomes
# 30               Flexible Classes
# 31              Verified Outcomes
# 32               Available Online
# 33               Available Online
# 34               Available Online
# 35                                           36.
# 36               Available Online
# 37               Flexible Classes
# 38               Available Online
# 39              Verified Outcomes
# 40                                           41.
# 41                                           42.
# 42              Verified Outcomes
# 43                                           44.
# 44              Verified Outcomes
# 45                  Job Guarantee
# 46               Flexible Classes
# 47               Available Online
# 48                                           49.
# 49               Available Online
#
#                                2              3   \
# 0                        Le Wagon
# 1                Flexible Classes
# 2                   Job Guarantee
# 3               Verified Outcomes
# 4               Verified Outcomes
# 5               Verified Outcomes
# 6                Flexible Classes
# 7               Verified Outcomes
# 8                                             9.
# 9               Verified Outcomes
# 10              Verified Outcomes
# 11               Flexible Classes
# 12              Verified Outcomes
# 13                                           14.
# 14              Verified Outcomes
# 15                                           16.
# 16               Flexible Classes
# 17               Flexible Classes
# 18                                           19.
# 19                  Job Guarantee
# 20              Verified Outcomes
# 21                                           22.
# 22          Skylab Coders Academy
# 23               Flexible Classes
# 24              Verified Outcomes
# 25               Flexible Classes
# 26               Flexible Classes
# 27               Flexible Classes
# 28                  Claim Academy
# 29                  Job Guarantee
# 30                                           31.
# 31                                           32.
# 32               Flexible Classes
# 33              Verified Outcomes
# 34               Flexible Classes
# 35                  Coding Temple
# 36               Flexible Classes
# 37                                           38.
# 38               Flexible Classes
# 39                                           40.
# 40            Founders and Coders
# 41                      Codeworks
# 42                                           43.
# 43                  Coder Foundry
# 44                                           45.
# 45                                           46.
# 46                                           47.
# 47               Flexible Classes
# 48                     SE Factory
# 49               Flexible Classes
#
#                                               4              5   \
# 0                                         4.98/5
# 1                                                            2.
# 2                                                            3.
# 3                               Flexible Classes
# 4                               Flexible Classes
# 5                               Flexible Classes
# 6                                                            7.
# 7                               Flexible Classes
# 8                                      HackerYou
# 9                               Flexible Classes
# 10                              Flexible Classes
# 11                                                          12.
# 12                              Flexible Classes
# 13                                Makers Academy
# 14                              Flexible Classes
# 15                             Tech Talent South
# 16                                 Job Guarantee
# 17                                                          18.
# 18                             Startup Institute
# 19                                                          20.
# 20                              Flexible Classes
# 21                                 Tech Elevator
# 22                                        4.95/5
# 23                                                          24.
# 24                              Flexible Classes
# 25                                                          26.
# 26                                                          27.
# 27                                                          28.
# 28                                        4.53/5
# 29                                                          30.
# 30                                       Neoland
# 31                                   devCodeCamp
# 32                                                          33.
# 33                              Flexible Classes
# 34                                 Job Guarantee
# 35                                        4.88/5
# 36                                                          37.
# 37                                   RED Academy
# 38                                                          39.
# 39          Turing School of Software and Design
# 40                                        4.84/5
# 41                                         5.0/5
# 42                                         Sabio
# 43                                        4.58/5
# 44                                Launch Academy
# 45                 Horizons School of Technology
# 46                                    Dev League
# 47                                                          48.
# 48                                        4.91/5
# 49                                                          50.
#
#                                    6                              7   \
# 0                                                    (1,118 reviews)
# 1                            Ironhack
# 2                         App Academy
# 3                                                                 4.
# 4                       Job Guarantee
# 5                       Job Guarantee
# 6                         Coding Dojo
# 7                       Job Guarantee
# 8                              4.98/5
# 9                                                                10.
# 10                                                               11.
# 11                          Actualize
# 12                                                               13.
# 13                             4.58/5
# 14                                                               15.
# 15                             4.71/5
# 16                                                               17.
# 17                           Epicodus
# 18                             4.39/5
# 19                Ubiqum Code Academy
# 20                                                               21.
# 21                              4.9/5
# 22                                                     (102 reviews)
# 23                      DigitalCrafts
# 24                                                               25.
# 25                       LearningFuze
# 26                       Code Fellows
# 27                    Lighthouse Labs
# 28                                                      (86 reviews)
# 29                            Wyncode
# 30                             4.78/5
# 31                             4.75/5
# 32                          Galvanize
# 33                                                               34.
# 34                                                               35.
# 35                                                      (67 reviews)
# 36                         Skillcrush
# 37                             4.53/5
# 38                     Code Institute
# 39                             4.86/5
# 40                                                      (56 reviews)
# 41                                                      (53 reviews)
# 42                             4.67/5
# 43                                                      (55 reviews)
# 44                             4.46/5
# 45                             4.92/5
# 46                              4.9/5
# 47                           V School
# 48                                                      (32 reviews)
# 49          Bitmaker General Assembly
#
#                             8                            9   ...  \
# 0                                                      $$$$  ...
# 1                       4.88/5                               ...
# 2                        4.7/5                               ...
# 3             General Assembly                               ...
# 4                                                        5.  ...
# 5                                                        6.  ...
# 6                       4.48/5                               ...
# 7                                                        8.  ...
# 8                                             (198 reviews)  ...
# 9             The Tech Academy                               ...
# 10                Hack Reactor                               ...
# 11                       4.9/5                               ...
# 12                   Codesmith                               ...
# 13                                            (174 reviews)  ...
# 14                BrainStation                               ...
# 15                                            (150 reviews)  ...
# 16               Lambda School                               ...
# 17                      4.75/5                               ...
# 18                                            (138 reviews)  ...
# 19                      4.81/5                               ...
# 20           Fullstack Academy                               ...
# 21                                            (106 reviews)  ...
# 22                                                     $$$$  ...
# 23                      4.97/5                               ...
# 24          The Software Guild                               ...
# 25                      4.98/5                               ...
# 26                      4.76/5                               ...
# 27                      4.33/5                               ...
# 28                                                     $$$$  ...
# 29                      4.72/5                               ...
# 30                                             (74 reviews)  ...
# 31                                             (73 reviews)  ...
# 32                      4.08/5                               ...
# 33                Dev Mountain                               ...
# 34               CareerFoundry                               ...
# 35                                                     $$$$  ...
# 36                      4.47/5                               ...
# 37                                             (70 reviews)  ...
# 38                      4.58/5                               ...
# 39                                             (56 reviews)  ...
# 40                                                     $$$$  ...
# 41                                                     $$$$  ...
# 42                                             (54 reviews)  ...
# 43                                                     $$$$  ...
# 44                                             (55 reviews)  ...
# 45                                             (48 reviews)  ...
# 46                                             (48 reviews)  ...
# 47                      4.95/5                               ...
# 48                                                     $$$$  ...
# 49                      4.61/5                               ...
#
#                   51                                                 52  \
# 0               None                                               None
# 1         Learn More
# 2         Learn More
# 3                                                      Read All Reviews
# 4                             I heard about Bloc thru a friend. She ...
# 5                             I am a couple of months into Thinkful'...
# 6         Learn More
# 7                             I took the online full stack web devel...
# 8               None                                               None
# 9                                                      Read All Reviews
# 10                                                     Read All Reviews
# 11        Learn More
# 12                                                     Read All Reviews
# 13              None                                               None
# 14                                                     Read All Reviews
# 15              None                                               None
# 16                                                     Read All Reviews
# 17        Learn More
# 18              None                                               None
# 19        Learn More
# 20                                                     Read All Reviews
# 21              None                                               None
# 22              None                                               None
# 23        Learn More
# 24                                                     Read All Reviews
# 25        Learn More
# 26        Learn More
# 27        Learn More
# 28              None                                               None
# 29        Learn More
# 30              None                                               None
# 31              None                                               None
# 32        Learn More
# 33                                                     Read All Reviews
# 34                                                     Read All Reviews
# 35              None                                               None
# 36        Learn More
# 37              None                                               None
# 38        Learn More
# 39              None                                               None
# 40              None                                               None
# 41              None                                               None
# 42              None                                               None
# 43              None                                               None
# 44              None                                               None
# 45              None                                               None
# 46              None                                               None
# 47        Learn More
# 48              None                                               None
# 49        Learn More
#
#             53                                   54                55  \
# 0         None                                 None              None
# 1         None                                 None              None
# 2         None                                 None              None
# 3                                                          Learn More
# 4                       Songting Hu - July 19, 2019
# 5                              Maya - July 23, 2019
# 6         None                                 None              None
# 7                           Annabel - June 26, 2019
# 8         None                                 None              None
# 9                                                          Learn More
# 10                                                         Learn More
# 11        None                                 None              None
# 12                                                         Learn More
# 13        None                                 None              None
# 14                                                         Learn More
# 15        None                                 None              None
# 16                                                         Learn More
# 17        None                                 None              None
# 18        None                                 None              None
# 19        None                                 None              None
# 20                                                         Learn More
# 21        None                                 None              None
# 22        None                                 None              None
# 23        None                                 None              None
# 24                                                         Learn More
# 25        None                                 None              None
# 26        None                                 None              None
# 27        None                                 None              None
# 28        None                                 None              None
# 29        None                                 None              None
# 30        None                                 None              None
# 31        None                                 None              None
# 32        None                                 None              None
# 33                                                         Learn More
# 34                                                         Learn More
# 35        None                                 None              None
# 36        None                                 None              None
# 37        None                                 None              None
# 38        None                                 None              None
# 39        None                                 None              None
# 40        None                                 None              None
# 41        None                                 None              None
# 42        None                                 None              None
# 43        None                                 None              None
# 44        None                                 None              None
# 45        None                                 None              None
# 46        None                                 None              None
# 47        None                                 None              None
# 48        None                                 None              None
# 49        None                                 None              None
#
#                             56          57    58                59    60
# 0                         None        None  None              None  None
# 1                         None        None  None              None  None
# 2                         None        None  None              None  None
# 3                                     None  None              None  None
# 4             Read All Reviews                          Learn More
# 5             Read All Reviews                          Learn More
# 6                         None        None  None              None  None
# 7             Read All Reviews                          Learn More
# 8                         None        None  None              None  None
# 9                                     None  None              None  None
# 10                                    None  None              None  None
# 11                        None        None  None              None  None
# 12                                    None  None              None  None
# 13                        None        None  None              None  None
# 14                                    None  None              None  None
# 15                        None        None  None              None  None
# 16                                    None  None              None  None
# 17                        None        None  None              None  None
# 18                        None        None  None              None  None
# 19                        None        None  None              None  None
# 20                                    None  None              None  None
# 21                        None        None  None              None  None
# 22                        None        None  None              None  None
# 23                        None        None  None              None  None
# 24                                    None  None              None  None
# 25                        None        None  None              None  None
# 26                        None        None  None              None  None
# 27                        None        None  None              None  None
# 28                        None        None  None              None  None
# 29                        None        None  None              None  None
# 30                        None        None  None              None  None
# 31                        None        None  None              None  None
# 32                        None        None  None              None  None
# 33                                    None  None              None  None
# 34                                    None  None              None  None
# 35                        None        None  None              None  None
# 36                        None        None  None              None  None
# 37                        None        None  None              None  None
# 38                        None        None  None              None  None
# 39                        None        None  None              None  None
# 40                        None        None  None              None  None
# 41                        None        None  None              None  None
# 42                        None        None  None              None  None
# 43                        None        None  None              None  None
# 44                        None        None  None              None  None
# 45                        None        None  None              None  None
# 46                        None        None  None              None  None
# 47                        None        None  None              None  None
# 48                        None        None  None              None  None
# 49                        None        None  None              None  None
#
# [50 rows x 61 columns]

# %%
l1 = [1,2,3,4,5]
l2 = ["teste","21321","asdjaso","!123132","hahha"]

# %%
pd.DataFrame({"lista1":l1,"lista2":l2})
# Out:
#    lista1   lista2
# 0       1    teste
# 1       2    21321
# 2       3  asdjaso
# 3       4  !123132
# 4       5    hahha
